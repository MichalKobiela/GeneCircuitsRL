# %% [markdown]
# Setup

# %%
# %pip install numpy
# %pip install matplotlib
# %pip install tensorboard
import numpy as np
import matplotlib.pyplot as plt
from juliacall import Main as jl
from juliacall import Pkg as jlPkg
jlPkg.activate("../.")
jl.Pkg.instantiate()
jl.include("../models/rl_repressilator_past_amort_setup.jl")
#jlPkg.instantiate() #run the first time using this repo
# Out:
# Requirement already satisfied: numpy in c:\Users\micha\miniconda3\envs\circuitsrl\Lib\site-packages (2.4.2)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: matplotlib in c:\Users\micha\miniconda3\envs\circuitsrl\Lib\site-packages (3.10.8)
# Requirement already satisfied: contourpy>=1.0.1 in c:\Users\micha\miniconda3\envs\circuitsrl\Lib\site-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\Users\micha\miniconda3\envs\circuitsrl\Lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\Users\micha\miniconda3\envs\circuitsrl\Lib\site-packages (from matplotlib) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\Users\micha\miniconda3\envs\circuitsrl\Lib\site-packages (from matplotlib) (1.4.9)
# Requirement already satisfied: numpy>=1.23 in c:\Users\micha\miniconda3\envs\circuitsrl\Lib\site-packages (from matplotlib) (2.4.2)
# Requirement already satisfied: packaging>=20.0 in c:\Users\micha\miniconda3\envs\circuitsrl\Lib\site-packages (from matplotlib) (26.0)
# Requirement already satisfied: pillow>=8 in c:\Users\micha\miniconda3\envs\circuitsrl\Lib\site-packages (from matplotlib) (12.1.0)
# Requirement already satisfied: pyparsing>=3 in c:\Users\micha\miniconda3\envs\circuitsrl\Lib\site-packages (from matplotlib) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\Users\micha\miniconda3\envs\circuitsrl\Lib\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\Users\micha\miniconda3\envs\circuitsrl\Lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: tensorboard in c:\Users\micha\miniconda3\envs\circuitsrl\Lib\site-packages (2.20.0)
# Requirement already satisfied: absl-py>=0.4 in c:\Users\micha\miniconda3\envs\circuitsrl\Lib\site-packages (from tensorboard) (2.4.0)
# Requirement already satisfied: grpcio>=1.48.2 in c:\Users\micha\miniconda3\envs\circuitsrl\Lib\site-packages (from tensorboard) (1.78.0)
# Requirement already satisfied: markdown>=2.6.8 in c:\Users\micha\miniconda3\envs\circuitsrl\Lib\site-packages (from tensorboard) (3.10.2)
# Requirement already satisfied: numpy>=1.12.0 in c:\Users\micha\miniconda3\envs\circuitsrl\Lib\site-packages (from tensorboard) (2.4.2)
# Requirement already satisfied: packaging in c:\Users\micha\miniconda3\envs\circuitsrl\Lib\site-packages (from tensorboard) (26.0)
# Requirement already satisfied: pillow in c:\Users\micha\miniconda3\envs\circuitsrl\Lib\site-packages (from tensorboard) (12.1.0)
# Requirement already satisfied: protobuf!=4.24.0,>=3.19.6 in c:\Users\micha\miniconda3\envs\circuitsrl\Lib\site-packages (from tensorboard) (6.33.5)
# Requirement already satisfied: setuptools>=41.0.0 in c:\Users\micha\miniconda3\envs\circuitsrl\Lib\site-packages (from tensorboard) (82.0.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in c:\Users\micha\miniconda3\envs\circuitsrl\Lib\site-packages (from tensorboard) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\Users\micha\miniconda3\envs\circuitsrl\Lib\site-packages (from tensorboard) (3.1.5)
# Requirement already satisfied: typing-extensions~=4.12 in c:\Users\micha\miniconda3\envs\circuitsrl\Lib\site-packages (from grpcio>=1.48.2->tensorboard) (4.15.0)
# Requirement already satisfied: markupsafe>=2.1.1 in c:\Users\micha\miniconda3\envs\circuitsrl\Lib\site-packages (from werkzeug>=1.0.1->tensorboard) (3.0.3)
# Note: you may need to restart the kernel to use updated packages.
# Detected IPython. Loading juliacall extension. See https://juliapy.github.io/PythonCall.jl/stable/compat/#IPython
#   Activating project at `c:\Users\micha\GeneCircuitsRL`
# observation (generic function with 2 methods)
# Second peak value: 0.7038096038235359

# %%
fixed_point = np.ones(4)

# %%
import gymnasium as gym
from gymnasium import spaces
import numpy as np
import torch as th
import torch.nn as nn
from stable_baselines3.common.torch_layers import BaseFeaturesExtractor

class Custom1DCNNExtractor(BaseFeaturesExtractor):
    def __init__(self, observation_space, features_dim=128, obs_dim=128, action_dim=3, n_steps=5):
        super(Custom1DCNNExtractor, self).__init__(observation_space, features_dim)

        self.obs_dim = obs_dim
        self.action_dim = action_dim
        self.n_steps = n_steps

        n_input_channels = 1
        seq_len = obs_dim

        # CNN to process each observation chunk
        self.cnn = nn.Sequential(
            nn.Conv1d(n_input_channels, 32, kernel_size=3, stride=1, padding=1),
            nn.ReLU(),
            nn.Conv1d(32, 64, kernel_size=3, stride=1, padding=1),
            nn.ReLU(),
            nn.Flatten()
        )

        # Determine CNN output size
        with th.no_grad():
            sample_obs = th.zeros((1, n_input_channels, seq_len), dtype=th.float32)
            cnn_output_dim = self.cnn(sample_obs).shape[1]

        # Concatenate obs features and raw actions across all steps
        combined_dim = self.n_steps * cnn_output_dim + self.n_steps * action_dim

        self.linear = nn.Sequential(
            nn.Linear(combined_dim, features_dim),
            nn.ReLU()
        )

    def forward(self, observations):
        """
        observations: (batch, 1, obs1 + act1 + ... + obsN + actN)
        """
        obs_feats = []
        act_feats = []

        for i in range(self.n_steps):
            obs_start = i * (self.obs_dim + self.action_dim)
            act_start = obs_start + self.obs_dim
            act_end = act_start + self.action_dim

            obs = observations[:, :, obs_start:act_start]  # (batch, 1, obs_dim)
            act = observations[:, 0, act_start:act_end]    # (batch, action_dim)

            obs_feat = self.cnn(obs)                       # (batch, cnn_output_dim)
            obs_feats.append(obs_feat)
            act_feats.append(act)

        combined = th.cat(obs_feats + act_feats, dim=1)
        return self.linear(combined)


# ======================
#  Environment
# ======================

import random
import torch
from gymnasium.utils import seeding

class CustomEnv(gym.Env):
    metadata = {"render_modes": []}

    def __init__(self, max_episode_steps=5):
        super(CustomEnv, self).__init__()

        self.obs_dim = 128
        self.action_dim = 3          # design params: kX, km, K
        self.uncertain_dim = 4       # H, γX, γm, ϵ
        self.n_steps = max_episode_steps

        self.observation_space = spaces.Box(
            low=-np.inf,
            high=np.inf,
            shape=(1, self.n_steps * (self.obs_dim + self.action_dim)),
            dtype=np.float32
        )

        self.action_space = spaces.Box(
            low=-1,
            high=1,
            shape=(self.action_dim,),
            dtype=np.float32
        )

        self.max_episode_steps = max_episode_steps
        self.current_step = 0
        self.uncertain = fixed_point

        self.effective_observation = np.zeros(self.observation_space.shape, dtype=np.float32)
    
    def seed(self, seed=None):
        self._np_random, seed = seeding.np_random(seed)
        np.random.seed(seed)
        random.seed(seed)
        torch.manual_seed(seed)
        jl.seval(f"Random.seed!({seed})")  # sync seed with Julia
        return [seed]
    
    def reset(self, seed=None, options=None):
        self.uncertain = fixed_point
        
        self.current_step = 0
        self.effective_observation[:] = 0.0

        info = {}
        return self.effective_observation.copy(), info

    def step(self, action):
        params_action = np.concatenate((self.uncertain, action))
        reward = jl.reward_normalized_past_amort(params_action, 1 / 7)
        rew = np.clip(reward, -5, 5)

        obs_vector = jl.observation(self.uncertain, action)
        obs_vector = np.array(obs_vector).reshape(1, -1).astype(np.float32)

        if self.current_step < self.max_episode_steps:
            obs_start = self.current_step * (self.obs_dim + self.action_dim)
            act_start = obs_start + self.obs_dim

            self.effective_observation[:, obs_start:act_start] = obs_vector
            self.effective_observation[:, act_start:act_start + self.action_dim] = action

        self.current_step += 1
        terminated = self.current_step >= self.max_episode_steps
        truncated = False
        info = {}

        return self.effective_observation.copy(), rew, terminated, truncated, info

# %%
from stable_baselines3.common.env_checker import check_env
env = CustomEnv()
check_env(env)
# Out:
# c:\Users\micha\miniconda3\envs\circuitsrl\Lib\site-packages\stable_baselines3\common\env_checker.py:316: UserWarning: Your observation  has an unconventional shape (neither an image, nor a 1D vector). We recommend you to flatten the observation to have only a 1D vector or use a custom policy to properly process the data.
#   warnings.warn(

# %% [markdown]
# Training

# %%
import os
import pandas as pd
import seaborn as sns

from stable_baselines3 import PPO
from stable_baselines3.common.monitor import Monitor

log_dir = "../logs/rl_repressilator_past_amort_multi_step_frame_5_fixed_1/"
os.makedirs(log_dir, exist_ok=True)


SEED = 1234

random.seed(SEED)
np.random.seed(SEED)
torch.manual_seed(SEED)
jl.seval(f"Random.seed!({SEED})") 
env = CustomEnv()
env.seed(SEED)
env.reset(seed=SEED)
env = Monitor(env, filename=log_dir)

policy_kwargs = dict(
    features_extractor_class=Custom1DCNNExtractor,
    features_extractor_kwargs=dict(features_dim=128),
)

model = PPO(
    "CnnPolicy", 
    env,
    policy_kwargs=policy_kwargs,
    verbose=1,
    tensorboard_log=log_dir,
    seed=SEED
)
# Out:
# Using cpu device
# Wrapping the env in a DummyVecEnv.

# %%
model.learn(total_timesteps=1500000)

obs, info = env.reset()
action, _ = model.predict(obs)
print("Test action:", action)
# Out:
# Logging to ../logs/rl_repressilator_past_amort_multi_step_frame_5_fixed_1/PPO_1
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 5        |
# |    ep_rew_mean     | 0.151    |
# | time/              |          |
# |    fps             | 19       |
# |    iterations      | 1        |
# |    time_elapsed    | 106      |
# |    total_timesteps | 2048     |
# ---------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 5          |
# |    ep_rew_mean          | 0.242      |
# | time/                   |            |
# |    fps                  | 17         |
# |    iterations           | 2          |
# |    time_elapsed         | 229        |
# |    total_timesteps      | 4096       |
# | train/                  |            |
# |    approx_kl            | 0.01451502 |
# |    clip_fraction        | 0.2        |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -4.21      |
# |    explained_variance   | -0.0026    |
# |    learning_rate        | 0.0003     |
# |    loss                 | 1.26       |
# |    n_updates            | 10         |
# |    policy_gradient_loss | -0.0197    |
# |    std                  | 0.975      |
# |    value_loss           | 2.05       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 5           |
# |    ep_rew_mean          | 0.0447      |
# | time/                   |             |
# |    fps                  | 17          |
# |    iterations           | 3           |
# |    time_elapsed         | 357         |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.011001073 |
# |    clip_fraction        | 0.139       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.14       |
# |    explained_variance   | -0.00101    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.09        |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.0121     |
# |    std                  | 0.949       |
# |    value_loss           | 1.88        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 5           |
# |    ep_rew_mean          | 0.349       |
# | time/                   |             |
# |    fps                  | 16          |
# |    iterations           | 4           |
# |    time_elapsed         | 488         |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.009162517 |
# |    clip_fraction        | 0.13        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.05       |
# |    explained_variance   | 0.00123     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.35        |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.0126     |
# |    std                  | 0.923       |
# |    value_loss           | 1.85        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 5           |
# |    ep_rew_mean          | 0.753       |
# | time/                   |             |
# |    fps                  | 16          |
# |    iterations           | 5           |
# |    time_elapsed         | 631         |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.013319416 |
# |    clip_fraction        | 0.146       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.97       |
# |    explained_variance   | -0.0162     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.872       |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.0153     |
# |    std                  | 0.9         |
# |    value_loss           | 1.75        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 5            |
# |    ep_rew_mean          | 0.854        |
# | time/                   |              |
# |    fps                  | 15           |
# |    iterations           | 6            |
# |    time_elapsed         | 783          |
# |    total_timesteps      | 12288        |
# | train/                  |              |
# |    approx_kl            | 0.0148320645 |
# |    clip_fraction        | 0.151        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -3.9         |
# |    explained_variance   | -0.0105      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.685        |
# |    n_updates            | 50           |
# |    policy_gradient_loss | -0.0195      |
# |    std                  | 0.882        |
# |    value_loss           | 1.52         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 5           |
# |    ep_rew_mean          | 0.873       |
# | time/                   |             |
# |    fps                  | 15          |
# |    iterations           | 7           |
# |    time_elapsed         | 945         |
# |    total_timesteps      | 14336       |
# | train/                  |             |
# |    approx_kl            | 0.017739687 |
# |    clip_fraction        | 0.188       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.85       |
# |    explained_variance   | -0.229      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.51        |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.0304     |
# |    std                  | 0.866       |
# |    value_loss           | 1.48        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 5          |
# |    ep_rew_mean          | 0.98       |
# | time/                   |            |
# |    fps                  | 14         |
# |    iterations           | 8          |
# |    time_elapsed         | 1153       |
# |    total_timesteps      | 16384      |
# | train/                  |            |
# |    approx_kl            | 0.02391048 |
# |    clip_fraction        | 0.225      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.78      |
# |    explained_variance   | -0.154     |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.359      |
# |    n_updates            | 70         |
# |    policy_gradient_loss | -0.0365    |
# |    std                  | 0.842      |
# |    value_loss           | 1.34       |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 5          |
# |    ep_rew_mean          | 1.21       |
# | time/                   |            |
# |    fps                  | 13         |
# |    iterations           | 9          |
# |    time_elapsed         | 1395       |
# |    total_timesteps      | 18432      |
# | train/                  |            |
# |    approx_kl            | 0.02625769 |
# |    clip_fraction        | 0.236      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.7       |
# |    explained_variance   | -0.0802    |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.505      |
# |    n_updates            | 80         |
# |    policy_gradient_loss | -0.0329    |
# |    std                  | 0.822      |
# |    value_loss           | 1.32       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 5           |
# |    ep_rew_mean          | 1.3         |
# | time/                   |             |
# |    fps                  | 12          |
# |    iterations           | 10          |
# |    time_elapsed         | 1675        |
# |    total_timesteps      | 20480       |
# | train/                  |             |
# |    approx_kl            | 0.037799247 |
# |    clip_fraction        | 0.261       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.62       |
# |    explained_variance   | -0.145      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.898       |
# |    n_updates            | 90          |
# |    policy_gradient_loss | -0.0425     |
# |    std                  | 0.798       |
# |    value_loss           | 1.19        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 5          |
# |    ep_rew_mean          | 1.63       |
# | time/                   |            |
# |    fps                  | 11         |
# |    iterations           | 11         |
# |    time_elapsed         | 1967       |
# |    total_timesteps      | 22528      |
# | train/                  |            |
# |    approx_kl            | 0.04490245 |
# |    clip_fraction        | 0.308      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.54      |
# |    explained_variance   | -0.201     |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.32       |
# |    n_updates            | 100        |
# |    policy_gradient_loss | -0.0431    |
# |    std                  | 0.776      |
# |    value_loss           | 1.09       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 5           |
# |    ep_rew_mean          | 1.31        |
# | time/                   |             |
# |    fps                  | 10          |
# |    iterations           | 12          |
# |    time_elapsed         | 2274        |
# |    total_timesteps      | 24576       |
# | train/                  |             |
# |    approx_kl            | 0.051594585 |
# |    clip_fraction        | 0.288       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.46       |
# |    explained_variance   | -0.157      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.142       |
# |    n_updates            | 110         |
# |    policy_gradient_loss | -0.0476     |
# |    std                  | 0.757       |
# |    value_loss           | 0.957       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 5           |
# |    ep_rew_mean          | 1.35        |
# | time/                   |             |
# |    fps                  | 10          |
# |    iterations           | 13          |
# |    time_elapsed         | 2567        |
# |    total_timesteps      | 26624       |
# | train/                  |             |
# |    approx_kl            | 0.060063407 |
# |    clip_fraction        | 0.355       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.37       |
# |    explained_variance   | -0.167      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.14        |
# |    n_updates            | 120         |
# |    policy_gradient_loss | -0.0521     |
# |    std                  | 0.733       |
# |    value_loss           | 0.979       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 5           |
# |    ep_rew_mean          | 1.41        |
# | time/                   |             |
# |    fps                  | 9           |
# |    iterations           | 14          |
# |    time_elapsed         | 2870        |
# |    total_timesteps      | 28672       |
# | train/                  |             |
# |    approx_kl            | 0.079072446 |
# |    clip_fraction        | 0.371       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.29       |
# |    explained_variance   | -0.186      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.273       |
# |    n_updates            | 130         |
# |    policy_gradient_loss | -0.053      |
# |    std                  | 0.715       |
# |    value_loss           | 0.986       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 5           |
# |    ep_rew_mean          | 1.62        |
# | time/                   |             |
# |    fps                  | 9           |
# |    iterations           | 15          |
# |    time_elapsed         | 3169        |
# |    total_timesteps      | 30720       |
# | train/                  |             |
# |    approx_kl            | 0.066454485 |
# |    clip_fraction        | 0.388       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.2        |
# |    explained_variance   | -0.215      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.46        |
# |    n_updates            | 140         |
# |    policy_gradient_loss | -0.0505     |
# |    std                  | 0.694       |
# |    value_loss           | 1.07        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 5          |
# |    ep_rew_mean          | 1.82       |
# | time/                   |            |
# |    fps                  | 9          |
# |    iterations           | 16         |
# |    time_elapsed         | 3473       |
# |    total_timesteps      | 32768      |
# | train/                  |            |
# |    approx_kl            | 0.08575153 |
# |    clip_fraction        | 0.414      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.1       |
# |    explained_variance   | -0.228     |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.121      |
# |    n_updates            | 150        |
# |    policy_gradient_loss | -0.0605    |
# |    std                  | 0.668      |
# |    value_loss           | 0.902      |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 5          |
# |    ep_rew_mean          | 1.91       |
# | time/                   |            |
# |    fps                  | 9          |
# |    iterations           | 17         |
# |    time_elapsed         | 3771       |
# |    total_timesteps      | 34816      |
# | train/                  |            |
# |    approx_kl            | 0.09807055 |
# |    clip_fraction        | 0.408      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -2.99      |
# |    explained_variance   | -0.0956    |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.21       |
# |    n_updates            | 160        |
# |    policy_gradient_loss | -0.0566    |
# |    std                  | 0.646      |
# |    value_loss           | 0.88       |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 5          |
# |    ep_rew_mean          | 1.9        |
# | time/                   |            |
# |    fps                  | 9          |
# |    iterations           | 18         |
# |    time_elapsed         | 4072       |
# |    total_timesteps      | 36864      |
# | train/                  |            |
# |    approx_kl            | 0.10390511 |
# |    clip_fraction        | 0.423      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -2.89      |
# |    explained_variance   | -0.0456    |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.274      |
# |    n_updates            | 170        |
# |    policy_gradient_loss | -0.0597    |
# |    std                  | 0.623      |
# |    value_loss           | 0.963      |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 5           |
# |    ep_rew_mean          | 2.15        |
# | time/                   |             |
# |    fps                  | 8           |
# |    iterations           | 19          |
# |    time_elapsed         | 4381        |
# |    total_timesteps      | 38912       |
# | train/                  |             |
# |    approx_kl            | 0.101348415 |
# |    clip_fraction        | 0.427       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.78       |
# |    explained_variance   | -0.0778     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.122       |
# |    n_updates            | 180         |
# |    policy_gradient_loss | -0.0603     |
# |    std                  | 0.601       |
# |    value_loss           | 0.733       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 5           |
# |    ep_rew_mean          | 2.15        |
# | time/                   |             |
# |    fps                  | 8           |
# |    iterations           | 20          |
# |    time_elapsed         | 4682        |
# |    total_timesteps      | 40960       |
# | train/                  |             |
# |    approx_kl            | 0.118636884 |
# |    clip_fraction        | 0.44        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.66       |
# |    explained_variance   | 0.00427     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.155       |
# |    n_updates            | 190         |
# |    policy_gradient_loss | -0.0646     |
# |    std                  | 0.578       |
# |    value_loss           | 0.708       |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 5          |
# |    ep_rew_mean          | 2.31       |
# | time/                   |            |
# |    fps                  | 8          |
# |    iterations           | 21         |
# |    time_elapsed         | 4990       |
# |    total_timesteps      | 43008      |
# | train/                  |            |
# |    approx_kl            | 0.12398738 |
# |    clip_fraction        | 0.443      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -2.56      |
# |    explained_variance   | -0.0278    |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.178      |
# |    n_updates            | 200        |
# |    policy_gradient_loss | -0.0598    |
# |    std                  | 0.56       |
# |    value_loss           | 0.757      |
# ----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 5         |
# |    ep_rew_mean          | 2.21      |
# | time/                   |           |
# |    fps                  | 8         |
# |    iterations           | 22        |
# |    time_elapsed         | 5292      |
# |    total_timesteps      | 45056     |
# | train/                  |           |
# |    approx_kl            | 0.1263172 |
# |    clip_fraction        | 0.474     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -2.47     |
# |    explained_variance   | -0.0578   |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0.0886    |
# |    n_updates            | 210       |
# |    policy_gradient_loss | -0.065    |
# |    std                  | 0.547     |
# |    value_loss           | 0.661     |
# ---------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 5          |
# |    ep_rew_mean          | 2.64       |
# | time/                   |            |
# |    fps                  | 8          |
# |    iterations           | 23         |
# |    time_elapsed         | 5609       |
# |    total_timesteps      | 47104      |
# | train/                  |            |
# |    approx_kl            | 0.14410573 |
# |    clip_fraction        | 0.478      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -2.37      |
# |    explained_variance   | -0.0224    |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.0282     |
# |    n_updates            | 220        |
# |    policy_gradient_loss | -0.0633    |
# |    std                  | 0.523      |
# |    value_loss           | 0.626      |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 5          |
# |    ep_rew_mean          | 2.73       |
# | time/                   |            |
# |    fps                  | 8          |
# |    iterations           | 24         |
# |    time_elapsed         | 5932       |
# |    total_timesteps      | 49152      |
# | train/                  |            |
# |    approx_kl            | 0.20112823 |
# |    clip_fraction        | 0.474      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -2.24      |
# |    explained_variance   | 0.0926     |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.0289     |
# |    n_updates            | 230        |
# |    policy_gradient_loss | -0.0659    |
# |    std                  | 0.504      |
# |    value_loss           | 0.64       |
# ----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 5         |
# |    ep_rew_mean          | 2.47      |
# | time/                   |           |
# |    fps                  | 8         |
# |    iterations           | 25        |
# |    time_elapsed         | 6261      |
# |    total_timesteps      | 51200     |
# | train/                  |           |
# |    approx_kl            | 0.1908479 |
# |    clip_fraction        | 0.494     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -2.13     |
# |    explained_variance   | 0.104     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0.00875   |
# |    n_updates            | 240       |
# |    policy_gradient_loss | -0.0616   |
# |    std                  | 0.486     |
# |    value_loss           | 0.595     |
# ---------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 5          |
# |    ep_rew_mean          | 2.21       |
# | time/                   |            |
# |    fps                  | 8          |
# |    iterations           | 26         |
# |    time_elapsed         | 6584       |
# |    total_timesteps      | 53248      |
# | train/                  |            |
# |    approx_kl            | 0.16574512 |
# |    clip_fraction        | 0.496      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -2.04      |
# |    explained_variance   | 0.0806     |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.139      |
# |    n_updates            | 250        |
# |    policy_gradient_loss | -0.0697    |
# |    std                  | 0.473      |
# |    value_loss           | 0.551      |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 5          |
# |    ep_rew_mean          | 2.74       |
# | time/                   |            |
# |    fps                  | 8          |
# |    iterations           | 27         |
# |    time_elapsed         | 6908       |
# |    total_timesteps      | 55296      |
# | train/                  |            |
# |    approx_kl            | 0.16832818 |
# |    clip_fraction        | 0.492      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.97      |
# |    explained_variance   | 0.116      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.188      |
# |    n_updates            | 260        |
# |    policy_gradient_loss | -0.0641    |
# |    std                  | 0.464      |
# |    value_loss           | 0.619      |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 5          |
# |    ep_rew_mean          | 2.43       |
# | time/                   |            |
# |    fps                  | 7          |
# |    iterations           | 28         |
# |    time_elapsed         | 7211       |
# |    total_timesteps      | 57344      |
# | train/                  |            |
# |    approx_kl            | 0.19739556 |
# |    clip_fraction        | 0.506      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.89      |
# |    explained_variance   | 0.0743     |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.019      |
# |    n_updates            | 270        |
# |    policy_gradient_loss | -0.0674    |
# |    std                  | 0.451      |
# |    value_loss           | 0.562      |
# ----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 5         |
# |    ep_rew_mean          | 2.78      |
# | time/                   |           |
# |    fps                  | 7         |
# |    iterations           | 29        |
# |    time_elapsed         | 7544      |
# |    total_timesteps      | 59392     |
# | train/                  |           |
# |    approx_kl            | 0.2267364 |
# |    clip_fraction        | 0.529     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -1.78     |
# |    explained_variance   | 0.111     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0.0239    |
# |    n_updates            | 280       |
# |    policy_gradient_loss | -0.0679   |
# |    std                  | 0.432     |
# |    value_loss           | 0.592     |
# ---------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 5          |
# |    ep_rew_mean          | 2.97       |
# | time/                   |            |
# |    fps                  | 7          |
# |    iterations           | 30         |
# |    time_elapsed         | 7879       |
# |    total_timesteps      | 61440      |
# | train/                  |            |
# |    approx_kl            | 0.20768437 |
# |    clip_fraction        | 0.517      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.68      |
# |    explained_variance   | 0.157      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.0602     |
# |    n_updates            | 290        |
# |    policy_gradient_loss | -0.0584    |
# |    std                  | 0.421      |
# |    value_loss           | 0.569      |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 5          |
# |    ep_rew_mean          | 2.98       |
# | time/                   |            |
# |    fps                  | 7          |
# |    iterations           | 31         |
# |    time_elapsed         | 8209       |
# |    total_timesteps      | 63488      |
# | train/                  |            |
# |    approx_kl            | 0.25072828 |
# |    clip_fraction        | 0.552      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.59      |
# |    explained_variance   | 0.13       |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0424    |
# |    n_updates            | 300        |
# |    policy_gradient_loss | -0.0703    |
# |    std                  | 0.408      |
# |    value_loss           | 0.525      |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 5          |
# |    ep_rew_mean          | 2.97       |
# | time/                   |            |
# |    fps                  | 7          |
# |    iterations           | 32         |
# |    time_elapsed         | 8544       |
# |    total_timesteps      | 65536      |
# | train/                  |            |
# |    approx_kl            | 0.25594294 |
# |    clip_fraction        | 0.52       |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.49      |
# |    explained_variance   | 0.197      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.104      |
# |    n_updates            | 310        |
# |    policy_gradient_loss | -0.066     |
# |    std                  | 0.396      |
# |    value_loss           | 0.546      |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 5          |
# |    ep_rew_mean          | 2.95       |
# | time/                   |            |
# |    fps                  | 7          |
# |    iterations           | 33         |
# |    time_elapsed         | 8888       |
# |    total_timesteps      | 67584      |
# | train/                  |            |
# |    approx_kl            | 0.25477886 |
# |    clip_fraction        | 0.553      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.39      |
# |    explained_variance   | 0.165      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.0155     |
# |    n_updates            | 320        |
# |    policy_gradient_loss | -0.0722    |
# |    std                  | 0.383      |
# |    value_loss           | 0.503      |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 5          |
# |    ep_rew_mean          | 3.13       |
# | time/                   |            |
# |    fps                  | 7          |
# |    iterations           | 34         |
# |    time_elapsed         | 9222       |
# |    total_timesteps      | 69632      |
# | train/                  |            |
# |    approx_kl            | 0.28348035 |
# |    clip_fraction        | 0.529      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.29      |
# |    explained_variance   | 0.268      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0737    |
# |    n_updates            | 330        |
# |    policy_gradient_loss | -0.0677    |
# |    std                  | 0.372      |
# |    value_loss           | 0.42       |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 5          |
# |    ep_rew_mean          | 3.31       |
# | time/                   |            |
# |    fps                  | 7          |
# |    iterations           | 35         |
# |    time_elapsed         | 9560       |
# |    total_timesteps      | 71680      |
# | train/                  |            |
# |    approx_kl            | 0.25918996 |
# |    clip_fraction        | 0.535      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.19      |
# |    explained_variance   | 0.319      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.0853     |
# |    n_updates            | 340        |
# |    policy_gradient_loss | -0.0645    |
# |    std                  | 0.36       |
# |    value_loss           | 0.451      |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 5          |
# |    ep_rew_mean          | 3.19       |
# | time/                   |            |
# |    fps                  | 7          |
# |    iterations           | 36         |
# |    time_elapsed         | 9898       |
# |    total_timesteps      | 73728      |
# | train/                  |            |
# |    approx_kl            | 0.39940557 |
# |    clip_fraction        | 0.578      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.08      |
# |    explained_variance   | 0.381      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0349    |
# |    n_updates            | 350        |
# |    policy_gradient_loss | -0.0704    |
# |    std                  | 0.346      |
# |    value_loss           | 0.36       |
# ----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 5         |
# |    ep_rew_mean          | 3.27      |
# | time/                   |           |
# |    fps                  | 7         |
# |    iterations           | 37        |
# |    time_elapsed         | 10234     |
# |    total_timesteps      | 75776     |
# | train/                  |           |
# |    approx_kl            | 0.3203125 |
# |    clip_fraction        | 0.559     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.973    |
# |    explained_variance   | 0.368     |
# |    learning_rate        | 0.0003    |
# |    loss                 | -0.0181   |
# |    n_updates            | 360       |
# |    policy_gradient_loss | -0.0726   |
# |    std                  | 0.336     |
# |    value_loss           | 0.419     |
# ---------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 5          |
# |    ep_rew_mean          | 3.2        |
# | time/                   |            |
# |    fps                  | 7          |
# |    iterations           | 38         |
# |    time_elapsed         | 10578      |
# |    total_timesteps      | 77824      |
# | train/                  |            |
# |    approx_kl            | 0.38130087 |
# |    clip_fraction        | 0.56       |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.878     |
# |    explained_variance   | 0.352      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0614    |
# |    n_updates            | 370        |
# |    policy_gradient_loss | -0.0662    |
# |    std                  | 0.324      |
# |    value_loss           | 0.419      |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 5          |
# |    ep_rew_mean          | 3.48       |
# | time/                   |            |
# |    fps                  | 7          |
# |    iterations           | 39         |
# |    time_elapsed         | 10909      |
# |    total_timesteps      | 79872      |
# | train/                  |            |
# |    approx_kl            | 0.35786447 |
# |    clip_fraction        | 0.568      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.764     |
# |    explained_variance   | 0.424      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0636    |
# |    n_updates            | 380        |
# |    policy_gradient_loss | -0.0757    |
# |    std                  | 0.312      |
# |    value_loss           | 0.328      |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 5          |
# |    ep_rew_mean          | 3.59       |
# | time/                   |            |
# |    fps                  | 7          |
# |    iterations           | 40         |
# |    time_elapsed         | 11266      |
# |    total_timesteps      | 81920      |
# | train/                  |            |
# |    approx_kl            | 0.30493242 |
# |    clip_fraction        | 0.56       |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.65      |
# |    explained_variance   | 0.464      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0598    |
# |    n_updates            | 390        |
# |    policy_gradient_loss | -0.0728    |
# |    std                  | 0.303      |
# |    value_loss           | 0.344      |
# ----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 5         |
# |    ep_rew_mean          | 3.58      |
# | time/                   |           |
# |    fps                  | 7         |
# |    iterations           | 41        |
# |    time_elapsed         | 11612     |
# |    total_timesteps      | 83968     |
# | train/                  |           |
# |    approx_kl            | 0.3896066 |
# |    clip_fraction        | 0.597     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.556    |
# |    explained_variance   | 0.515     |
# |    learning_rate        | 0.0003    |
# |    loss                 | -0.0241   |
# |    n_updates            | 400       |
# |    policy_gradient_loss | -0.0776   |
# |    std                  | 0.293     |
# |    value_loss           | 0.297     |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 5         |
# |    ep_rew_mean          | 3.67      |
# | time/                   |           |
# |    fps                  | 7         |
# |    iterations           | 42        |
# |    time_elapsed         | 11964     |
# |    total_timesteps      | 86016     |
# | train/                  |           |
# |    approx_kl            | 0.3780841 |
# |    clip_fraction        | 0.571     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.448    |
# |    explained_variance   | 0.517     |
# |    learning_rate        | 0.0003    |
# |    loss                 | -0.000338 |
# |    n_updates            | 410       |
# |    policy_gradient_loss | -0.0727   |
# |    std                  | 0.284     |
# |    value_loss           | 0.296     |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 5         |
# |    ep_rew_mean          | 3.5       |
# | time/                   |           |
# |    fps                  | 7         |
# |    iterations           | 43        |
# |    time_elapsed         | 12315     |
# |    total_timesteps      | 88064     |
# | train/                  |           |
# |    approx_kl            | 0.5021434 |
# |    clip_fraction        | 0.603     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.341    |
# |    explained_variance   | 0.516     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0.00483   |
# |    n_updates            | 420       |
# |    policy_gradient_loss | -0.0726   |
# |    std                  | 0.273     |
# |    value_loss           | 0.306     |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 5         |
# |    ep_rew_mean          | 3.97      |
# | time/                   |           |
# |    fps                  | 7         |
# |    iterations           | 44        |
# |    time_elapsed         | 12675     |
# |    total_timesteps      | 90112     |
# | train/                  |           |
# |    approx_kl            | 0.4749235 |
# |    clip_fraction        | 0.602     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.24     |
# |    explained_variance   | 0.516     |
# |    learning_rate        | 0.0003    |
# |    loss                 | -0.103    |
# |    n_updates            | 430       |
# |    policy_gradient_loss | -0.0763   |
# |    std                  | 0.267     |
# |    value_loss           | 0.304     |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 5         |
# |    ep_rew_mean          | 3.69      |
# | time/                   |           |
# |    fps                  | 7         |
# |    iterations           | 45        |
# |    time_elapsed         | 13037     |
# |    total_timesteps      | 92160     |
# | train/                  |           |
# |    approx_kl            | 0.4880013 |
# |    clip_fraction        | 0.595     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.157    |
# |    explained_variance   | 0.499     |
# |    learning_rate        | 0.0003    |
# |    loss                 | -0.0258   |
# |    n_updates            | 440       |
# |    policy_gradient_loss | -0.0706   |
# |    std                  | 0.259     |
# |    value_loss           | 0.335     |
# ---------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 5          |
# |    ep_rew_mean          | 3.66       |
# | time/                   |            |
# |    fps                  | 7          |
# |    iterations           | 46         |
# |    time_elapsed         | 13386      |
# |    total_timesteps      | 94208      |
# | train/                  |            |
# |    approx_kl            | 0.52197516 |
# |    clip_fraction        | 0.584      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.0671    |
# |    explained_variance   | 0.568      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0197    |
# |    n_updates            | 450        |
# |    policy_gradient_loss | -0.0717    |
# |    std                  | 0.252      |
# |    value_loss           | 0.27       |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 5          |
# |    ep_rew_mean          | 3.86       |
# | time/                   |            |
# |    fps                  | 7          |
# |    iterations           | 47         |
# |    time_elapsed         | 13746      |
# |    total_timesteps      | 96256      |
# | train/                  |            |
# |    approx_kl            | 0.42158318 |
# |    clip_fraction        | 0.589      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | 0.0352     |
# |    explained_variance   | 0.552      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.0505     |
# |    n_updates            | 460        |
# |    policy_gradient_loss | -0.0779    |
# |    std                  | 0.244      |
# |    value_loss           | 0.312      |
# ----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 5         |
# |    ep_rew_mean          | 3.81      |
# | time/                   |           |
# |    fps                  | 6         |
# |    iterations           | 48        |
# |    time_elapsed         | 14103     |
# |    total_timesteps      | 98304     |
# | train/                  |           |
# |    approx_kl            | 0.4777458 |
# |    clip_fraction        | 0.609     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | 0.129     |
# |    explained_variance   | 0.64      |
# |    learning_rate        | 0.0003    |
# |    loss                 | -0.0877   |
# |    n_updates            | 470       |
# |    policy_gradient_loss | -0.0744   |
# |    std                  | 0.238     |
# |    value_loss           | 0.218     |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 5         |
# |    ep_rew_mean          | 4.09      |
# | time/                   |           |
# |    fps                  | 6         |
# |    iterations           | 49        |
# |    time_elapsed         | 14461     |
# |    total_timesteps      | 100352    |
# | train/                  |           |
# |    approx_kl            | 0.6046443 |
# |    clip_fraction        | 0.621     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | 0.218     |
# |    explained_variance   | 0.665     |
# |    learning_rate        | 0.0003    |
# |    loss                 | -0.0488   |
# |    n_updates            | 480       |
# |    policy_gradient_loss | -0.0754   |
# |    std                  | 0.232     |
# |    value_loss           | 0.226     |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 5         |
# |    ep_rew_mean          | 4.06      |
# | time/                   |           |
# |    fps                  | 6         |
# |    iterations           | 50        |
# |    time_elapsed         | 14823     |
# |    total_timesteps      | 102400    |
# | train/                  |           |
# |    approx_kl            | 0.4521813 |
# |    clip_fraction        | 0.595     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | 0.287     |
# |    explained_variance   | 0.701     |
# |    learning_rate        | 0.0003    |
# |    loss                 | -0.119    |
# |    n_updates            | 490       |
# |    policy_gradient_loss | -0.0717   |
# |    std                  | 0.228     |
# |    value_loss           | 0.211     |
# ---------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 5          |
# |    ep_rew_mean          | 4.12       |
# | time/                   |            |
# |    fps                  | 6          |
# |    iterations           | 51         |
# |    time_elapsed         | 15185      |
# |    total_timesteps      | 104448     |
# | train/                  |            |
# |    approx_kl            | 0.48038554 |
# |    clip_fraction        | 0.606      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | 0.364      |
# |    explained_variance   | 0.679      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0394    |
# |    n_updates            | 500        |
# |    policy_gradient_loss | -0.0798    |
# |    std                  | 0.221      |
# |    value_loss           | 0.215      |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 5          |
# |    ep_rew_mean          | 4.09       |
# | time/                   |            |
# |    fps                  | 6          |
# |    iterations           | 52         |
# |    time_elapsed         | 15546      |
# |    total_timesteps      | 106496     |
# | train/                  |            |
# |    approx_kl            | 0.47016633 |
# |    clip_fraction        | 0.619      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | 0.464      |
# |    explained_variance   | 0.675      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0991    |
# |    n_updates            | 510        |
# |    policy_gradient_loss | -0.0785    |
# |    std                  | 0.215      |
# |    value_loss           | 0.209      |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 5          |
# |    ep_rew_mean          | 4.21       |
# | time/                   |            |
# |    fps                  | 6          |
# |    iterations           | 53         |
# |    time_elapsed         | 15901      |
# |    total_timesteps      | 108544     |
# | train/                  |            |
# |    approx_kl            | 0.50635284 |
# |    clip_fraction        | 0.591      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | 0.555      |
# |    explained_variance   | 0.693      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.0221     |
# |    n_updates            | 520        |
# |    policy_gradient_loss | -0.0693    |
# |    std                  | 0.208      |
# |    value_loss           | 0.21       |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 5          |
# |    ep_rew_mean          | 4.24       |
# | time/                   |            |
# |    fps                  | 6          |
# |    iterations           | 54         |
# |    time_elapsed         | 16263      |
# |    total_timesteps      | 110592     |
# | train/                  |            |
# |    approx_kl            | 0.49739537 |
# |    clip_fraction        | 0.608      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | 0.657      |
# |    explained_variance   | 0.678      |
# ...
# |    policy_gradient_loss | -0.00767  |
# |    std                  | 0.0123    |
# |    value_loss           | 0.118     |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 5         |
# |    ep_rew_mean          | 5.01      |
# | time/                   |           |
# |    fps                  | 5         |
# |    iterations           | 716       |
# |    time_elapsed         | 245284    |
# |    total_timesteps      | 1466368   |
# | train/                  |           |
# |    approx_kl            | 1.4994214 |
# |    clip_fraction        | 0.756     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | 9.12      |
# |    explained_variance   | 0.943     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0.122     |
# |    n_updates            | 7150      |
# |    policy_gradient_loss | 0.00129   |
# |    std                  | 0.0122    |
# |    value_loss           | 0.112     |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 5         |
# |    ep_rew_mean          | 4.92      |
# | time/                   |           |
# |    fps                  | 5         |
# |    iterations           | 717       |
# |    time_elapsed         | 245543    |
# |    total_timesteps      | 1468416   |
# | train/                  |           |
# |    approx_kl            | 1.2981681 |
# |    clip_fraction        | 0.776     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | 9.12      |
# |    explained_variance   | 0.927     |
# |    learning_rate        | 0.0003    |
# |    loss                 | -0.0305   |
# |    n_updates            | 7160      |
# |    policy_gradient_loss | 0.00796   |
# |    std                  | 0.0122    |
# |    value_loss           | 0.15      |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 5         |
# |    ep_rew_mean          | 5.04      |
# | time/                   |           |
# |    fps                  | 5         |
# |    iterations           | 718       |
# |    time_elapsed         | 245802    |
# |    total_timesteps      | 1470464   |
# | train/                  |           |
# |    approx_kl            | 1.5638549 |
# |    clip_fraction        | 0.784     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | 9.1       |
# |    explained_variance   | 0.936     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0.00853   |
# |    n_updates            | 7170      |
# |    policy_gradient_loss | 0.0387    |
# |    std                  | 0.0123    |
# |    value_loss           | 0.128     |
# ---------------------------------------
# --------------------------------------
# | rollout/                |          |
# |    ep_len_mean          | 5        |
# |    ep_rew_mean          | 4.96     |
# | time/                   |          |
# |    fps                  | 5        |
# |    iterations           | 719      |
# |    time_elapsed         | 246061   |
# |    total_timesteps      | 1472512  |
# | train/                  |          |
# |    approx_kl            | 2.130948 |
# |    clip_fraction        | 0.767    |
# |    clip_range           | 0.2      |
# |    entropy_loss         | 9.09     |
# |    explained_variance   | 0.946    |
# |    learning_rate        | 0.0003   |
# |    loss                 | 0.0119   |
# |    n_updates            | 7180     |
# |    policy_gradient_loss | 0.00856  |
# |    std                  | 0.0123   |
# |    value_loss           | 0.109    |
# --------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 5         |
# |    ep_rew_mean          | 4.98      |
# | time/                   |           |
# |    fps                  | 5         |
# |    iterations           | 720       |
# |    time_elapsed         | 246320    |
# |    total_timesteps      | 1474560   |
# | train/                  |           |
# |    approx_kl            | 1.5282532 |
# |    clip_fraction        | 0.755     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | 9.09      |
# |    explained_variance   | 0.939     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0.0167    |
# |    n_updates            | 7190      |
# |    policy_gradient_loss | -0.0102   |
# |    std                  | 0.0123    |
# |    value_loss           | 0.123     |
# ---------------------------------------
# --------------------------------------
# | rollout/                |          |
# |    ep_len_mean          | 5        |
# |    ep_rew_mean          | 5.02     |
# | time/                   |          |
# |    fps                  | 5        |
# |    iterations           | 721      |
# |    time_elapsed         | 246579   |
# |    total_timesteps      | 1476608  |
# | train/                  |          |
# |    approx_kl            | 1.539999 |
# |    clip_fraction        | 0.769    |
# |    clip_range           | 0.2      |
# |    entropy_loss         | 9.1      |
# |    explained_variance   | 0.941    |
# |    learning_rate        | 0.0003   |
# |    loss                 | -0.00143 |
# |    n_updates            | 7200     |
# |    policy_gradient_loss | 0.01     |
# |    std                  | 0.0123   |
# |    value_loss           | 0.118    |
# --------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 5         |
# |    ep_rew_mean          | 4.98      |
# | time/                   |           |
# |    fps                  | 5         |
# |    iterations           | 722       |
# |    time_elapsed         | 246837    |
# |    total_timesteps      | 1478656   |
# | train/                  |           |
# |    approx_kl            | 1.6567588 |
# |    clip_fraction        | 0.78      |
# |    clip_range           | 0.2       |
# |    entropy_loss         | 9.09      |
# |    explained_variance   | 0.937     |
# |    learning_rate        | 0.0003    |
# |    loss                 | -0.0147   |
# |    n_updates            | 7210      |
# |    policy_gradient_loss | 0.0237    |
# |    std                  | 0.0123    |
# |    value_loss           | 0.128     |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 5         |
# |    ep_rew_mean          | 5.03      |
# | time/                   |           |
# |    fps                  | 5         |
# |    iterations           | 723       |
# |    time_elapsed         | 247096    |
# |    total_timesteps      | 1480704   |
# | train/                  |           |
# |    approx_kl            | 2.4257689 |
# |    clip_fraction        | 0.772     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | 9.09      |
# |    explained_variance   | 0.936     |
# |    learning_rate        | 0.0003    |
# |    loss                 | -0.022    |
# |    n_updates            | 7220      |
# |    policy_gradient_loss | 0.0038    |
# |    std                  | 0.0124    |
# |    value_loss           | 0.127     |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 5         |
# |    ep_rew_mean          | 4.91      |
# | time/                   |           |
# |    fps                  | 5         |
# |    iterations           | 724       |
# |    time_elapsed         | 247355    |
# |    total_timesteps      | 1482752   |
# | train/                  |           |
# |    approx_kl            | 1.6924982 |
# |    clip_fraction        | 0.774     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | 9.07      |
# |    explained_variance   | 0.947     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0.175     |
# |    n_updates            | 7230      |
# |    policy_gradient_loss | 0.00362   |
# |    std                  | 0.0124    |
# |    value_loss           | 0.106     |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 5         |
# |    ep_rew_mean          | 5.05      |
# | time/                   |           |
# |    fps                  | 5         |
# |    iterations           | 725       |
# |    time_elapsed         | 247613    |
# |    total_timesteps      | 1484800   |
# | train/                  |           |
# |    approx_kl            | 1.6674159 |
# |    clip_fraction        | 0.774     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | 9.08      |
# |    explained_variance   | 0.929     |
# |    learning_rate        | 0.0003    |
# |    loss                 | -0.00968  |
# |    n_updates            | 7240      |
# |    policy_gradient_loss | 0.0135    |
# |    std                  | 0.0124    |
# |    value_loss           | 0.143     |
# ---------------------------------------
# --------------------------------------
# | rollout/                |          |
# |    ep_len_mean          | 5        |
# |    ep_rew_mean          | 5.02     |
# | time/                   |          |
# |    fps                  | 5        |
# |    iterations           | 726      |
# |    time_elapsed         | 247872   |
# |    total_timesteps      | 1486848  |
# | train/                  |          |
# |    approx_kl            | 2.405982 |
# |    clip_fraction        | 0.761    |
# |    clip_range           | 0.2      |
# |    entropy_loss         | 9.08     |
# |    explained_variance   | 0.938    |
# |    learning_rate        | 0.0003   |
# |    loss                 | -0.0369  |
# |    n_updates            | 7250     |
# |    policy_gradient_loss | -0.0116  |
# |    std                  | 0.0123   |
# |    value_loss           | 0.127    |
# --------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 5         |
# |    ep_rew_mean          | 4.99      |
# | time/                   |           |
# |    fps                  | 6         |
# |    iterations           | 727       |
# |    time_elapsed         | 248131    |
# |    total_timesteps      | 1488896   |
# | train/                  |           |
# |    approx_kl            | 1.9452357 |
# |    clip_fraction        | 0.784     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | 9.09      |
# |    explained_variance   | 0.946     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0.108     |
# |    n_updates            | 7260      |
# |    policy_gradient_loss | 0.000858  |
# |    std                  | 0.0124    |
# |    value_loss           | 0.109     |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 5         |
# |    ep_rew_mean          | 4.99      |
# | time/                   |           |
# |    fps                  | 6         |
# |    iterations           | 728       |
# |    time_elapsed         | 248390    |
# |    total_timesteps      | 1490944   |
# | train/                  |           |
# |    approx_kl            | 1.7794974 |
# |    clip_fraction        | 0.786     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | 9.08      |
# |    explained_variance   | 0.941     |
# |    learning_rate        | 0.0003    |
# |    loss                 | -0.0372   |
# |    n_updates            | 7270      |
# |    policy_gradient_loss | 0.00435   |
# |    std                  | 0.0123    |
# |    value_loss           | 0.12      |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 5         |
# |    ep_rew_mean          | 5.04      |
# | time/                   |           |
# |    fps                  | 6         |
# |    iterations           | 729       |
# |    time_elapsed         | 248649    |
# |    total_timesteps      | 1492992   |
# | train/                  |           |
# |    approx_kl            | 1.3631431 |
# |    clip_fraction        | 0.754     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | 9.08      |
# |    explained_variance   | 0.934     |
# |    learning_rate        | 0.0003    |
# |    loss                 | -0.0198   |
# |    n_updates            | 7280      |
# |    policy_gradient_loss | -0.0187   |
# |    std                  | 0.0123    |
# |    value_loss           | 0.133     |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 5         |
# |    ep_rew_mean          | 4.97      |
# | time/                   |           |
# |    fps                  | 6         |
# |    iterations           | 730       |
# |    time_elapsed         | 248909    |
# |    total_timesteps      | 1495040   |
# | train/                  |           |
# |    approx_kl            | 1.9937587 |
# |    clip_fraction        | 0.785     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | 9.08      |
# |    explained_variance   | 0.939     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0.00843   |
# |    n_updates            | 7290      |
# |    policy_gradient_loss | 0.00152   |
# |    std                  | 0.0124    |
# |    value_loss           | 0.123     |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 5         |
# |    ep_rew_mean          | 5.01      |
# | time/                   |           |
# |    fps                  | 6         |
# |    iterations           | 731       |
# |    time_elapsed         | 249169    |
# |    total_timesteps      | 1497088   |
# | train/                  |           |
# |    approx_kl            | 1.9126005 |
# |    clip_fraction        | 0.767     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | 9.09      |
# |    explained_variance   | 0.931     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0.0414    |
# |    n_updates            | 7300      |
# |    policy_gradient_loss | -0.00624  |
# |    std                  | 0.0122    |
# |    value_loss           | 0.138     |
# ---------------------------------------
# --------------------------------------
# | rollout/                |          |
# |    ep_len_mean          | 5        |
# |    ep_rew_mean          | 5.01     |
# | time/                   |          |
# |    fps                  | 6        |
# |    iterations           | 732      |
# |    time_elapsed         | 249428   |
# |    total_timesteps      | 1499136  |
# | train/                  |          |
# |    approx_kl            | 1.550241 |
# |    clip_fraction        | 0.771    |
# |    clip_range           | 0.2      |
# |    entropy_loss         | 9.11     |
# |    explained_variance   | 0.936    |
# |    learning_rate        | 0.0003   |
# |    loss                 | -0.0226  |
# |    n_updates            | 7310     |
# |    policy_gradient_loss | -0.00337 |
# |    std                  | 0.0122   |
# |    value_loss           | 0.127    |
# --------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 5         |
# |    ep_rew_mean          | 4.93      |
# | time/                   |           |
# |    fps                  | 6         |
# |    iterations           | 733       |
# |    time_elapsed         | 249688    |
# |    total_timesteps      | 1501184   |
# | train/                  |           |
# |    approx_kl            | 1.7404417 |
# |    clip_fraction        | 0.805     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | 9.11      |
# |    explained_variance   | 0.941     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0.0608    |
# |    n_updates            | 7320      |
# |    policy_gradient_loss | 0.0388    |
# |    std                  | 0.0122    |
# |    value_loss           | 0.118     |
# ---------------------------------------
# Test action: [-0.14837909  0.53180575  1.        ]

# %%
model.save(os.path.join(log_dir, "ppo_model"))

# %% [markdown]
# Evaluation

# %%
log_dir = "../logs/rl_repressilator_past_amort_multi_step_frame_5_fixed_1/"

# %%
import os
import pandas as pd
import seaborn as sns

from stable_baselines3 import PPO
from stable_baselines3.common.monitor import Monitor

# test environment
env = CustomEnv()

# ==== Configuration ====
model_path = os.path.join(log_dir, "ppo_model")
monitor_file = os.path.join(log_dir, "monitor.csv")

df = pd.read_csv(monitor_file, skiprows=1)  # Skip header comment row

# %%
model = PPO.load(model_path)

# %%
# ==== 3. Plot learning curve ====
plt.figure(figsize=(10, 6))
sns.lineplot(x=[x / 1e3 for x in range(len(df))], y=df["r"], linewidth=2)

plt.xlabel("thousand steps", fontsize=18)
plt.ylabel("reward", fontsize=18)
plt.legend(fontsize=14)
sns.despine()

plt.tight_layout()
# plt.savefig("learning_curve_3.pdf", format="pdf")
plt.show()
# Out:
# C:\Users\micha\AppData\Local\Temp\ipykernel_24624\2659683471.py:7: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend(fontsize=14)

# %%
obs, info = env.reset()  # Reset the environment with a specific frequency

action, _states = model.predict(obs, deterministic=True)
action
print("Action taken:", action)
first_params = np.hstack((env.uncertain, action))



# print("First Reward:",jl.reward_normalized_past_amort(first_params, 1/7))
obs, reward, terminated, truncated, info = env.step(action)
print(terminated)

print("First reward:", reward)
print(obs.shape)

# plt.plot(jl.observation_normalized(np.concatenate((env.uncertain, action))), label="Second Design")
plt.legend()
# Take action in the environment

action, _states = model.predict(obs, deterministic=True)

obs, reward, terminated, truncated, info = env.step(action)

print("Action taken:", action)
print("Second reward:", reward)

plt.plot(obs[0,0:128], label="First Design")
plt.plot(obs[0,132:260], label="Second Design")

action, _states = model.predict(obs, deterministic=True)

plt.plot(jl.observation(env.uncertain, action), label="Third Design")

obs, reward, terminated, truncated, info = env.step(action)

print("Action taken:", action)
print("Third reward:", reward)


print(terminated)
# Out:
# Action taken: [-0.15166496  0.55922437  1.        ]
# False
# First reward: 0.7887989949335531
# (1, 655)
# Action taken: [-0.32153162  1.          1.        ]
# Second reward: 1.2077979817813296
# C:\Users\micha\AppData\Local\Temp\ipykernel_24624\4038937236.py:18: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()
# Action taken: [-0.31267244  1.          1.        ]
# Third reward: 1.206053375474099
# False

# %%
first_rewards = np.zeros(1000)
second_rewards = np.zeros(1000)
third_rewards = np.zeros(1000)
forth_rewards = np.zeros(1000)
fifth_rewards = np.zeros(1000)

env.seed(31415)

for i in range(1000):
    obs, info = env.reset() 
    action, _states = model.predict(obs, deterministic=True)
    obs, reward, terminated, truncated, info = env.step(action)
    first_rewards[i] = (reward + jl.reward_normalized_past_amort(np.hstack((env.uncertain, action)), 1/7) + jl.reward_normalized_past_amort(np.hstack((env.uncertain, action)), 1/7) + jl.reward_normalized_past_amort(np.hstack((env.uncertain, action)), 1/7) + jl.reward_normalized_past_amort(np.hstack((env.uncertain, action)), 1/7))/ 5
    action, _states = model.predict(obs, deterministic=True)
    obs, reward, terminated, truncated, info = env.step(action)
    second_rewards[i] = (reward + jl.reward_normalized_past_amort(np.hstack((env.uncertain, action)), 1/7) + jl.reward_normalized_past_amort(np.hstack((env.uncertain, action)), 1/7) + jl.reward_normalized_past_amort(np.hstack((env.uncertain, action)), 1/7) + jl.reward_normalized_past_amort(np.hstack((env.uncertain, action)), 1/7))/ 5
    action, _states = model.predict(obs, deterministic=True)
    obs, reward, terminated, truncated, info = env.step(action)
    third_rewards[i] = (reward + jl.reward_normalized_past_amort(np.hstack((env.uncertain, action)), 1/7) + jl.reward_normalized_past_amort(np.hstack((env.uncertain, action)), 1/7) + jl.reward_normalized_past_amort(np.hstack((env.uncertain, action)), 1/7) + jl.reward_normalized_past_amort(np.hstack((env.uncertain, action)), 1/7))/ 5
    action, _states = model.predict(obs, deterministic=True)
    obs, reward, terminated, truncated, info = env.step(action)
    forth_rewards[i] = (reward + jl.reward_normalized_past_amort(np.hstack((env.uncertain, action)), 1/7) + jl.reward_normalized_past_amort(np.hstack((env.uncertain, action)), 1/7) + jl.reward_normalized_past_amort(np.hstack((env.uncertain, action)), 1/7) + jl.reward_normalized_past_amort(np.hstack((env.uncertain, action)), 1/7))/ 5
    action, _states = model.predict(obs, deterministic=True)
    obs, reward, terminated, truncated, info = env.step(action)
    fifth_rewards[i] = (reward + jl.reward_normalized_past_amort(np.hstack((env.uncertain, action)), 1/7) + jl.reward_normalized_past_amort(np.hstack((env.uncertain, action)), 1/7) + jl.reward_normalized_past_amort(np.hstack((env.uncertain, action)), 1/7) + jl.reward_normalized_past_amort(np.hstack((env.uncertain, action)), 1/7))/ 5

# %%
plt.figure(figsize=(10, 6))
plt.plot(first_rewards, label='First Reward', alpha=0.7)
plt.plot(second_rewards, label='Second Reward', alpha=0.7)
plt.plot(third_rewards, label='Third Reward', alpha=0.7)
plt.legend()
plt.xlabel("Trial (new uncertain parameters sampled from the prior)", fontsize=18)
plt.ylabel("Reward", fontsize=18)
# Out:
# Text(0, 0.5, 'Reward')

# %%
#plot violins seaborn
import seaborn as sns
plt.figure(figsize=(10, 6))
sns.violinplot(data=[first_rewards, second_rewards, third_rewards, forth_rewards, fifth_rewards], inner="quartile")
plt.xlabel("Design", fontsize=18)
plt.ylabel("Reward", fontsize=18)
# Out:
# Text(0, 0.5, 'Reward')

# %%
# Plot boxplot with seaborn
plt.figure(figsize=(3, 3))
sns.boxplot(data=[first_rewards, second_rewards, third_rewards, forth_rewards, fifth_rewards], showmeans=True, showfliers = True)

# Set x-axis labels starting from 1
plt.xticks(ticks=range(5), labels=["1", "2", "3", "4", "5"])

plt.xlabel("Step", fontsize=12)
plt.ylabel("Reward", fontsize=12)
plt.ylim(-1,1.5)

sns.despine()
plt.tight_layout()
# plt.savefig("boxes_std.pdf", format="pdf")
plt.show()

# %%
import os
import pandas as pd
import seaborn as sns

from stable_baselines3 import PPO
from stable_baselines3.common.monitor import Monitor

# test environment
env = CustomEnv()

# ==== Configuration ====
log_dir = "../logs/rl_repressilator_past_amort_multi_step_frame_5_1235"
model_path = os.path.join(log_dir, "ppo_model")

model = PPO.load(model_path)

first_rewards_adapt = np.zeros(1000)
second_rewards_adapt = np.zeros(1000)
third_rewards_adapt = np.zeros(1000)
forth_rewards_adapt = np.zeros(1000)
fifth_rewards_adapt = np.zeros(1000)

env.seed(31415)

for i in range(1000):
    obs, info = env.reset() 
    action, _states = model.predict(obs, deterministic=True)
    obs, reward, terminated, truncated, info = env.step(action)
    first_rewards_adapt[i] = (reward + jl.reward_normalized_past_amort(np.hstack((env.uncertain, action)), 1/7) + jl.reward_normalized_past_amort(np.hstack((env.uncertain, action)), 1/7) + jl.reward_normalized_past_amort(np.hstack((env.uncertain, action)), 1/7) + jl.reward_normalized_past_amort(np.hstack((env.uncertain, action)), 1/7))/ 5
    action, _states = model.predict(obs, deterministic=True)
    obs, reward, terminated, truncated, info = env.step(action)
    second_rewards_adapt[i] = (reward + jl.reward_normalized_past_amort(np.hstack((env.uncertain, action)), 1/7) + jl.reward_normalized_past_amort(np.hstack((env.uncertain, action)), 1/7) + jl.reward_normalized_past_amort(np.hstack((env.uncertain, action)), 1/7) + jl.reward_normalized_past_amort(np.hstack((env.uncertain, action)), 1/7))/ 5
    action, _states = model.predict(obs, deterministic=True)
    obs, reward, terminated, truncated, info = env.step(action)
    third_rewards_adapt[i] = (reward + jl.reward_normalized_past_amort(np.hstack((env.uncertain, action)), 1/7) + jl.reward_normalized_past_amort(np.hstack((env.uncertain, action)), 1/7) + jl.reward_normalized_past_amort(np.hstack((env.uncertain, action)), 1/7) + jl.reward_normalized_past_amort(np.hstack((env.uncertain, action)), 1/7))/ 5
    action, _states = model.predict(obs, deterministic=True)
    obs, reward, terminated, truncated, info = env.step(action)
    forth_rewards_adapt[i] = (reward + jl.reward_normalized_past_amort(np.hstack((env.uncertain, action)), 1/7) + jl.reward_normalized_past_amort(np.hstack((env.uncertain, action)), 1/7) + jl.reward_normalized_past_amort(np.hstack((env.uncertain, action)), 1/7) + jl.reward_normalized_past_amort(np.hstack((env.uncertain, action)), 1/7))/ 5
    action, _states = model.predict(obs, deterministic=True)
    obs, reward, terminated, truncated, info = env.step(action)
    fifth_rewards_adapt[i] = (reward + jl.reward_normalized_past_amort(np.hstack((env.uncertain, action)), 1/7) + jl.reward_normalized_past_amort(np.hstack((env.uncertain, action)), 1/7) + jl.reward_normalized_past_amort(np.hstack((env.uncertain, action)), 1/7) + jl.reward_normalized_past_amort(np.hstack((env.uncertain, action)), 1/7))/ 5

# %%
# Plot boxplot with seaborn
plt.figure(figsize=(3, 3))
sns.boxplot(data=[first_rewards_adapt, second_rewards_adapt, third_rewards_adapt, forth_rewards_adapt, fifth_rewards_adapt], showmeans=True, showfliers = True)

# Set x-axis labels starting from 1
plt.xticks(ticks=range(5), labels=["1", "2", "3", "4", "5"])

plt.xlabel("Step", fontsize=12)
plt.ylabel("Reward", fontsize=12)
plt.ylim(-1,1.5)
sns.despine()
plt.tight_layout()
# plt.savefig("boxes_std.pdf", format="pdf")
plt.show()
