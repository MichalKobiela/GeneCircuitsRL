# %% [markdown]
# Setup

# %%
# %pip install numpy
# %pip install matplotlib
# %pip install tensorboard
import numpy as np
import matplotlib.pyplot as plt
from juliacall import Main as jl
from juliacall import Pkg as jlPkg
jlPkg.activate("../../.")
jl.include("rl_repressilator_past_amort_setup.jl")
#jlPkg.instantiate() #run the first time using this repo
# Out:
# Requirement already satisfied: numpy in c:\Users\micha\miniconda3\envs\circuitsrl\Lib\site-packages (2.4.2)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: matplotlib in c:\Users\micha\miniconda3\envs\circuitsrl\Lib\site-packages (3.10.8)
# Requirement already satisfied: contourpy>=1.0.1 in c:\Users\micha\miniconda3\envs\circuitsrl\Lib\site-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\Users\micha\miniconda3\envs\circuitsrl\Lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\Users\micha\miniconda3\envs\circuitsrl\Lib\site-packages (from matplotlib) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\Users\micha\miniconda3\envs\circuitsrl\Lib\site-packages (from matplotlib) (1.4.9)
# Requirement already satisfied: numpy>=1.23 in c:\Users\micha\miniconda3\envs\circuitsrl\Lib\site-packages (from matplotlib) (2.4.2)
# Requirement already satisfied: packaging>=20.0 in c:\Users\micha\miniconda3\envs\circuitsrl\Lib\site-packages (from matplotlib) (26.0)
# Requirement already satisfied: pillow>=8 in c:\Users\micha\miniconda3\envs\circuitsrl\Lib\site-packages (from matplotlib) (12.1.0)
# Requirement already satisfied: pyparsing>=3 in c:\Users\micha\miniconda3\envs\circuitsrl\Lib\site-packages (from matplotlib) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\Users\micha\miniconda3\envs\circuitsrl\Lib\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\Users\micha\miniconda3\envs\circuitsrl\Lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: tensorboard in c:\Users\micha\miniconda3\envs\circuitsrl\Lib\site-packages (2.20.0)
# Requirement already satisfied: absl-py>=0.4 in c:\Users\micha\miniconda3\envs\circuitsrl\Lib\site-packages (from tensorboard) (2.4.0)
# Requirement already satisfied: grpcio>=1.48.2 in c:\Users\micha\miniconda3\envs\circuitsrl\Lib\site-packages (from tensorboard) (1.78.0)
# Requirement already satisfied: markdown>=2.6.8 in c:\Users\micha\miniconda3\envs\circuitsrl\Lib\site-packages (from tensorboard) (3.10.2)
# Requirement already satisfied: numpy>=1.12.0 in c:\Users\micha\miniconda3\envs\circuitsrl\Lib\site-packages (from tensorboard) (2.4.2)
# Requirement already satisfied: packaging in c:\Users\micha\miniconda3\envs\circuitsrl\Lib\site-packages (from tensorboard) (26.0)
# Requirement already satisfied: pillow in c:\Users\micha\miniconda3\envs\circuitsrl\Lib\site-packages (from tensorboard) (12.1.0)
# Requirement already satisfied: protobuf!=4.24.0,>=3.19.6 in c:\Users\micha\miniconda3\envs\circuitsrl\Lib\site-packages (from tensorboard) (6.33.5)
# Requirement already satisfied: setuptools>=41.0.0 in c:\Users\micha\miniconda3\envs\circuitsrl\Lib\site-packages (from tensorboard) (82.0.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in c:\Users\micha\miniconda3\envs\circuitsrl\Lib\site-packages (from tensorboard) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\Users\micha\miniconda3\envs\circuitsrl\Lib\site-packages (from tensorboard) (3.1.5)
# Requirement already satisfied: typing-extensions~=4.12 in c:\Users\micha\miniconda3\envs\circuitsrl\Lib\site-packages (from grpcio>=1.48.2->tensorboard) (4.15.0)
# Requirement already satisfied: markupsafe>=2.1.1 in c:\Users\micha\miniconda3\envs\circuitsrl\Lib\site-packages (from werkzeug>=1.0.1->tensorboard) (3.0.3)
# Note: you may need to restart the kernel to use updated packages.
#   Activating project at `c:\Users\micha\GeneCircuitsRL`
# observation (generic function with 2 methods)
# Second peak value: 0.7038096038235359

# %%
import gymnasium as gym
from gymnasium import spaces
import numpy as np
import torch as th
import torch.nn as nn
from stable_baselines3.common.torch_layers import BaseFeaturesExtractor

class Custom1DCNNExtractor(BaseFeaturesExtractor):
    def __init__(self, observation_space, features_dim=128, obs_dim=128, action_dim=3, n_steps=5):
        super(Custom1DCNNExtractor, self).__init__(observation_space, features_dim)

        self.obs_dim = obs_dim
        self.action_dim = action_dim
        self.n_steps = n_steps

        n_input_channels = 1
        seq_len = obs_dim

        # CNN to process each observation chunk
        self.cnn = nn.Sequential(
            nn.Conv1d(n_input_channels, 32, kernel_size=3, stride=1, padding=1),
            nn.ReLU(),
            nn.Conv1d(32, 64, kernel_size=3, stride=1, padding=1),
            nn.ReLU(),
            nn.Flatten()
        )

        # Determine CNN output size
        with th.no_grad():
            sample_obs = th.zeros((1, n_input_channels, seq_len), dtype=th.float32)
            cnn_output_dim = self.cnn(sample_obs).shape[1]

        # Concatenate obs features and raw actions across all steps
        combined_dim = self.n_steps * cnn_output_dim + self.n_steps * action_dim

        self.linear = nn.Sequential(
            nn.Linear(combined_dim, features_dim),
            nn.ReLU()
        )

    def forward(self, observations):
        """
        observations: (batch, 1, obs1 + act1 + ... + obsN + actN)
        """
        obs_feats = []
        act_feats = []

        for i in range(self.n_steps):
            obs_start = i * (self.obs_dim + self.action_dim)
            act_start = obs_start + self.obs_dim
            act_end = act_start + self.action_dim

            obs = observations[:, :, obs_start:act_start]  # (batch, 1, obs_dim)
            act = observations[:, 0, act_start:act_end]    # (batch, action_dim)

            obs_feat = self.cnn(obs)                       # (batch, cnn_output_dim)
            obs_feats.append(obs_feat)
            act_feats.append(act)

        combined = th.cat(obs_feats + act_feats, dim=1)
        return self.linear(combined)


# ======================
#  Environment
# ======================

import random
import torch
from gymnasium.utils import seeding

class CustomEnv(gym.Env):
    metadata = {"render_modes": []}

    def __init__(self, max_episode_steps=5):
        super(CustomEnv, self).__init__()

        self.obs_dim = 128
        self.action_dim = 3          # design params: kX, km, K
        self.uncertain_dim = 4       # H, γX, γm, ϵ
        self.n_steps = max_episode_steps

        self.observation_space = spaces.Box(
            low=-np.inf,
            high=np.inf,
            shape=(1, self.n_steps * (self.obs_dim + self.action_dim)),
            dtype=np.float32
        )

        self.action_space = spaces.Box(
            low=-1,
            high=1,
            shape=(self.action_dim,),
            dtype=np.float32
        )

        self.max_episode_steps = max_episode_steps
        self.current_step = 0
        self.uncertain = np.zeros(self.uncertain_dim, dtype=np.float32)

        self.effective_observation = np.zeros(self.observation_space.shape, dtype=np.float32)
    
    def seed(self, seed=None):
        self._np_random, seed = seeding.np_random(seed)
        np.random.seed(seed)
        random.seed(seed)
        torch.manual_seed(seed)
        jl.seval(f"Random.seed!({seed})")  # sync seed with Julia
        return [seed]
    
    def reset(self, seed=None, options=None):
        if options is not None and 'uncertain' in options:
            self.uncertain = np.array(options['uncertain'], dtype=np.float32)
        else:
            self.uncertain = (np.random.rand(self.uncertain_dim) * 2 - 1).astype(np.float32)

        if seed is not None:
            self.seed(seed)
        
        self.current_step = 0
        self.effective_observation[:] = 0.0

        info = {}
        return self.effective_observation.copy(), info

    def step(self, action):
        params_action = np.concatenate((self.uncertain, action))
        reward = jl.reward_normalized_past_amort(params_action, 1 / 7)
        rew = np.clip(reward, -5, 5)

        obs_vector = jl.observation(self.uncertain, action)
        obs_vector = np.array(obs_vector).reshape(1, -1).astype(np.float32)

        if self.current_step < self.max_episode_steps:
            obs_start = self.current_step * (self.obs_dim + self.action_dim)
            act_start = obs_start + self.obs_dim

            self.effective_observation[:, obs_start:act_start] = obs_vector
            self.effective_observation[:, act_start:act_start + self.action_dim] = action

        self.current_step += 1
        terminated = self.current_step >= self.max_episode_steps
        truncated = False
        info = {}

        return self.effective_observation.copy(), rew, terminated, truncated, info

# %%
from stable_baselines3.common.env_checker import check_env
env = CustomEnv()
check_env(env)
# Out:
# c:\Users\micha\miniconda3\envs\circuitsrl\Lib\site-packages\stable_baselines3\common\env_checker.py:316: UserWarning: Your observation  has an unconventional shape (neither an image, nor a 1D vector). We recommend you to flatten the observation to have only a 1D vector or use a custom policy to properly process the data.
#   warnings.warn(

# %% [markdown]
# Training

# %%
import os
import pandas as pd
import seaborn as sns

from stable_baselines3 import PPO
from stable_baselines3.common.monitor import Monitor

# =============================== #
# ✅ Logging and Monitor
# =============================== #
log_dir = "logs/rl_repressilator_past_amort_multi_step_frame_5/"
os.makedirs(log_dir, exist_ok=True)


SEED = 1234

random.seed(SEED)
np.random.seed(SEED)
torch.manual_seed(SEED)
jl.seval(f"Random.seed!({SEED})")  # your Julia seed
env = CustomEnv()
env.seed(SEED)
env.reset(seed=SEED)
env = Monitor(env, filename=log_dir)

# =============================== #
# ✅ PPO with 1D CNN Feature Extractor
# =============================== #
policy_kwargs = dict(
    features_extractor_class=Custom1DCNNExtractor,
    features_extractor_kwargs=dict(features_dim=128),
)

model = PPO(
    "CnnPolicy", 
    env,
    policy_kwargs=policy_kwargs,
    verbose=1,
    tensorboard_log=log_dir,
    seed=SEED
)
# Out:
# Using cpu device
# Wrapping the env in a DummyVecEnv.

# %%
model.learn(total_timesteps=750000)

# =============================== #
# ✅ Quick test
# =============================== #
obs, info = env.reset()
action, _ = model.predict(obs)
print("Test action:", action)
# Out:
# Logging to logs/rl_repressilator_past_amort_multi_step_frame_5/PPO_2
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 5        |
# |    ep_rew_mean     | -0.355   |
# | time/              |          |
# |    fps             | 18       |
# |    iterations      | 1        |
# |    time_elapsed    | 109      |
# |    total_timesteps | 2048     |
# ---------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 5            |
# |    ep_rew_mean          | -0.314       |
# | time/                   |              |
# |    fps                  | 16           |
# |    iterations           | 2            |
# |    time_elapsed         | 246          |
# |    total_timesteps      | 4096         |
# | train/                  |              |
# |    approx_kl            | 0.0075752935 |
# |    clip_fraction        | 0.132        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.25        |
# |    explained_variance   | -0.00748     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.14         |
# |    n_updates            | 10           |
# |    policy_gradient_loss | -0.00998     |
# |    std                  | 0.995        |
# |    value_loss           | 2.74         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 5           |
# |    ep_rew_mean          | -0.189      |
# | time/                   |             |
# |    fps                  | 16          |
# |    iterations           | 3           |
# |    time_elapsed         | 370         |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.008957533 |
# |    clip_fraction        | 0.125       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.23       |
# |    explained_variance   | -0.0306     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.504       |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.0136     |
# |    std                  | 0.987       |
# |    value_loss           | 2.21        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 5           |
# |    ep_rew_mean          | -0.341      |
# | time/                   |             |
# |    fps                  | 16          |
# |    iterations           | 4           |
# |    time_elapsed         | 502         |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.008703854 |
# |    clip_fraction        | 0.0897      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.22       |
# |    explained_variance   | -0.129      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.42        |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.0126     |
# |    std                  | 0.986       |
# |    value_loss           | 2.86        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 5           |
# |    ep_rew_mean          | -0.357      |
# | time/                   |             |
# |    fps                  | 16          |
# |    iterations           | 5           |
# |    time_elapsed         | 639         |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.016932927 |
# |    clip_fraction        | 0.16        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.18       |
# |    explained_variance   | -0.257      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.651       |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.0258     |
# |    std                  | 0.968       |
# |    value_loss           | 1.88        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 5           |
# |    ep_rew_mean          | 0.248       |
# | time/                   |             |
# |    fps                  | 15          |
# |    iterations           | 6           |
# |    time_elapsed         | 777         |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.020599954 |
# |    clip_fraction        | 0.193       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.15       |
# |    explained_variance   | -0.202      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.822       |
# |    n_updates            | 50          |
# |    policy_gradient_loss | -0.0298     |
# |    std                  | 0.964       |
# |    value_loss           | 2.08        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 5           |
# |    ep_rew_mean          | 0.227       |
# | time/                   |             |
# |    fps                  | 15          |
# |    iterations           | 7           |
# |    time_elapsed         | 927         |
# |    total_timesteps      | 14336       |
# | train/                  |             |
# |    approx_kl            | 0.027814455 |
# |    clip_fraction        | 0.245       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.14       |
# |    explained_variance   | -0.196      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.348       |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.0382     |
# |    std                  | 0.959       |
# |    value_loss           | 1.84        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 5           |
# |    ep_rew_mean          | -0.0271     |
# | time/                   |             |
# |    fps                  | 15          |
# |    iterations           | 8           |
# |    time_elapsed         | 1075        |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.036181025 |
# |    clip_fraction        | 0.282       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.12       |
# |    explained_variance   | -0.241      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.806       |
# |    n_updates            | 70          |
# |    policy_gradient_loss | -0.0433     |
# |    std                  | 0.951       |
# |    value_loss           | 2.09        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 5          |
# |    ep_rew_mean          | 0.571      |
# | time/                   |            |
# |    fps                  | 15         |
# |    iterations           | 9          |
# |    time_elapsed         | 1224       |
# |    total_timesteps      | 18432      |
# | train/                  |            |
# |    approx_kl            | 0.04151298 |
# |    clip_fraction        | 0.285      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -4.08      |
# |    explained_variance   | -0.262     |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.269      |
# |    n_updates            | 80         |
# |    policy_gradient_loss | -0.0454    |
# |    std                  | 0.934      |
# |    value_loss           | 1.8        |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 5          |
# |    ep_rew_mean          | 0.317      |
# | time/                   |            |
# |    fps                  | 14         |
# |    iterations           | 10         |
# |    time_elapsed         | 1374       |
# |    total_timesteps      | 20480      |
# | train/                  |            |
# |    approx_kl            | 0.05293861 |
# |    clip_fraction        | 0.353      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -4.03      |
# |    explained_variance   | -0.3       |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.595      |
# |    n_updates            | 90         |
# |    policy_gradient_loss | -0.0508    |
# |    std                  | 0.917      |
# |    value_loss           | 1.8        |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 5          |
# |    ep_rew_mean          | 0.342      |
# | time/                   |            |
# |    fps                  | 14         |
# |    iterations           | 11         |
# |    time_elapsed         | 1524       |
# |    total_timesteps      | 22528      |
# | train/                  |            |
# |    approx_kl            | 0.05743501 |
# |    clip_fraction        | 0.323      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.97      |
# |    explained_variance   | -0.14      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.382      |
# |    n_updates            | 100        |
# |    policy_gradient_loss | -0.045     |
# |    std                  | 0.903      |
# |    value_loss           | 1.87       |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 5          |
# |    ep_rew_mean          | 0.721      |
# | time/                   |            |
# |    fps                  | 14         |
# |    iterations           | 12         |
# |    time_elapsed         | 1664       |
# |    total_timesteps      | 24576      |
# | train/                  |            |
# |    approx_kl            | 0.06164042 |
# |    clip_fraction        | 0.361      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.93      |
# |    explained_variance   | -0.171     |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.508      |
# |    n_updates            | 110        |
# |    policy_gradient_loss | -0.0535    |
# |    std                  | 0.891      |
# |    value_loss           | 1.73       |
# ----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 5         |
# |    ep_rew_mean          | 0.876     |
# | time/                   |           |
# |    fps                  | 14        |
# |    iterations           | 13        |
# |    time_elapsed         | 1783      |
# |    total_timesteps      | 26624     |
# | train/                  |           |
# |    approx_kl            | 0.0831224 |
# |    clip_fraction        | 0.397     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -3.89     |
# |    explained_variance   | -0.175    |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0.663     |
# |    n_updates            | 120       |
# |    policy_gradient_loss | -0.0472   |
# |    std                  | 0.878     |
# |    value_loss           | 2.04      |
# ---------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 5          |
# |    ep_rew_mean          | 1.01       |
# | time/                   |            |
# |    fps                  | 15         |
# |    iterations           | 14         |
# |    time_elapsed         | 1910       |
# |    total_timesteps      | 28672      |
# | train/                  |            |
# |    approx_kl            | 0.06672877 |
# |    clip_fraction        | 0.396      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.84      |
# |    explained_variance   | -0.256     |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.826      |
# |    n_updates            | 130        |
# |    policy_gradient_loss | -0.0501    |
# |    std                  | 0.861      |
# |    value_loss           | 1.72       |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 5          |
# |    ep_rew_mean          | 0.494      |
# | time/                   |            |
# |    fps                  | 15         |
# |    iterations           | 15         |
# |    time_elapsed         | 2035       |
# |    total_timesteps      | 30720      |
# | train/                  |            |
# |    approx_kl            | 0.08005866 |
# |    clip_fraction        | 0.388      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.77      |
# |    explained_variance   | -0.161     |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.986      |
# |    n_updates            | 140        |
# |    policy_gradient_loss | -0.0441    |
# |    std                  | 0.844      |
# |    value_loss           | 1.84       |
# ----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 5         |
# |    ep_rew_mean          | 0.854     |
# | time/                   |           |
# |    fps                  | 15        |
# |    iterations           | 16        |
# |    time_elapsed         | 2157      |
# |    total_timesteps      | 32768     |
# | train/                  |           |
# |    approx_kl            | 0.0793467 |
# |    clip_fraction        | 0.37      |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -3.73     |
# |    explained_variance   | -0.109    |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0.594     |
# |    n_updates            | 150       |
# |    policy_gradient_loss | -0.0456   |
# |    std                  | 0.833     |
# |    value_loss           | 1.78      |
# ---------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 5          |
# |    ep_rew_mean          | 1.08       |
# | time/                   |            |
# |    fps                  | 15         |
# |    iterations           | 17         |
# |    time_elapsed         | 2278       |
# |    total_timesteps      | 34816      |
# | train/                  |            |
# |    approx_kl            | 0.13885953 |
# |    clip_fraction        | 0.399      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.68      |
# |    explained_variance   | -0.0814    |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.313      |
# |    n_updates            | 160        |
# |    policy_gradient_loss | -0.0476    |
# |    std                  | 0.818      |
# |    value_loss           | 1.75       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 5           |
# |    ep_rew_mean          | 1.27        |
# | time/                   |             |
# |    fps                  | 15          |
# |    iterations           | 18          |
# |    time_elapsed         | 2395        |
# |    total_timesteps      | 36864       |
# | train/                  |             |
# |    approx_kl            | 0.085641444 |
# |    clip_fraction        | 0.403       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.63       |
# |    explained_variance   | -0.102      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.602       |
# |    n_updates            | 170         |
# |    policy_gradient_loss | -0.0458     |
# |    std                  | 0.806       |
# |    value_loss           | 1.95        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 5           |
# |    ep_rew_mean          | 1.16        |
# | time/                   |             |
# |    fps                  | 15          |
# |    iterations           | 19          |
# |    time_elapsed         | 2513        |
# |    total_timesteps      | 38912       |
# | train/                  |             |
# |    approx_kl            | 0.085405156 |
# |    clip_fraction        | 0.407       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.59       |
# |    explained_variance   | -0.0932     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.475       |
# |    n_updates            | 180         |
# |    policy_gradient_loss | -0.0458     |
# |    std                  | 0.794       |
# |    value_loss           | 1.41        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 5           |
# |    ep_rew_mean          | 1.39        |
# | time/                   |             |
# |    fps                  | 15          |
# |    iterations           | 20          |
# |    time_elapsed         | 2637        |
# |    total_timesteps      | 40960       |
# | train/                  |             |
# |    approx_kl            | 0.091077715 |
# |    clip_fraction        | 0.397       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.53       |
# |    explained_variance   | -0.0799     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.294       |
# |    n_updates            | 190         |
# |    policy_gradient_loss | -0.0414     |
# |    std                  | 0.776       |
# |    value_loss           | 1.8         |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 5          |
# |    ep_rew_mean          | 1.25       |
# | time/                   |            |
# |    fps                  | 15         |
# |    iterations           | 21         |
# |    time_elapsed         | 2760       |
# |    total_timesteps      | 43008      |
# | train/                  |            |
# |    approx_kl            | 0.11758745 |
# |    clip_fraction        | 0.428      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.44      |
# |    explained_variance   | 0.0038     |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.653      |
# |    n_updates            | 200        |
# |    policy_gradient_loss | -0.0466    |
# |    std                  | 0.751      |
# |    value_loss           | 1.67       |
# ----------------------------------------
# --------------------------------------
# | rollout/                |          |
# |    ep_len_mean          | 5        |
# |    ep_rew_mean          | 1.38     |
# | time/                   |          |
# |    fps                  | 15       |
# |    iterations           | 22       |
# |    time_elapsed         | 2886     |
# |    total_timesteps      | 45056    |
# | train/                  |          |
# |    approx_kl            | 0.134908 |
# |    clip_fraction        | 0.427    |
# |    clip_range           | 0.2      |
# |    entropy_loss         | -3.37    |
# |    explained_variance   | -0.00683 |
# |    learning_rate        | 0.0003   |
# |    loss                 | 0.314    |
# |    n_updates            | 210      |
# |    policy_gradient_loss | -0.0432  |
# |    std                  | 0.735    |
# |    value_loss           | 1.77     |
# --------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 5          |
# |    ep_rew_mean          | 1.57       |
# | time/                   |            |
# |    fps                  | 15         |
# |    iterations           | 23         |
# |    time_elapsed         | 3005       |
# |    total_timesteps      | 47104      |
# | train/                  |            |
# |    approx_kl            | 0.12634209 |
# |    clip_fraction        | 0.395      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.3       |
# |    explained_variance   | -0.0535    |
# |    learning_rate        | 0.0003     |
# |    loss                 | 1.17       |
# |    n_updates            | 220        |
# |    policy_gradient_loss | -0.0469    |
# |    std                  | 0.72       |
# |    value_loss           | 1.59       |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 5          |
# |    ep_rew_mean          | 2.07       |
# | time/                   |            |
# |    fps                  | 15         |
# |    iterations           | 24         |
# |    time_elapsed         | 3131       |
# |    total_timesteps      | 49152      |
# | train/                  |            |
# |    approx_kl            | 0.11873105 |
# |    clip_fraction        | 0.405      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.23      |
# |    explained_variance   | -0.029     |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.516      |
# |    n_updates            | 230        |
# |    policy_gradient_loss | -0.0487    |
# |    std                  | 0.705      |
# |    value_loss           | 1.55       |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 5          |
# |    ep_rew_mean          | 1.93       |
# | time/                   |            |
# |    fps                  | 15         |
# |    iterations           | 25         |
# |    time_elapsed         | 3255       |
# |    total_timesteps      | 51200      |
# | train/                  |            |
# |    approx_kl            | 0.14908397 |
# |    clip_fraction        | 0.448      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.17      |
# |    explained_variance   | 0.0425     |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.176      |
# |    n_updates            | 240        |
# |    policy_gradient_loss | -0.0493    |
# |    std                  | 0.686      |
# |    value_loss           | 1.54       |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 5          |
# |    ep_rew_mean          | 1.5        |
# | time/                   |            |
# |    fps                  | 15         |
# |    iterations           | 26         |
# |    time_elapsed         | 3379       |
# |    total_timesteps      | 53248      |
# | train/                  |            |
# |    approx_kl            | 0.15802711 |
# |    clip_fraction        | 0.48       |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.1       |
# |    explained_variance   | 0.0222     |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.501      |
# |    n_updates            | 250        |
# |    policy_gradient_loss | -0.043     |
# |    std                  | 0.675      |
# |    value_loss           | 1.67       |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 5          |
# |    ep_rew_mean          | 1.81       |
# | time/                   |            |
# |    fps                  | 15         |
# |    iterations           | 27         |
# |    time_elapsed         | 3501       |
# |    total_timesteps      | 55296      |
# | train/                  |            |
# |    approx_kl            | 0.12645464 |
# |    clip_fraction        | 0.443      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.04      |
# |    explained_variance   | 0.00376    |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.439      |
# |    n_updates            | 260        |
# |    policy_gradient_loss | -0.0496    |
# |    std                  | 0.66       |
# |    value_loss           | 1.68       |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 5          |
# |    ep_rew_mean          | 2.05       |
# | time/                   |            |
# |    fps                  | 15         |
# |    iterations           | 28         |
# |    time_elapsed         | 3629       |
# |    total_timesteps      | 57344      |
# | train/                  |            |
# |    approx_kl            | 0.15054227 |
# |    clip_fraction        | 0.452      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -2.98      |
# |    explained_variance   | -0.0164    |
# |    learning_rate        | 0.0003     |
# |    loss                 | 1.22       |
# |    n_updates            | 270        |
# |    policy_gradient_loss | -0.048     |
# |    std                  | 0.645      |
# |    value_loss           | 1.63       |
# ----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 5         |
# |    ep_rew_mean          | 2.04      |
# | time/                   |           |
# |    fps                  | 15        |
# |    iterations           | 29        |
# |    time_elapsed         | 3755      |
# |    total_timesteps      | 59392     |
# | train/                  |           |
# |    approx_kl            | 0.1823406 |
# |    clip_fraction        | 0.457     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -2.92     |
# |    explained_variance   | 0.0355    |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0.261     |
# |    n_updates            | 280       |
# |    policy_gradient_loss | -0.0465   |
# |    std                  | 0.636     |
# |    value_loss           | 1.63      |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 5         |
# |    ep_rew_mean          | 2.23      |
# | time/                   |           |
# |    fps                  | 15        |
# |    iterations           | 30        |
# |    time_elapsed         | 3878      |
# |    total_timesteps      | 61440     |
# | train/                  |           |
# |    approx_kl            | 0.1550093 |
# |    clip_fraction        | 0.451     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -2.86     |
# |    explained_variance   | 0.0821    |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0.91      |
# |    n_updates            | 290       |
# |    policy_gradient_loss | -0.0502   |
# |    std                  | 0.62      |
# |    value_loss           | 1.38      |
# ---------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 5          |
# |    ep_rew_mean          | 1.72       |
# | time/                   |            |
# |    fps                  | 15         |
# |    iterations           | 31         |
# |    time_elapsed         | 4003       |
# |    total_timesteps      | 63488      |
# | train/                  |            |
# |    approx_kl            | 0.19393894 |
# |    clip_fraction        | 0.471      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -2.8       |
# |    explained_variance   | 0.065      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.296      |
# |    n_updates            | 300        |
# |    policy_gradient_loss | -0.0476    |
# |    std                  | 0.612      |
# |    value_loss           | 1.46       |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 5          |
# |    ep_rew_mean          | 1.93       |
# | time/                   |            |
# |    fps                  | 15         |
# |    iterations           | 32         |
# |    time_elapsed         | 4130       |
# |    total_timesteps      | 65536      |
# | train/                  |            |
# |    approx_kl            | 0.18576124 |
# |    clip_fraction        | 0.461      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -2.73      |
# |    explained_variance   | 0.07       |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.877      |
# |    n_updates            | 310        |
# |    policy_gradient_loss | -0.0482    |
# |    std                  | 0.594      |
# |    value_loss           | 1.78       |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 5          |
# |    ep_rew_mean          | 1.93       |
# | time/                   |            |
# |    fps                  | 15         |
# |    iterations           | 33         |
# |    time_elapsed         | 4258       |
# |    total_timesteps      | 67584      |
# | train/                  |            |
# |    approx_kl            | 0.24087104 |
# |    clip_fraction        | 0.489      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -2.65      |
# |    explained_variance   | 0.0443     |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.366      |
# |    n_updates            | 320        |
# |    policy_gradient_loss | -0.0426    |
# |    std                  | 0.58       |
# |    value_loss           | 1.79       |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 5          |
# |    ep_rew_mean          | 2.53       |
# | time/                   |            |
# |    fps                  | 15         |
# |    iterations           | 34         |
# |    time_elapsed         | 4381       |
# |    total_timesteps      | 69632      |
# | train/                  |            |
# |    approx_kl            | 0.22988176 |
# |    clip_fraction        | 0.494      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -2.59      |
# |    explained_variance   | 0.111      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 1.1        |
# |    n_updates            | 330        |
# |    policy_gradient_loss | -0.044     |
# |    std                  | 0.569      |
# |    value_loss           | 1.58       |
# ----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 5         |
# |    ep_rew_mean          | 2.68      |
# | time/                   |           |
# |    fps                  | 15        |
# |    iterations           | 35        |
# |    time_elapsed         | 4506      |
# |    total_timesteps      | 71680     |
# | train/                  |           |
# |    approx_kl            | 0.1924699 |
# |    clip_fraction        | 0.481     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -2.51     |
# |    explained_variance   | 0.0526    |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0.338     |
# |    n_updates            | 340       |
# |    policy_gradient_loss | -0.0457   |
# |    std                  | 0.551     |
# |    value_loss           | 1.43      |
# ---------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 5          |
# |    ep_rew_mean          | 2.29       |
# | time/                   |            |
# |    fps                  | 15         |
# |    iterations           | 36         |
# |    time_elapsed         | 4632       |
# |    total_timesteps      | 73728      |
# | train/                  |            |
# |    approx_kl            | 0.22035615 |
# |    clip_fraction        | 0.485      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -2.45      |
# |    explained_variance   | 0.155      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.222      |
# |    n_updates            | 350        |
# |    policy_gradient_loss | -0.042     |
# |    std                  | 0.546      |
# |    value_loss           | 1.48       |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 5          |
# |    ep_rew_mean          | 2.93       |
# | time/                   |            |
# |    fps                  | 15         |
# |    iterations           | 37         |
# |    time_elapsed         | 4757       |
# |    total_timesteps      | 75776      |
# | train/                  |            |
# |    approx_kl            | 0.22109684 |
# |    clip_fraction        | 0.486      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -2.4       |
# |    explained_variance   | 0.0951     |
# |    learning_rate        | 0.0003     |
# |    loss                 | 1.6        |
# |    n_updates            | 360        |
# |    policy_gradient_loss | -0.0412    |
# |    std                  | 0.532      |
# |    value_loss           | 1.87       |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 5          |
# |    ep_rew_mean          | 2.71       |
# | time/                   |            |
# |    fps                  | 15         |
# |    iterations           | 38         |
# |    time_elapsed         | 4879       |
# |    total_timesteps      | 77824      |
# | train/                  |            |
# |    approx_kl            | 0.23268294 |
# |    clip_fraction        | 0.467      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -2.32      |
# |    explained_variance   | 0.107      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 1.19       |
# |    n_updates            | 370        |
# |    policy_gradient_loss | -0.0484    |
# |    std                  | 0.517      |
# |    value_loss           | 1.62       |
# ----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 5         |
# |    ep_rew_mean          | 2.32      |
# | time/                   |           |
# |    fps                  | 15        |
# |    iterations           | 39        |
# |    time_elapsed         | 5004      |
# |    total_timesteps      | 79872     |
# | train/                  |           |
# |    approx_kl            | 0.2939763 |
# |    clip_fraction        | 0.489     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -2.25     |
# |    explained_variance   | 0.132     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0.579     |
# |    n_updates            | 380       |
# |    policy_gradient_loss | -0.0454   |
# |    std                  | 0.507     |
# |    value_loss           | 1.46      |
# ---------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 5          |
# |    ep_rew_mean          | 2.16       |
# | time/                   |            |
# |    fps                  | 15         |
# |    iterations           | 40         |
# |    time_elapsed         | 5130       |
# |    total_timesteps      | 81920      |
# | train/                  |            |
# |    approx_kl            | 0.23777395 |
# |    clip_fraction        | 0.538      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -2.19      |
# |    explained_variance   | 0.11       |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.214      |
# |    n_updates            | 390        |
# |    policy_gradient_loss | -0.0464    |
# |    std                  | 0.498      |
# |    value_loss           | 1.74       |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 5          |
# |    ep_rew_mean          | 2.1        |
# | time/                   |            |
# |    fps                  | 15         |
# |    iterations           | 41         |
# |    time_elapsed         | 5255       |
# |    total_timesteps      | 83968      |
# | train/                  |            |
# |    approx_kl            | 0.23751134 |
# |    clip_fraction        | 0.48       |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -2.14      |
# |    explained_variance   | 0.182      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.34       |
# |    n_updates            | 400        |
# |    policy_gradient_loss | -0.0502    |
# |    std                  | 0.488      |
# |    value_loss           | 1.85       |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 5          |
# |    ep_rew_mean          | 2.17       |
# | time/                   |            |
# |    fps                  | 15         |
# |    iterations           | 42         |
# |    time_elapsed         | 5377       |
# |    total_timesteps      | 86016      |
# | train/                  |            |
# |    approx_kl            | 0.20318183 |
# |    clip_fraction        | 0.515      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -2.08      |
# |    explained_variance   | 0.181      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.397      |
# |    n_updates            | 410        |
# |    policy_gradient_loss | -0.0465    |
# |    std                  | 0.48       |
# |    value_loss           | 1.77       |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 5          |
# |    ep_rew_mean          | 2.25       |
# | time/                   |            |
# |    fps                  | 16         |
# |    iterations           | 43         |
# |    time_elapsed         | 5499       |
# |    total_timesteps      | 88064      |
# | train/                  |            |
# |    approx_kl            | 0.29345128 |
# |    clip_fraction        | 0.502      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -2.02      |
# |    explained_variance   | 0.189      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.807      |
# |    n_updates            | 420        |
# |    policy_gradient_loss | -0.0484    |
# |    std                  | 0.468      |
# |    value_loss           | 1.68       |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 5          |
# |    ep_rew_mean          | 2.39       |
# | time/                   |            |
# |    fps                  | 16         |
# |    iterations           | 44         |
# |    time_elapsed         | 5624       |
# |    total_timesteps      | 90112      |
# | train/                  |            |
# |    approx_kl            | 0.25477278 |
# |    clip_fraction        | 0.509      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.95      |
# |    explained_variance   | 0.159      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.186      |
# |    n_updates            | 430        |
# |    policy_gradient_loss | -0.0415    |
# |    std                  | 0.459      |
# |    value_loss           | 1.56       |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 5          |
# |    ep_rew_mean          | 3.04       |
# | time/                   |            |
# |    fps                  | 16         |
# |    iterations           | 45         |
# |    time_elapsed         | 5747       |
# |    total_timesteps      | 92160      |
# | train/                  |            |
# |    approx_kl            | 0.30446938 |
# |    clip_fraction        | 0.537      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.88      |
# |    explained_variance   | 0.234      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 1.36       |
# |    n_updates            | 440        |
# |    policy_gradient_loss | -0.0461    |
# |    std                  | 0.449      |
# |    value_loss           | 1.65       |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 5          |
# |    ep_rew_mean          | 2.25       |
# | time/                   |            |
# |    fps                  | 16         |
# |    iterations           | 46         |
# |    time_elapsed         | 5872       |
# |    total_timesteps      | 94208      |
# | train/                  |            |
# |    approx_kl            | 0.22201781 |
# |    clip_fraction        | 0.522      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.84      |
# |    explained_variance   | 0.189      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.735      |
# |    n_updates            | 450        |
# |    policy_gradient_loss | -0.0427    |
# |    std                  | 0.446      |
# |    value_loss           | 1.36       |
# ----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 5         |
# |    ep_rew_mean          | 2.27      |
# | time/                   |           |
# |    fps                  | 16        |
# |    iterations           | 47        |
# |    time_elapsed         | 5998      |
# |    total_timesteps      | 96256     |
# | train/                  |           |
# |    approx_kl            | 0.2569112 |
# |    clip_fraction        | 0.497     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -1.81     |
# |    explained_variance   | 0.248     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 2.3       |
# |    n_updates            | 460       |
# |    policy_gradient_loss | -0.0406   |
# |    std                  | 0.439     |
# |    value_loss           | 1.58      |
# ---------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 5          |
# |    ep_rew_mean          | 3.02       |
# | time/                   |            |
# |    fps                  | 16         |
# |    iterations           | 48         |
# |    time_elapsed         | 6121       |
# |    total_timesteps      | 98304      |
# | train/                  |            |
# |    approx_kl            | 0.23974071 |
# |    clip_fraction        | 0.521      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.77      |
# |    explained_variance   | 0.206      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.381      |
# |    n_updates            | 470        |
# |    policy_gradient_loss | -0.0416    |
# |    std                  | 0.434      |
# |    value_loss           | 1.52       |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 5          |
# |    ep_rew_mean          | 1.87       |
# | time/                   |            |
# |    fps                  | 16         |
# |    iterations           | 49         |
# |    time_elapsed         | 6243       |
# |    total_timesteps      | 100352     |
# | train/                  |            |
# |    approx_kl            | 0.25008136 |
# |    clip_fraction        | 0.525      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.75      |
# |    explained_variance   | 0.247      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.946      |
# |    n_updates            | 480        |
# |    policy_gradient_loss | -0.0428    |
# |    std                  | 0.431      |
# |    value_loss           | 1.75       |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 5          |
# |    ep_rew_mean          | 2.48       |
# | time/                   |            |
# |    fps                  | 16         |
# |    iterations           | 50         |
# |    time_elapsed         | 6366       |
# |    total_timesteps      | 102400     |
# | train/                  |            |
# |    approx_kl            | 0.47923318 |
# |    clip_fraction        | 0.52       |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.72      |
# |    explained_variance   | 0.193      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.734      |
# |    n_updates            | 490        |
# |    policy_gradient_loss | -0.0411    |
# |    std                  | 0.428      |
# |    value_loss           | 1.67       |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 5          |
# |    ep_rew_mean          | 2.68       |
# | time/                   |            |
# |    fps                  | 16         |
# |    iterations           | 51         |
# |    time_elapsed         | 6491       |
# |    total_timesteps      | 104448     |
# | train/                  |            |
# |    approx_kl            | 0.29162493 |
# |    clip_fraction        | 0.524      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.69      |
# |    explained_variance   | 0.208      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.559      |
# |    n_updates            | 500        |
# |    policy_gradient_loss | -0.0427    |
# |    std                  | 0.423      |
# |    value_loss           | 1.52       |
# ----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 5         |
# |    ep_rew_mean          | 3.24      |
# | time/                   |           |
# |    fps                  | 16        |
# |    iterations           | 52        |
# |    time_elapsed         | 6616      |
# |    total_timesteps      | 106496    |
# | train/                  |           |
# |    approx_kl            | 0.2591174 |
# |    clip_fraction        | 0.528     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -1.66     |
# |    explained_variance   | 0.242     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0.174     |
# |    n_updates            | 510       |
# |    policy_gradient_loss | -0.0404   |
# |    std                  | 0.418     |
# |    value_loss           | 1.57      |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 5         |
# |    ep_rew_mean          | 2.68      |
# | time/                   |           |
# |    fps                  | 16        |
# |    iterations           | 53        |
# |    time_elapsed         | 6738      |
# |    total_timesteps      | 108544    |
# | train/                  |           |
# |    approx_kl            | 0.2706412 |
# |    clip_fraction        | 0.556     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -1.61     |
# |    explained_variance   | 0.222     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 3.08      |
# |    n_updates            | 520       |
# |    policy_gradient_loss | -0.0514   |
# |    std                  | 0.411     |
# |    value_loss           | 1.27      |
# ---------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 5          |
# |    ep_rew_mean          | 2.46       |
# | time/                   |            |
# |    fps                  | 16         |
# |    iterations           | 54         |
# |    time_elapsed         | 6865       |
# |    total_timesteps      | 110592     |
# | train/                  |            |
# |    approx_kl            | 0.21466607 |
# |    clip_fraction        | 0.515      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.56      |
# |    explained_variance   | 0.213      |
# |    learning_rate        | 0.0003     |
# ...
# | rollout/                |            |
# |    ep_len_mean          | 5          |
# |    ep_rew_mean          | 3.03       |
# | time/                   |            |
# |    fps                  | 16         |
# |    iterations           | 59         |
# |    time_elapsed         | 7498       |
# |    total_timesteps      | 120832     |
# | train/                  |            |
# |    approx_kl            | 0.30162615 |
# |    clip_fraction        | 0.574      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.36      |
# |    explained_variance   | 0.216      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.531      |
# |    n_updates            | 580        |
# |    policy_gradient_loss | -0.0396    |
# |    std                  | 0.379      |
# |    value_loss           | 1.26       |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 5          |
# |    ep_rew_mean          | 2.83       |
# | time/                   |            |
# |    fps                  | 16         |
# |    iterations           | 60         |
# |    time_elapsed         | 7625       |
# |    total_timesteps      | 122880     |
# | train/                  |            |
# |    approx_kl            | 0.34686738 |
# |    clip_fraction        | 0.543      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.31      |
# |    explained_variance   | 0.263      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.149      |
# |    n_updates            | 590        |
# |    policy_gradient_loss | -0.0422    |
# |    std                  | 0.37       |
# |    value_loss           | 1.64       |
# ----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 5         |
# |    ep_rew_mean          | 3.11      |
# | time/                   |           |
# |    fps                  | 16        |
# |    iterations           | 61        |
# |    time_elapsed         | 7750      |
# |    total_timesteps      | 124928    |
# | train/                  |           |
# |    approx_kl            | 0.3674723 |
# |    clip_fraction        | 0.549     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -1.26     |
# |    explained_variance   | 0.241     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0.381     |
# |    n_updates            | 600       |
# |    policy_gradient_loss | -0.0443   |
# |    std                  | 0.365     |
# |    value_loss           | 1.45      |
# ---------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 5          |
# |    ep_rew_mean          | 2.71       |
# | time/                   |            |
# |    fps                  | 16         |
# |    iterations           | 62         |
# |    time_elapsed         | 7876       |
# |    total_timesteps      | 126976     |
# | train/                  |            |
# |    approx_kl            | 0.27445996 |
# |    clip_fraction        | 0.546      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.23      |
# |    explained_variance   | 0.28       |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.138      |
# |    n_updates            | 610        |
# |    policy_gradient_loss | -0.028     |
# |    std                  | 0.365      |
# |    value_loss           | 1.34       |
# ----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 5         |
# |    ep_rew_mean          | 2.59      |
# | time/                   |           |
# |    fps                  | 16        |
# |    iterations           | 63        |
# |    time_elapsed         | 7997      |
# |    total_timesteps      | 129024    |
# | train/                  |           |
# |    approx_kl            | 0.2768169 |
# |    clip_fraction        | 0.542     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -1.23     |
# |    explained_variance   | 0.258     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0.598     |
# |    n_updates            | 620       |
# |    policy_gradient_loss | -0.0455   |
# |    std                  | 0.363     |
# |    value_loss           | 1.46      |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 5         |
# |    ep_rew_mean          | 2.85      |
# | time/                   |           |
# |    fps                  | 16        |
# |    iterations           | 64        |
# |    time_elapsed         | 8113      |
# |    total_timesteps      | 131072    |
# | train/                  |           |
# |    approx_kl            | 0.3801015 |
# |    clip_fraction        | 0.558     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -1.2      |
# |    explained_variance   | 0.244     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0.661     |
# |    n_updates            | 630       |
# |    policy_gradient_loss | -0.0495   |
# |    std                  | 0.358     |
# |    value_loss           | 1.37      |
# ---------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 5          |
# |    ep_rew_mean          | 2.5        |
# | time/                   |            |
# |    fps                  | 16         |
# |    iterations           | 65         |
# |    time_elapsed         | 8228       |
# |    total_timesteps      | 133120     |
# | train/                  |            |
# |    approx_kl            | 0.30657572 |
# |    clip_fraction        | 0.559      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.16      |
# |    explained_variance   | 0.232      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.28       |
# |    n_updates            | 640        |
# |    policy_gradient_loss | -0.0518    |
# |    std                  | 0.355      |
# |    value_loss           | 1.52       |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 5          |
# |    ep_rew_mean          | 2.3        |
# | time/                   |            |
# |    fps                  | 16         |
# |    iterations           | 66         |
# |    time_elapsed         | 8345       |
# |    total_timesteps      | 135168     |
# | train/                  |            |
# |    approx_kl            | 0.32415232 |
# |    clip_fraction        | 0.566      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.13      |
# |    explained_variance   | 0.19       |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.0589     |
# |    n_updates            | 650        |
# |    policy_gradient_loss | -0.0434    |
# |    std                  | 0.35       |
# |    value_loss           | 1.49       |
# ----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 5         |
# |    ep_rew_mean          | 2.94      |
# | time/                   |           |
# |    fps                  | 16        |
# |    iterations           | 67        |
# |    time_elapsed         | 8460      |
# |    total_timesteps      | 137216    |
# | train/                  |           |
# |    approx_kl            | 0.3153084 |
# |    clip_fraction        | 0.549     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -1.1      |
# |    explained_variance   | 0.286     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0.243     |
# |    n_updates            | 660       |
# |    policy_gradient_loss | -0.0501   |
# |    std                  | 0.347     |
# |    value_loss           | 1.79      |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 5         |
# |    ep_rew_mean          | 2.73      |
# | time/                   |           |
# |    fps                  | 16        |
# |    iterations           | 68        |
# |    time_elapsed         | 8576      |
# |    total_timesteps      | 139264    |
# | train/                  |           |
# |    approx_kl            | 0.3850547 |
# |    clip_fraction        | 0.574     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -1.04     |
# |    explained_variance   | 0.26      |
# |    learning_rate        | 0.0003    |
# |    loss                 | 1.59      |
# |    n_updates            | 670       |
# |    policy_gradient_loss | -0.054    |
# |    std                  | 0.339     |
# |    value_loss           | 1.34      |
# ---------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 5          |
# |    ep_rew_mean          | 2.83       |
# | time/                   |            |
# |    fps                  | 16         |
# |    iterations           | 69         |
# |    time_elapsed         | 8701       |
# |    total_timesteps      | 141312     |
# | train/                  |            |
# |    approx_kl            | 0.32391152 |
# |    clip_fraction        | 0.552      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.987     |
# |    explained_variance   | 0.261      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.554      |
# |    n_updates            | 680        |
# |    policy_gradient_loss | -0.0515    |
# |    std                  | 0.334      |
# |    value_loss           | 1.44       |
# ----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 5         |
# |    ep_rew_mean          | 2.48      |
# | time/                   |           |
# |    fps                  | 16        |
# |    iterations           | 70        |
# |    time_elapsed         | 8824      |
# |    total_timesteps      | 143360    |
# | train/                  |           |
# |    approx_kl            | 0.3671322 |
# |    clip_fraction        | 0.565     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.937    |
# |    explained_variance   | 0.272     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0.762     |
# |    n_updates            | 690       |
# |    policy_gradient_loss | -0.0495   |
# |    std                  | 0.327     |
# |    value_loss           | 1.36      |
# ---------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 5          |
# |    ep_rew_mean          | 2.85       |
# | time/                   |            |
# |    fps                  | 16         |
# |    iterations           | 71         |
# |    time_elapsed         | 8945       |
# |    total_timesteps      | 145408     |
# | train/                  |            |
# |    approx_kl            | 0.39506036 |
# |    clip_fraction        | 0.553      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.889     |
# |    explained_variance   | 0.283      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.528      |
# |    n_updates            | 700        |
# |    policy_gradient_loss | -0.0474    |
# |    std                  | 0.323      |
# |    value_loss           | 1.42       |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 5          |
# |    ep_rew_mean          | 3.19       |
# | time/                   |            |
# |    fps                  | 16         |
# |    iterations           | 72         |
# |    time_elapsed         | 9066       |
# |    total_timesteps      | 147456     |
# | train/                  |            |
# |    approx_kl            | 0.40702277 |
# |    clip_fraction        | 0.587      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.842     |
# |    explained_variance   | 0.295      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.114      |
# |    n_updates            | 710        |
# |    policy_gradient_loss | -0.0593    |
# |    std                  | 0.317      |
# |    value_loss           | 1.07       |
# ----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 5         |
# |    ep_rew_mean          | 2.83      |
# | time/                   |           |
# |    fps                  | 16        |
# |    iterations           | 73        |
# |    time_elapsed         | 9188      |
# |    total_timesteps      | 149504    |
# | train/                  |           |
# |    approx_kl            | 0.4288272 |
# |    clip_fraction        | 0.584     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.793    |
# |    explained_variance   | 0.387     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0.659     |
# |    n_updates            | 720       |
# |    policy_gradient_loss | -0.0567   |
# |    std                  | 0.313     |
# |    value_loss           | 0.948     |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 5         |
# |    ep_rew_mean          | 3         |
# | time/                   |           |
# |    fps                  | 16        |
# |    iterations           | 74        |
# |    time_elapsed         | 9310      |
# |    total_timesteps      | 151552    |
# | train/                  |           |
# |    approx_kl            | 0.3750285 |
# |    clip_fraction        | 0.589     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.743    |
# |    explained_variance   | 0.289     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0.0237    |
# |    n_updates            | 730       |
# |    policy_gradient_loss | -0.0539   |
# |    std                  | 0.307     |
# |    value_loss           | 1.26      |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 5         |
# |    ep_rew_mean          | 2.82      |
# | time/                   |           |
# |    fps                  | 16        |
# |    iterations           | 75        |
# |    time_elapsed         | 9508      |
# |    total_timesteps      | 153600    |
# | train/                  |           |
# |    approx_kl            | 0.4460662 |
# |    clip_fraction        | 0.583     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.72     |
# |    explained_variance   | 0.35      |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0.273     |
# |    n_updates            | 740       |
# |    policy_gradient_loss | -0.0505   |
# |    std                  | 0.307     |
# |    value_loss           | 1.1       |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 5         |
# |    ep_rew_mean          | 2.69      |
# | time/                   |           |
# |    fps                  | 15        |
# |    iterations           | 76        |
# |    time_elapsed         | 9889      |
# |    total_timesteps      | 155648    |
# | train/                  |           |
# |    approx_kl            | 0.3696031 |
# |    clip_fraction        | 0.558     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.7      |
# |    explained_variance   | 0.298     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 1.23      |
# |    n_updates            | 750       |
# |    policy_gradient_loss | -0.0498   |
# |    std                  | 0.304     |
# |    value_loss           | 1.69      |
# ---------------------------------------

# %%
model.save(os.path.join(log_dir, "ppo_model"))

# %% [markdown]
# Evaluation

# %%
import os
import pandas as pd
import seaborn as sns

from stable_baselines3 import PPO
from stable_baselines3.common.monitor import Monitor

# test environment
env = CustomEnv()

# ==== Configuration ====
log_dir = "logs/rl_repressilator_past_amort_multi_step_frame_5"
model_path = os.path.join(log_dir, "ppo_model")

# %%
model = PPO.load(model_path)

# %%
obs, info = env.reset()  # Reset the environment with a specific frequency

action, _states = model.predict(obs, deterministic=True)
action
print("Action taken:", action)
first_params = np.hstack((env.uncertain, action))



# print("First Reward:",jl.reward_normalized_past_amort(first_params, 1/7))
obs, reward, terminated, truncated, info = env.step(action)
print(terminated)

print("First reward:", reward)
print(obs.shape)

# plt.plot(jl.observation_normalized(np.concatenate((env.uncertain, action))), label="Second Design")
plt.legend()
# Take action in the environment

action, _states = model.predict(obs, deterministic=True)

obs, reward, terminated, truncated, info = env.step(action)

print("Action taken:", action)
print("Second reward:", reward)

plt.plot(obs[0,0:128], label="First Design")
plt.plot(obs[0,132:260], label="Second Design")

action, _states = model.predict(obs, deterministic=True)

plt.plot(jl.observation(env.uncertain, action), label="Third Design")

obs, reward, terminated, truncated, info = env.step(action)

print("Action taken:", action)
print("Third reward:", reward)


print(terminated)
# Out:
# Action taken: [-1.         0.8810336  1.       ]
# False
# First reward: 0.45630441606295563
# (1, 655)
# Action taken: [-1.  1.  1.]
# Second reward: 0.8269251682108958
# C:\Users\micha\AppData\Local\Temp\ipykernel_32040\4038937236.py:18: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()
# Action taken: [-1.          0.70176136  1.        ]
# Third reward: 1.2194504024755481
# False

# %%
first_rewards = np.zeros(1000)
second_rewards = np.zeros(1000)
third_rewards = np.zeros(1000)
forth_rewards = np.zeros(1000)
fifth_rewards = np.zeros(1000)

env.seed(31415)

for i in range(1000):
    obs, info = env.reset() 
    action, _states = model.predict(obs, deterministic=True)
    obs, reward, terminated, truncated, info = env.step(action)
    first_rewards[i] = (reward + jl.reward_normalized_past_amort(np.hstack((env.uncertain, action)), 1/7) + jl.reward_normalized_past_amort(np.hstack((env.uncertain, action)), 1/7) + jl.reward_normalized_past_amort(np.hstack((env.uncertain, action)), 1/7) + jl.reward_normalized_past_amort(np.hstack((env.uncertain, action)), 1/7))/ 5
    action, _states = model.predict(obs, deterministic=True)
    obs, reward, terminated, truncated, info = env.step(action)
    second_rewards[i] = (reward + jl.reward_normalized_past_amort(np.hstack((env.uncertain, action)), 1/7) + jl.reward_normalized_past_amort(np.hstack((env.uncertain, action)), 1/7) + jl.reward_normalized_past_amort(np.hstack((env.uncertain, action)), 1/7) + jl.reward_normalized_past_amort(np.hstack((env.uncertain, action)), 1/7))/ 5
    action, _states = model.predict(obs, deterministic=True)
    obs, reward, terminated, truncated, info = env.step(action)
    third_rewards[i] = (reward + jl.reward_normalized_past_amort(np.hstack((env.uncertain, action)), 1/7) + jl.reward_normalized_past_amort(np.hstack((env.uncertain, action)), 1/7) + jl.reward_normalized_past_amort(np.hstack((env.uncertain, action)), 1/7) + jl.reward_normalized_past_amort(np.hstack((env.uncertain, action)), 1/7))/ 5
    action, _states = model.predict(obs, deterministic=True)
    obs, reward, terminated, truncated, info = env.step(action)
    forth_rewards[i] = (reward + jl.reward_normalized_past_amort(np.hstack((env.uncertain, action)), 1/7) + jl.reward_normalized_past_amort(np.hstack((env.uncertain, action)), 1/7) + jl.reward_normalized_past_amort(np.hstack((env.uncertain, action)), 1/7) + jl.reward_normalized_past_amort(np.hstack((env.uncertain, action)), 1/7))/ 5
    action, _states = model.predict(obs, deterministic=True)
    obs, reward, terminated, truncated, info = env.step(action)
    fifth_rewards[i] = (reward + jl.reward_normalized_past_amort(np.hstack((env.uncertain, action)), 1/7) + jl.reward_normalized_past_amort(np.hstack((env.uncertain, action)), 1/7) + jl.reward_normalized_past_amort(np.hstack((env.uncertain, action)), 1/7) + jl.reward_normalized_past_amort(np.hstack((env.uncertain, action)), 1/7))/ 5

# %%
plt.figure(figsize=(10, 6))
plt.plot(first_rewards, label='First Reward', alpha=0.7)
plt.plot(second_rewards, label='Second Reward', alpha=0.7)
plt.plot(third_rewards, label='Third Reward', alpha=0.7)
plt.legend()
plt.xlabel("Trial (new uncertain parameters sampled from the prior)", fontsize=18)
plt.ylabel("Reward", fontsize=18)
# Out:
# Text(0, 0.5, 'Reward')

# %%
#plot violins seaborn
import seaborn as sns
plt.figure(figsize=(10, 6))
sns.violinplot(data=[first_rewards, second_rewards, third_rewards, forth_rewards, fifth_rewards], inner="quartile")
plt.xlabel("Design", fontsize=18)
plt.ylabel("Reward", fontsize=18)
# Out:
# Text(0, 0.5, 'Reward')

# %%
# Plot boxplot with seaborn
plt.figure(figsize=(10, 6))
sns.boxplot(data=[first_rewards, second_rewards, third_rewards, forth_rewards, fifth_rewards], showmeans=True)

# Set x-axis labels starting from 1
plt.xticks(ticks=range(5), labels=["1", "2", "3", "4", "5"])

plt.xlabel("design", fontsize=18)
plt.ylabel("reward", fontsize=18)

sns.despine()

plt.tight_layout()
plt.savefig("boxes_std.pdf", format="pdf")
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

def stacked_amort_heatmap(env, action, step_idx, num_samples=10):
    """
    Repeats jl.plot_amort with the same input multiple times and plots a 2D heatmap.
    
    Parameters:
        env: the environment object
        action: the action taken
        step_idx: index of the current step (for labeling)
        num_samples: number of times to repeat jl.plot_amort
    """
    amort_outputs = []
    for _ in range(num_samples):
        out = jl.plot_amort(np.hstack([env.uncertain, action]))
        amort_outputs.append(out)
    return amort_outputs

# Start interaction with the environment
obs, info = env.reset()
env.uncertain = np.ones(2)
env.seed(31415)
print("Environment reset.")

# Step 1
action, _states = model.predict(obs, deterministic=True)
print("Action taken:", action)
h1 = stacked_amort_heatmap(env, action, step_idx=1)

obs, reward, terminated, truncated, info = env.step(action)
print("Step 1 reward:", reward)
print("Terminated:", terminated)

# Step 2
action, _states = model.predict(obs, deterministic=True)
print("Action taken:", action)
h2 = stacked_amort_heatmap(env, action, step_idx=2)

obs, reward, terminated, truncated, info = env.step(action)
print("Step 2 reward:", reward)
print("Terminated:", terminated)

# Step 3
action, _states = model.predict(obs, deterministic=True)
print("Action taken:", action)
h3 = stacked_amort_heatmap(env, action, step_idx=3)

obs, reward, terminated, truncated, info = env.step(action)
print("Step 3 reward:", reward)
print("Terminated:", terminated)

# Step 4
action, _states = model.predict(obs, deterministic=True)
print("Action taken:", action)
h4 = stacked_amort_heatmap(env, action, step_idx=4)

obs, reward, terminated, truncated, info = env.step(action)
print("Step 4 reward:", reward)
print("Terminated:", terminated)

# Step 5
action, _states = model.predict(obs, deterministic=True)
print("Action taken:", action)
h5 = stacked_amort_heatmap(env, action, step_idx=5)

obs, reward, terminated, truncated, info = env.step(action)
print("Step 5 reward:", reward)
print("Terminated:", terminated)
# Out:
# Environment reset.
# Action taken: [ 0.09105472 -0.81247514  1.          1.        ]
# Step 1 reward: 0.5503016700874196
# Terminated: False
# Action taken: [-0.08662032 -0.85542274  1.          0.24638996]
# Step 2 reward: 0.9818471457449586
# Terminated: False
# Action taken: [ 0.85036933 -0.72266835  0.88866234 -0.06208357]
# Step 3 reward: 1.1050607921291296
# Terminated: False
# Action taken: [ 1.         -0.41897336  0.89494383  0.34132922]
# Step 4 reward: 0.9751906415277429
# Terminated: False
# Action taken: [-0.04679902 -0.80467355  1.          0.3810021 ]
# Step 5 reward: 1.1214619261112762
# Terminated: True

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from matplotlib.gridspec import GridSpec
import numpy as np
from scipy.signal import find_peaks, savgol_filter

def sort_by_first_peak(matrix, smooth_window=30, poly_order=5, min_start_fraction=0.00, min_prominence=1):
    """Sort rows of a 2D array-like by the location of the first peak, with smoothing and early-peak filtering."""
    matrix = np.array(matrix)  # ensure NumPy array
    n_timepoints = matrix.shape[1]
    min_start_index = int(n_timepoints * min_start_fraction)

    peak_positions = []
    for row in matrix:
        # Smooth the signal
        if len(row) >= smooth_window:
            smooth_row = savgol_filter(row, smooth_window, poly_order)
        else:
            smooth_row = row

        # Find peaks with prominence filter
        peaks, _ = find_peaks(smooth_row, prominence=min_prominence)

        # Filter out peaks that are too close to the start
        peaks = peaks[peaks > min_start_index]

        if len(peaks) > 0:
            peak_positions.append(peaks[0])  # first valid peak
        else:
            peak_positions.append(np.inf)    # no valid peak found

    sorted_idx = np.argsort(peak_positions)
    return matrix[sorted_idx, :], sorted_idx

def plot_heatmaps_with_shared_colorbar(h_list, steps):
    num_plots = len(h_list)
    total_slots = num_plots * 2 - 1
    width_ratios = [6 if i % 2 == 0 else 0.6 for i in range(total_slots)]

    fig = plt.figure(figsize=(6 * num_plots + 1, 5))
    gs = GridSpec(1, total_slots + 1, width_ratios=width_ratios + [0.4])

    # Sort each heatmap independently
    h_list_sorted = [sort_by_first_peak(h)[0] for h in h_list]

    global_min = min(np.min(h) for h in h_list_sorted)
    global_max = max(np.max(h) for h in h_list_sorted)

    for i in range(num_plots):
        ax = fig.add_subplot(gs[0, i * 2])
        sns.heatmap(
            h_list_sorted[i],
            ax=ax,
            cbar=False,
            vmin=global_min,
            vmax=global_max,
            cmap='viridis'
        )

        ax.set_title(f"Step {steps[i]}", fontsize=16)
        if i == 0:
            ax.set_ylabel("Aleatoric Uncertainty", fontsize=12)
            ax.set_xlabel("Time", fontsize=12)
        else:
            ax.set_ylabel("")
            ax.set_xlabel("Time", fontsize=12)

        ax.set_xticks([])
        ax.set_yticks([])

    for i in range(num_plots - 1):
        ax_arrow = fig.add_subplot(gs[0, i * 2 + 1])
        ax_arrow.axis('off')
        ax_arrow.text(0.5, 0.5, '→', fontsize=40, ha='center', va='center', transform=ax_arrow.transAxes)

    # Shared colorbar on the right
    cbar_ax = fig.add_subplot(gs[0, -1])
    norm = plt.cm.colors.Normalize(vmin=global_min, vmax=global_max)
    sm = plt.cm.ScalarMappable(cmap='viridis', norm=norm)
    sm.set_array([])
    cbar = fig.colorbar(sm, cax=cbar_ax)
    cbar.set_label('Expression', fontsize=12)

    plt.tight_layout()

# Example usage
plot_heatmaps_with_shared_colorbar([h1, h3, h5], steps=[1, 3, 5])

plt.tight_layout()
plt.savefig("heatmaps_3_1.pdf", format="pdf")
plt.savefig("heatmaps_3_1.png", format="png")
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from matplotlib.gridspec import GridSpec
import numpy as np
from scipy.signal import find_peaks, savgol_filter

def sort_by_first_peak(matrix, smooth_window=30, poly_order=5, min_start_fraction=0.00, min_prominence=1):
    """Sort rows of a 2D array-like by the location of the first peak, with smoothing and early-peak filtering."""
    matrix = np.array(matrix)  # ensure NumPy array
    n_timepoints = matrix.shape[1]
    min_start_index = int(n_timepoints * min_start_fraction)

    peak_positions = []
    for row in matrix:
        # Smooth the signal
        if len(row) >= smooth_window:
            smooth_row = savgol_filter(row, smooth_window, poly_order)
        else:
            smooth_row = row

        # Find peaks with prominence filter
        peaks, _ = find_peaks(smooth_row, prominence=min_prominence)

        # Filter out peaks that are too close to the start
        peaks = peaks[peaks > min_start_index]

        if len(peaks) > 0:
            peak_positions.append(peaks[0])  # first valid peak
        else:
            peak_positions.append(np.inf)    # no valid peak found

    sorted_idx = np.argsort(peak_positions)
    return matrix[sorted_idx, :], sorted_idx

def plot_heatmaps_with_shared_colorbar(h_list, steps):
    num_plots = len(h_list)
    total_slots = num_plots * 2 - 1
    width_ratios = [6 if i % 2 == 0 else 0.6 for i in range(total_slots)]

    fig = plt.figure(figsize=(6 * num_plots + 1, 5))
    gs = GridSpec(1, total_slots + 1, width_ratios=width_ratios + [0.4])

    # Sort each heatmap independently
    h_list_sorted = [sort_by_first_peak(h)[0] for h in h_list]

    global_min = min(np.min(h) for h in h_list_sorted)
    global_max = max(np.max(h) for h in h_list_sorted)

    for i in range(num_plots):
        ax = fig.add_subplot(gs[0, i * 2])
        sns.heatmap(
            h_list_sorted[i],
            ax=ax,
            cbar=False,
            vmin=global_min,
            vmax=global_max,
            cmap='viridis'
        )

        ax.set_title(f"Step {steps[i]}", fontsize=16)
        if i == 0:
            ax.set_ylabel("Aleatoric Uncertainty", fontsize=12)
            ax.set_xlabel("Time", fontsize=12)
        else:
            ax.set_ylabel("")
            ax.set_xlabel("Time", fontsize=12)

        ax.set_xticks([])
        ax.set_yticks([])

    for i in range(num_plots - 1):
        ax_arrow = fig.add_subplot(gs[0, i * 2 + 1])
        ax_arrow.axis('off')
        ax_arrow.text(0.5, 0.5, '→', fontsize=40, ha='center', va='center', transform=ax_arrow.transAxes)

    # Shared colorbar on the right
    cbar_ax = fig.add_subplot(gs[0, -1])
    norm = plt.cm.colors.Normalize(vmin=global_min, vmax=global_max)
    sm = plt.cm.ScalarMappable(cmap='viridis', norm=norm)
    sm.set_array([])
    cbar = fig.colorbar(sm, cax=cbar_ax)
    cbar.set_label('Expression', fontsize=12)

    plt.tight_layout()
    plt.show()

# Example usage
plot_heatmaps_with_shared_colorbar([h1, h3, h5], steps=[1, 3, 5])

# %%
import numpy as np
import matplotlib.pyplot as plt

def stacked_amort_heatmap(env, action, step_idx, num_samples=10):
    """
    Repeats jl.plot_amort with the same input multiple times and plots a 2D heatmap.
    
    Parameters:
        env: the environment object
        action: the action taken
        step_idx: index of the current step (for labeling)
        num_samples: number of times to repeat jl.plot_amort
    """
    amort_outputs = []
    for _ in range(num_samples):
        out = jl.plot_amort(np.hstack([env.uncertain, action]))
        amort_outputs.append(out)
    return amort_outputs

# Start interaction with the environment
obs, info = env.reset()
env.uncertain = np.array([0,-1])
env.seed(31415)
print("Environment reset.")

# Step 1
action, _states = model.predict(obs, deterministic=True)
print("Action taken:", action)
h1 = stacked_amort_heatmap(env, action, step_idx=1)

obs, reward, terminated, truncated, info = env.step(action)
print("Step 1 reward:", reward)
print("Terminated:", terminated)

# Step 2
action, _states = model.predict(obs, deterministic=True)
print("Action taken:", action)
h2 = stacked_amort_heatmap(env, action, step_idx=2)

obs, reward, terminated, truncated, info = env.step(action)
print("Step 2 reward:", reward)
print("Terminated:", terminated)

# Step 3
action, _states = model.predict(obs, deterministic=True)
print("Action taken:", action)
h3 = stacked_amort_heatmap(env, action, step_idx=3)

obs, reward, terminated, truncated, info = env.step(action)
print("Step 3 reward:", reward)
print("Terminated:", terminated)

# Step 4
action, _states = model.predict(obs, deterministic=True)
print("Action taken:", action)
h4 = stacked_amort_heatmap(env, action, step_idx=4)

obs, reward, terminated, truncated, info = env.step(action)
print("Step 4 reward:", reward)
print("Terminated:", terminated)

# Step 5
action, _states = model.predict(obs, deterministic=True)
print("Action taken:", action)
h5 = stacked_amort_heatmap(env, action, step_idx=5)

obs, reward, terminated, truncated, info = env.step(action)
print("Step 5 reward:", reward)
print("Terminated:", terminated)
# Out:
# Environment reset.
# Action taken: [ 0.09105472 -0.81247514  1.          1.        ]
# Step 1 reward: 0.5688697082347376
# Terminated: False
# Action taken: [ 0.31985462 -0.91879773  1.          1.        ]
# Step 2 reward: 0.9937989892358314
# Terminated: False
# Action taken: [ 0.5887918 -0.8251871  1.         0.9184077]
# Step 3 reward: 1.136951611447681
# Terminated: False
# Action taken: [ 0.761827   -0.82478154  1.          0.82011914]
# Step 4 reward: 0.7069890176807961
# Terminated: False
# Action taken: [-0.17442301 -1.          1.          0.98664   ]
# Step 5 reward: 0.9923358979244994
# Terminated: True

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from matplotlib.gridspec import GridSpec
import numpy as np
from scipy.signal import find_peaks, savgol_filter

def sort_by_first_peak(matrix, smooth_window=30, poly_order=5, min_start_fraction=0.00, min_prominence=1):
    """Sort rows of a 2D array-like by the location of the first peak, with smoothing and early-peak filtering."""
    matrix = np.array(matrix)  # ensure NumPy array
    n_timepoints = matrix.shape[1]
    min_start_index = int(n_timepoints * min_start_fraction)

    peak_positions = []
    for row in matrix:
        # Smooth the signal
        if len(row) >= smooth_window:
            smooth_row = savgol_filter(row, smooth_window, poly_order)
        else:
            smooth_row = row

        # Find peaks with prominence filter
        peaks, _ = find_peaks(smooth_row, prominence=min_prominence)

        # Filter out peaks that are too close to the start
        peaks = peaks[peaks > min_start_index]

        if len(peaks) > 0:
            peak_positions.append(peaks[0])  # first valid peak
        else:
            peak_positions.append(np.inf)    # no valid peak found

    sorted_idx = np.argsort(peak_positions)
    return matrix[sorted_idx, :], sorted_idx

def plot_heatmaps_with_shared_colorbar(h_list, steps):
    num_plots = len(h_list)
    total_slots = num_plots * 2 - 1
    width_ratios = [6 if i % 2 == 0 else 0.6 for i in range(total_slots)]

    fig = plt.figure(figsize=(6 * num_plots + 1, 5))
    gs = GridSpec(1, total_slots + 1, width_ratios=width_ratios + [0.4])

    # Sort each heatmap independently
    h_list_sorted = [sort_by_first_peak(h)[0] for h in h_list]

    global_min = min(np.min(h) for h in h_list_sorted)
    global_max = max(np.max(h) for h in h_list_sorted)

    for i in range(num_plots):
        ax = fig.add_subplot(gs[0, i * 2])
        sns.heatmap(
            h_list_sorted[i],
            ax=ax,
            cbar=False,
            vmin=global_min,
            vmax=global_max,
            cmap='viridis'
        )

        ax.set_title(f"Step {steps[i]}", fontsize=16)
        if i == 0:
            ax.set_ylabel("Aleatoric Uncertainty", fontsize=12)
            ax.set_xlabel("Time", fontsize=12)
        else:
            ax.set_ylabel("")
            ax.set_xlabel("Time", fontsize=12)

        ax.set_xticks([])
        ax.set_yticks([])

    for i in range(num_plots - 1):
        ax_arrow = fig.add_subplot(gs[0, i * 2 + 1])
        ax_arrow.axis('off')
        ax_arrow.text(0.5, 0.5, '→', fontsize=40, ha='center', va='center', transform=ax_arrow.transAxes)

    # Shared colorbar on the right
    cbar_ax = fig.add_subplot(gs[0, -1])
    norm = plt.cm.colors.Normalize(vmin=global_min, vmax=global_max)
    sm = plt.cm.ScalarMappable(cmap='viridis', norm=norm)
    sm.set_array([])
    cbar = fig.colorbar(sm, cax=cbar_ax)
    cbar.set_label('Expression', fontsize=12)

    plt.tight_layout()

# Example usage
plot_heatmaps_with_shared_colorbar([h1, h3, h5], steps=[1, 3, 5])

plt.tight_layout()
plt.savefig("heatmaps_3_2.pdf", format="pdf")
plt.savefig("heatmaps_3_2.png", format="png")
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from matplotlib.gridspec import GridSpec

def plot_heatmaps_with_arrows_less_arrow_space(h_list, steps):
    num_plots = len(h_list)
    total_slots = num_plots * 2 - 1

    # Adjust width ratios: heatmaps get 6, arrows get 0.6
    width_ratios = [6 if i % 2 == 0 else 0.6 for i in range(total_slots)]

    fig = plt.figure(figsize=(6 * num_plots, 5))
    gs = GridSpec(1, total_slots, width_ratios=width_ratios)

    for i in range(num_plots):
        ax = fig.add_subplot(gs[0, i * 2])
        sns.heatmap(h_list[i], ax=ax, cbar=True)
        ax.set_title(f"Step {steps[i]}", fontsize=16)
        ax.axis('off')

    for i in range(num_plots - 1):
        ax_arrow = fig.add_subplot(gs[0, i * 2 + 1])
        ax_arrow.axis('off')
        ax_arrow.text(0.5, 0.5, '→', fontsize=40, ha='center', va='center', transform=ax_arrow.transAxes)

    plt.tight_layout()
    plt.show()

# Use your heatmaps
plot_heatmaps_with_arrows_less_arrow_space([h1, h3, h5], steps=[1, 3, 5])

# %%
first_rewards_zeros = np.zeros(1000)
second_rewards_zeros = np.zeros(1000)
third_rewards_zeros = np.zeros(1000)
forth_rewards_zeros = np.zeros(1000)
fifth_rewards_zeros = np.zeros(1000)

env.seed(31415)

for i in range(1000):
    obs, info = env.reset()
    env.uncertain = np.zeros(2)
    action, _states = model.predict(obs, deterministic=True)
    obs, reward, terminated, truncated, info = env.step(action)
    first_rewards_zeros[i] = (reward + jl.reward_normalized_past_amort(np.hstack((env.uncertain, action)), 1/7) + jl.reward_normalized_past_amort(np.hstack((env.uncertain, action)), 1/7) + jl.reward_normalized_past_amort(np.hstack((env.uncertain, action)), 1/7) + jl.reward_normalized_past_amort(np.hstack((env.uncertain, action)), 1/7))/ 5
    action, _states = model.predict(obs, deterministic=True)
    obs, reward, terminated, truncated, info = env.step(action)
    second_rewards_zeros[i] = (reward + jl.reward_normalized_past_amort(np.hstack((env.uncertain, action)), 1/7) + jl.reward_normalized_past_amort(np.hstack((env.uncertain, action)), 1/7) + jl.reward_normalized_past_amort(np.hstack((env.uncertain, action)), 1/7) + jl.reward_normalized_past_amort(np.hstack((env.uncertain, action)), 1/7))/ 5
    action, _states = model.predict(obs, deterministic=True)
    obs, reward, terminated, truncated, info = env.step(action)
    third_rewards_zeros[i] = (reward + jl.reward_normalized_past_amort(np.hstack((env.uncertain, action)), 1/7) + jl.reward_normalized_past_amort(np.hstack((env.uncertain, action)), 1/7) + jl.reward_normalized_past_amort(np.hstack((env.uncertain, action)), 1/7) + jl.reward_normalized_past_amort(np.hstack((env.uncertain, action)), 1/7))/ 5
    action, _states = model.predict(obs, deterministic=True)
    obs, reward, terminated, truncated, info = env.step(action)
    forth_rewards_zeros[i] = (reward + jl.reward_normalized_past_amort(np.hstack((env.uncertain, action)), 1/7) + jl.reward_normalized_past_amort(np.hstack((env.uncertain, action)), 1/7) + jl.reward_normalized_past_amort(np.hstack((env.uncertain, action)), 1/7) + jl.reward_normalized_past_amort(np.hstack((env.uncertain, action)), 1/7))/ 5
    action, _states = model.predict(obs, deterministic=True)
    obs, reward, terminated, truncated, info = env.step(action)
    fifth_rewards_zeros[i] = (reward + jl.reward_normalized_past_amort(np.hstack((env.uncertain, action)), 1/7) + jl.reward_normalized_past_amort(np.hstack((env.uncertain, action)), 1/7) + jl.reward_normalized_past_amort(np.hstack((env.uncertain, action)), 1/7) + jl.reward_normalized_past_amort(np.hstack((env.uncertain, action)), 1/7))/ 5

# %%
#plot boxplot seaborn
plt.figure(figsize=(10, 6))
sns.boxplot(data=[first_rewards_zeros, second_rewards_zeros, third_rewards_zeros,forth_rewards_zeros, fifth_rewards_zeros],showmeans=True)
plt.xlabel("Design", fontsize=18)
plt.ylabel("Reward", fontsize=18)
# Set y-axis range
plt.ylim(0, 1.5)
plt.tight_layout()
sns.despine()
plt.savefig("box_0_0.pdf", format="pdf")

# %%
first_rewards_ones = np.zeros(1000)
second_rewards_ones = np.zeros(1000)
third_rewards_ones = np.zeros(1000)
forth_rewards_ones = np.zeros(1000)
fifth_rewards_ones = np.zeros(1000)

env.seed(31415)

for i in range(1000):
    obs, info = env.reset()
    env.uncertain = np.ones(2)
    action, _states = model.predict(obs, deterministic=True)
    obs, reward, terminated, truncated, info = env.step(action)
    first_rewards_ones[i] = (reward + jl.reward_normalized_past_amort(np.hstack((env.uncertain, action)), 1/7) + jl.reward_normalized_past_amort(np.hstack((env.uncertain, action)), 1/7) + jl.reward_normalized_past_amort(np.hstack((env.uncertain, action)), 1/7) + jl.reward_normalized_past_amort(np.hstack((env.uncertain, action)), 1/7))/ 5
    action, _states = model.predict(obs, deterministic=True)
    obs, reward, terminated, truncated, info = env.step(action)
    second_rewards_ones[i] = (reward + jl.reward_normalized_past_amort(np.hstack((env.uncertain, action)), 1/7) + jl.reward_normalized_past_amort(np.hstack((env.uncertain, action)), 1/7) + jl.reward_normalized_past_amort(np.hstack((env.uncertain, action)), 1/7) + jl.reward_normalized_past_amort(np.hstack((env.uncertain, action)), 1/7))/ 5
    action, _states = model.predict(obs, deterministic=True)
    obs, reward, terminated, truncated, info = env.step(action)
    third_rewards_ones[i] = (reward + jl.reward_normalized_past_amort(np.hstack((env.uncertain, action)), 1/7) + jl.reward_normalized_past_amort(np.hstack((env.uncertain, action)), 1/7) + jl.reward_normalized_past_amort(np.hstack((env.uncertain, action)), 1/7) + jl.reward_normalized_past_amort(np.hstack((env.uncertain, action)), 1/7))/ 5
    action, _states = model.predict(obs, deterministic=True)
    obs, reward, terminated, truncated, info = env.step(action)
    forth_rewards_ones[i] = (reward + jl.reward_normalized_past_amort(np.hstack((env.uncertain, action)), 1/7) + jl.reward_normalized_past_amort(np.hstack((env.uncertain, action)), 1/7) + jl.reward_normalized_past_amort(np.hstack((env.uncertain, action)), 1/7) + jl.reward_normalized_past_amort(np.hstack((env.uncertain, action)), 1/7))/ 5
    action, _states = model.predict(obs, deterministic=True)
    obs, reward, terminated, truncated, info = env.step(action)
    fifth_rewards_ones[i] = (reward + jl.reward_normalized_past_amort(np.hstack((env.uncertain, action)), 1/7) + jl.reward_normalized_past_amort(np.hstack((env.uncertain, action)), 1/7) + jl.reward_normalized_past_amort(np.hstack((env.uncertain, action)), 1/7) + jl.reward_normalized_past_amort(np.hstack((env.uncertain, action)), 1/7))/ 5

# %%
#plot boxplot seaborn
plt.figure(figsize=(10, 6))
sns.boxplot(data=[first_rewards_ones, second_rewards_ones, third_rewards_ones,forth_rewards_ones, fifth_rewards_ones],showmeans=True)
plt.xlabel("Design", fontsize=18)
plt.ylabel("Reward", fontsize=18)
# Set y-axis range
plt.ylim(0, 1.5)
plt.tight_layout()
sns.despine()
plt.savefig("box_1_1.pdf", format="pdf")

# %%
first_rewards_minus_ones = np.zeros(1000)
second_rewards_minus_ones = np.zeros(1000)
third_rewards_minus_ones = np.zeros(1000)
forth_rewards_minus_ones = np.zeros(1000)
fifth_rewards_minus_ones = np.zeros(1000)

env.seed(31415)

for i in range(1000):
    obs, info = env.reset()
    env.uncertain = -np.ones(2)
    action, _states = model.predict(obs, deterministic=True)
    obs, reward, terminated, truncated, info = env.step(action)
    first_rewards_minus_ones[i] = (reward + jl.reward_normalized_past_amort(np.hstack((env.uncertain, action)), 1/7) + jl.reward_normalized_past_amort(np.hstack((env.uncertain, action)), 1/7) + jl.reward_normalized_past_amort(np.hstack((env.uncertain, action)), 1/7) + jl.reward_normalized_past_amort(np.hstack((env.uncertain, action)), 1/7))/ 5
    action, _states = model.predict(obs, deterministic=True)
    obs, reward, terminated, truncated, info = env.step(action)
    second_rewards_minus_ones[i] = (reward + jl.reward_normalized_past_amort(np.hstack((env.uncertain, action)), 1/7) + jl.reward_normalized_past_amort(np.hstack((env.uncertain, action)), 1/7) + jl.reward_normalized_past_amort(np.hstack((env.uncertain, action)), 1/7) + jl.reward_normalized_past_amort(np.hstack((env.uncertain, action)), 1/7))/ 5
    action, _states = model.predict(obs, deterministic=True)
    obs, reward, terminated, truncated, info = env.step(action)
    third_rewards_minus_ones[i] = (reward + jl.reward_normalized_past_amort(np.hstack((env.uncertain, action)), 1/7) + jl.reward_normalized_past_amort(np.hstack((env.uncertain, action)), 1/7) + jl.reward_normalized_past_amort(np.hstack((env.uncertain, action)), 1/7) + jl.reward_normalized_past_amort(np.hstack((env.uncertain, action)), 1/7))/ 5
    action, _states = model.predict(obs, deterministic=True)
    obs, reward, terminated, truncated, info = env.step(action)
    forth_rewards_minus_ones[i] = (reward + jl.reward_normalized_past_amort(np.hstack((env.uncertain, action)), 1/7) + jl.reward_normalized_past_amort(np.hstack((env.uncertain, action)), 1/7) + jl.reward_normalized_past_amort(np.hstack((env.uncertain, action)), 1/7) + jl.reward_normalized_past_amort(np.hstack((env.uncertain, action)), 1/7))/ 5
    action, _states = model.predict(obs, deterministic=True)
    obs, reward, terminated, truncated, info = env.step(action)
    fifth_rewards_minus_ones[i] = (reward + jl.reward_normalized_past_amort(np.hstack((env.uncertain, action)), 1/7) + jl.reward_normalized_past_amort(np.hstack((env.uncertain, action)), 1/7) + jl.reward_normalized_past_amort(np.hstack((env.uncertain, action)), 1/7) + jl.reward_normalized_past_amort(np.hstack((env.uncertain, action)), 1/7))/ 5

# %%
#plot boxplot seaborn
plt.figure(figsize=(10, 6))
sns.boxplot(data=[first_rewards_minus_ones, second_rewards_minus_ones, third_rewards_minus_ones,forth_rewards_minus_ones, fifth_rewards_minus_ones],showmeans=True)
plt.xlabel("Design", fontsize=18)
plt.ylabel("Reward", fontsize=18)
# Set y-axis range
plt.ylim(0, 1.5)
plt.tight_layout()
sns.despine()
plt.savefig("box_-1_-1.pdf", format="pdf")

# %%
first_rewards = np.zeros(1000)
second_rewards = np.zeros(1000)
third_rewards = np.zeros(1000)
forth_rewards = np.zeros(1000)
fifth_rewards = np.zeros(1000)

env.seed(31415)

for i in range(1000):
    obs, info = env.reset()
    env.uncertain = -np.array([1,-1])
    action, _states = model.predict(obs, deterministic=True)
    obs, reward, terminated, truncated, info = env.step(action)
    first_rewards[i] = (reward + jl.reward_normalized_past_amort(np.hstack((env.uncertain, action)), 1/7) + jl.reward_normalized_past_amort(np.hstack((env.uncertain, action)), 1/7) + jl.reward_normalized_past_amort(np.hstack((env.uncertain, action)), 1/7) + jl.reward_normalized_past_amort(np.hstack((env.uncertain, action)), 1/7))/ 5
    action, _states = model.predict(obs, deterministic=True)
    obs, reward, terminated, truncated, info = env.step(action)
    second_rewards[i] = (reward + jl.reward_normalized_past_amort(np.hstack((env.uncertain, action)), 1/7) + jl.reward_normalized_past_amort(np.hstack((env.uncertain, action)), 1/7) + jl.reward_normalized_past_amort(np.hstack((env.uncertain, action)), 1/7) + jl.reward_normalized_past_amort(np.hstack((env.uncertain, action)), 1/7))/ 5
    action, _states = model.predict(obs, deterministic=True)
    obs, reward, terminated, truncated, info = env.step(action)
    third_rewards[i] = (reward + jl.reward_normalized_past_amort(np.hstack((env.uncertain, action)), 1/7) + jl.reward_normalized_past_amort(np.hstack((env.uncertain, action)), 1/7) + jl.reward_normalized_past_amort(np.hstack((env.uncertain, action)), 1/7) + jl.reward_normalized_past_amort(np.hstack((env.uncertain, action)), 1/7))/ 5
    action, _states = model.predict(obs, deterministic=True)
    obs, reward, terminated, truncated, info = env.step(action)
    forth_rewards[i] = (reward + jl.reward_normalized_past_amort(np.hstack((env.uncertain, action)), 1/7) + jl.reward_normalized_past_amort(np.hstack((env.uncertain, action)), 1/7) + jl.reward_normalized_past_amort(np.hstack((env.uncertain, action)), 1/7) + jl.reward_normalized_past_amort(np.hstack((env.uncertain, action)), 1/7))/ 5
    action, _states = model.predict(obs, deterministic=True)
    obs, reward, terminated, truncated, info = env.step(action)
    fifth_rewards[i] = (reward + jl.reward_normalized_past_amort(np.hstack((env.uncertain, action)), 1/7) + jl.reward_normalized_past_amort(np.hstack((env.uncertain, action)), 1/7) + jl.reward_normalized_past_amort(np.hstack((env.uncertain, action)), 1/7) + jl.reward_normalized_past_amort(np.hstack((env.uncertain, action)), 1/7))/ 5

# %%
#plot boxplot seaborn
plt.figure(figsize=(10, 6))
sns.boxplot(data=[first_rewards, second_rewards, third_rewards,forth_rewards, fifth_rewards],showmeans=True)
plt.xlabel("Design", fontsize=18)
plt.ylabel("Reward", fontsize=18)
# Out:
# Text(0, 0.5, 'Reward')

# %%
first_rewards = np.zeros(1000)
second_rewards = np.zeros(1000)
third_rewards = np.zeros(1000)
forth_rewards = np.zeros(1000)
fifth_rewards = np.zeros(1000)

env.seed(31415)

for i in range(1000):
    obs, info = env.reset()
    env.uncertain = -np.array([0,-1])
    action, _states = model.predict(obs, deterministic=True)
    obs, reward, terminated, truncated, info = env.step(action)
    first_rewards[i] = (reward + jl.reward_normalized_past_amort(np.hstack((env.uncertain, action)), 1/7) + jl.reward_normalized_past_amort(np.hstack((env.uncertain, action)), 1/7) + jl.reward_normalized_past_amort(np.hstack((env.uncertain, action)), 1/7) + jl.reward_normalized_past_amort(np.hstack((env.uncertain, action)), 1/7))/ 5
    action, _states = model.predict(obs, deterministic=True)
    obs, reward, terminated, truncated, info = env.step(action)
    second_rewards[i] = (reward + jl.reward_normalized_past_amort(np.hstack((env.uncertain, action)), 1/7) + jl.reward_normalized_past_amort(np.hstack((env.uncertain, action)), 1/7) + jl.reward_normalized_past_amort(np.hstack((env.uncertain, action)), 1/7) + jl.reward_normalized_past_amort(np.hstack((env.uncertain, action)), 1/7))/ 5
    action, _states = model.predict(obs, deterministic=True)
    obs, reward, terminated, truncated, info = env.step(action)
    third_rewards[i] = (reward + jl.reward_normalized_past_amort(np.hstack((env.uncertain, action)), 1/7) + jl.reward_normalized_past_amort(np.hstack((env.uncertain, action)), 1/7) + jl.reward_normalized_past_amort(np.hstack((env.uncertain, action)), 1/7) + jl.reward_normalized_past_amort(np.hstack((env.uncertain, action)), 1/7))/ 5
    action, _states = model.predict(obs, deterministic=True)
    obs, reward, terminated, truncated, info = env.step(action)
    forth_rewards[i] = (reward + jl.reward_normalized_past_amort(np.hstack((env.uncertain, action)), 1/7) + jl.reward_normalized_past_amort(np.hstack((env.uncertain, action)), 1/7) + jl.reward_normalized_past_amort(np.hstack((env.uncertain, action)), 1/7) + jl.reward_normalized_past_amort(np.hstack((env.uncertain, action)), 1/7))/ 5
    action, _states = model.predict(obs, deterministic=True)
    obs, reward, terminated, truncated, info = env.step(action)
    fifth_rewards[i] = (reward + jl.reward_normalized_past_amort(np.hstack((env.uncertain, action)), 1/7) + jl.reward_normalized_past_amort(np.hstack((env.uncertain, action)), 1/7) + jl.reward_normalized_past_amort(np.hstack((env.uncertain, action)), 1/7) + jl.reward_normalized_past_amort(np.hstack((env.uncertain, action)), 1/7))/ 5

# %%
#plot boxplot seaborn
plt.figure(figsize=(10, 6))
sns.boxplot(data=[first_rewards, second_rewards, third_rewards,forth_rewards, fifth_rewards],showmeans=True)
plt.xlabel("Design", fontsize=18)
plt.ylabel("Reward", fontsize=18)
# Set y-axis range
plt.ylim(0, 1.5)
plt.tight_layout()
sns.despine()
plt.savefig("box_0_-1.pdf", format="pdf")

# %%
#plot boxplot seaborn
plt.figure(figsize=(10, 6))
sns.boxplot(data=[first_rewards, second_rewards, third_rewards,forth_rewards, fifth_rewards],showmeans=True)
plt.xlabel("Design", fontsize=18)
plt.ylabel("Reward", fontsize=18)

# %%
env = Monitor(env, filename=log_dir)

model = PPO.load(model_path, env=env)

model.learn(total_timesteps=500000)
# Out:
# Wrapping the env in a DummyVecEnv.
# Logging to logs/rl_repressilator_past_amort_multi_step_frame_5/PPO_2
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 5        |
# |    ep_rew_mean     | 4.8      |
# | time/              |          |
# |    fps             | 21       |
# |    iterations      | 1        |
# |    time_elapsed    | 94       |
# |    total_timesteps | 2048     |
# ---------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 5         |
# |    ep_rew_mean          | 4.85      |
# | time/                   |           |
# |    fps                  | 19        |
# |    iterations           | 2         |
# |    time_elapsed         | 212       |
# |    total_timesteps      | 4096      |
# | train/                  |           |
# |    approx_kl            | 1.2182374 |
# |    clip_fraction        | 0.757     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | 6.69      |
# |    explained_variance   | 0.955     |
# |    learning_rate        | 0.0003    |
# |    loss                 | -0.0578   |
# |    n_updates            | 2460      |
# |    policy_gradient_loss | -0.0297   |
# |    std                  | 0.0479    |
# |    value_loss           | 0.0737    |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 5         |
# |    ep_rew_mean          | 4.71      |
# | time/                   |           |
# |    fps                  | 18        |
# |    iterations           | 3         |
# |    time_elapsed         | 331       |
# |    total_timesteps      | 6144      |
# | train/                  |           |
# |    approx_kl            | 1.8197908 |
# |    clip_fraction        | 0.755     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | 6.69      |
# |    explained_variance   | 0.95      |
# |    learning_rate        | 0.0003    |
# |    loss                 | -0.00848  |
# |    n_updates            | 2470      |
# |    policy_gradient_loss | -0.00942  |
# |    std                  | 0.0479    |
# |    value_loss           | 0.084     |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 5         |
# |    ep_rew_mean          | 4.77      |
# | time/                   |           |
# |    fps                  | 18        |
# |    iterations           | 4         |
# |    time_elapsed         | 450       |
# |    total_timesteps      | 8192      |
# | train/                  |           |
# |    approx_kl            | 1.5281863 |
# |    clip_fraction        | 0.758     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | 6.7       |
# |    explained_variance   | 0.948     |
# |    learning_rate        | 0.0003    |
# |    loss                 | -0.0282   |
# |    n_updates            | 2480      |
# |    policy_gradient_loss | -0.00769  |
# |    std                  | 0.0477    |
# |    value_loss           | 0.0855    |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 5         |
# |    ep_rew_mean          | 4.8       |
# | time/                   |           |
# |    fps                  | 17        |
# |    iterations           | 5         |
# |    time_elapsed         | 570       |
# |    total_timesteps      | 10240     |
# | train/                  |           |
# |    approx_kl            | 1.3104863 |
# |    clip_fraction        | 0.759     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | 6.73      |
# |    explained_variance   | 0.948     |
# |    learning_rate        | 0.0003    |
# |    loss                 | -0.0291   |
# |    n_updates            | 2490      |
# |    policy_gradient_loss | -0.0203   |
# |    std                  | 0.0472    |
# |    value_loss           | 0.087     |
# ---------------------------------------
# --------------------------------------
# | rollout/                |          |
# |    ep_len_mean          | 5        |
# |    ep_rew_mean          | 4.81     |
# | time/                   |          |
# |    fps                  | 17       |
# |    iterations           | 6        |
# |    time_elapsed         | 689      |
# |    total_timesteps      | 12288    |
# | train/                  |          |
# |    approx_kl            | 1.541893 |
# |    clip_fraction        | 0.757    |
# |    clip_range           | 0.2      |
# |    entropy_loss         | 6.76     |
# |    explained_variance   | 0.953    |
# |    learning_rate        | 0.0003   |
# |    loss                 | -0.0583  |
# |    n_updates            | 2500     |
# |    policy_gradient_loss | -0.029   |
# |    std                  | 0.0468   |
# |    value_loss           | 0.08     |
# --------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 5         |
# |    ep_rew_mean          | 4.8       |
# | time/                   |           |
# |    fps                  | 17        |
# |    iterations           | 7         |
# |    time_elapsed         | 807       |
# |    total_timesteps      | 14336     |
# | train/                  |           |
# |    approx_kl            | 1.3851264 |
# |    clip_fraction        | 0.753     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | 6.79      |
# |    explained_variance   | 0.953     |
# |    learning_rate        | 0.0003    |
# |    loss                 | -0.0276   |
# |    n_updates            | 2510      |
# |    policy_gradient_loss | -0.0163   |
# |    std                  | 0.0464    |
# |    value_loss           | 0.0772    |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 5         |
# |    ep_rew_mean          | 4.82      |
# | time/                   |           |
# |    fps                  | 17        |
# |    iterations           | 8         |
# |    time_elapsed         | 928       |
# |    total_timesteps      | 16384     |
# | train/                  |           |
# |    approx_kl            | 1.6474016 |
# |    clip_fraction        | 0.742     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | 6.83      |
# |    explained_variance   | 0.95      |
# |    learning_rate        | 0.0003    |
# |    loss                 | -0.0225   |
# |    n_updates            | 2520      |
# |    policy_gradient_loss | -0.0276   |
# |    std                  | 0.0462    |
# |    value_loss           | 0.0838    |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 5         |
# |    ep_rew_mean          | 4.73      |
# | time/                   |           |
# |    fps                  | 17        |
# |    iterations           | 9         |
# |    time_elapsed         | 1047      |
# |    total_timesteps      | 18432     |
# | train/                  |           |
# |    approx_kl            | 1.8839669 |
# |    clip_fraction        | 0.747     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | 6.84      |
# |    explained_variance   | 0.954     |
# |    learning_rate        | 0.0003    |
# |    loss                 | -0.0474   |
# |    n_updates            | 2530      |
# |    policy_gradient_loss | -0.0205   |
# |    std                  | 0.0459    |
# |    value_loss           | 0.0779    |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 5         |
# |    ep_rew_mean          | 4.86      |
# | time/                   |           |
# |    fps                  | 17        |
# |    iterations           | 10        |
# |    time_elapsed         | 1165      |
# |    total_timesteps      | 20480     |
# | train/                  |           |
# |    approx_kl            | 1.5043092 |
# |    clip_fraction        | 0.761     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | 6.85      |
# |    explained_variance   | 0.95      |
# |    learning_rate        | 0.0003    |
# |    loss                 | -0.0547   |
# |    n_updates            | 2540      |
# |    policy_gradient_loss | -0.0223   |
# |    std                  | 0.0458    |
# |    value_loss           | 0.0836    |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 5         |
# |    ep_rew_mean          | 4.83      |
# | time/                   |           |
# |    fps                  | 17        |
# |    iterations           | 11        |
# |    time_elapsed         | 1283      |
# |    total_timesteps      | 22528     |
# | train/                  |           |
# |    approx_kl            | 1.5132699 |
# |    clip_fraction        | 0.758     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | 6.86      |
# |    explained_variance   | 0.953     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0.0109    |
# |    n_updates            | 2550      |
# |    policy_gradient_loss | -0.0289   |
# |    std                  | 0.0455    |
# |    value_loss           | 0.0794    |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 5         |
# |    ep_rew_mean          | 4.78      |
# | time/                   |           |
# |    fps                  | 17        |
# |    iterations           | 12        |
# |    time_elapsed         | 1407      |
# |    total_timesteps      | 24576     |
# | train/                  |           |
# |    approx_kl            | 1.3132071 |
# |    clip_fraction        | 0.763     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | 6.9       |
# |    explained_variance   | 0.957     |
# |    learning_rate        | 0.0003    |
# |    loss                 | -0.0129   |
# |    n_updates            | 2560      |
# |    policy_gradient_loss | -0.0153   |
# |    std                  | 0.0451    |
# |    value_loss           | 0.074     |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 5         |
# |    ep_rew_mean          | 4.86      |
# | time/                   |           |
# |    fps                  | 17        |
# |    iterations           | 13        |
# |    time_elapsed         | 1530      |
# |    total_timesteps      | 26624     |
# | train/                  |           |
# |    approx_kl            | 2.1660001 |
# |    clip_fraction        | 0.762     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | 6.94      |
# |    explained_variance   | 0.954     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0.011     |
# |    n_updates            | 2570      |
# |    policy_gradient_loss | -0.0276   |
# |    std                  | 0.0448    |
# |    value_loss           | 0.0748    |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 5         |
# |    ep_rew_mean          | 4.74      |
# | time/                   |           |
# |    fps                  | 17        |
# |    iterations           | 14        |
# |    time_elapsed         | 1649      |
# |    total_timesteps      | 28672     |
# | train/                  |           |
# |    approx_kl            | 1.6430624 |
# |    clip_fraction        | 0.77      |
# |    clip_range           | 0.2       |
# |    entropy_loss         | 6.95      |
# |    explained_variance   | 0.959     |
# |    learning_rate        | 0.0003    |
# |    loss                 | -0.0803   |
# |    n_updates            | 2580      |
# |    policy_gradient_loss | -0.0109   |
# |    std                  | 0.0448    |
# |    value_loss           | 0.069     |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 5         |
# |    ep_rew_mean          | 4.79      |
# | time/                   |           |
# |    fps                  | 17        |
# |    iterations           | 15        |
# |    time_elapsed         | 1768      |
# |    total_timesteps      | 30720     |
# | train/                  |           |
# |    approx_kl            | 1.6163027 |
# |    clip_fraction        | 0.755     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | 6.95      |
# |    explained_variance   | 0.955     |
# |    learning_rate        | 0.0003    |
# |    loss                 | -0.0352   |
# |    n_updates            | 2590      |
# |    policy_gradient_loss | -0.0145   |
# |    std                  | 0.0447    |
# |    value_loss           | 0.0759    |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 5         |
# |    ep_rew_mean          | 4.77      |
# | time/                   |           |
# |    fps                  | 17        |
# |    iterations           | 16        |
# |    time_elapsed         | 1889      |
# |    total_timesteps      | 32768     |
# | train/                  |           |
# |    approx_kl            | 1.3857303 |
# |    clip_fraction        | 0.754     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | 6.97      |
# |    explained_variance   | 0.955     |
# |    learning_rate        | 0.0003    |
# |    loss                 | -0.0764   |
# |    n_updates            | 2600      |
# |    policy_gradient_loss | -0.0176   |
# |    std                  | 0.0444    |
# |    value_loss           | 0.0753    |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 5         |
# |    ep_rew_mean          | 4.71      |
# | time/                   |           |
# |    fps                  | 17        |
# |    iterations           | 17        |
# |    time_elapsed         | 2010      |
# |    total_timesteps      | 34816     |
# | train/                  |           |
# |    approx_kl            | 1.3453693 |
# |    clip_fraction        | 0.757     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | 7         |
# |    explained_variance   | 0.954     |
# |    learning_rate        | 0.0003    |
# |    loss                 | -0.0309   |
# |    n_updates            | 2610      |
# |    policy_gradient_loss | -0.0246   |
# |    std                  | 0.0443    |
# |    value_loss           | 0.0788    |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 5         |
# |    ep_rew_mean          | 4.76      |
# | time/                   |           |
# |    fps                  | 17        |
# |    iterations           | 18        |
# |    time_elapsed         | 2131      |
# |    total_timesteps      | 36864     |
# | train/                  |           |
# |    approx_kl            | 1.4928346 |
# |    clip_fraction        | 0.752     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | 7.01      |
# |    explained_variance   | 0.955     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0.00703   |
# |    n_updates            | 2620      |
# |    policy_gradient_loss | -0.0247   |
# |    std                  | 0.044     |
# |    value_loss           | 0.0781    |
# ---------------------------------------
# --------------------------------------
# | rollout/                |          |
# |    ep_len_mean          | 5        |
# |    ep_rew_mean          | 4.76     |
# | time/                   |          |
# |    fps                  | 17       |
# |    iterations           | 19       |
# |    time_elapsed         | 2253     |
# |    total_timesteps      | 38912    |
# | train/                  |          |
# |    approx_kl            | 1.548518 |
# |    clip_fraction        | 0.766    |
# |    clip_range           | 0.2      |
# |    entropy_loss         | 7.04     |
# |    explained_variance   | 0.958    |
# |    learning_rate        | 0.0003   |
# |    loss                 | -0.0348  |
# |    n_updates            | 2630     |
# |    policy_gradient_loss | -0.0154  |
# |    std                  | 0.0438   |
# |    value_loss           | 0.0735   |
# --------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 5         |
# |    ep_rew_mean          | 4.81      |
# | time/                   |           |
# |    fps                  | 17        |
# |    iterations           | 20        |
# |    time_elapsed         | 2375      |
# |    total_timesteps      | 40960     |
# | train/                  |           |
# |    approx_kl            | 1.5455428 |
# |    clip_fraction        | 0.763     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | 7.05      |
# |    explained_variance   | 0.955     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0.0171    |
# |    n_updates            | 2640      |
# |    policy_gradient_loss | -0.0138   |
# |    std                  | 0.0438    |
# |    value_loss           | 0.0794    |
# ---------------------------------------
# --------------------------------------
# | rollout/                |          |
# |    ep_len_mean          | 5        |
# |    ep_rew_mean          | 4.72     |
# | time/                   |          |
# |    fps                  | 17       |
# |    iterations           | 21       |
# |    time_elapsed         | 2496     |
# |    total_timesteps      | 43008    |
# | train/                  |          |
# |    approx_kl            | 1.42342  |
# |    clip_fraction        | 0.76     |
# |    clip_range           | 0.2      |
# |    entropy_loss         | 7.06     |
# |    explained_variance   | 0.951    |
# |    learning_rate        | 0.0003   |
# |    loss                 | -0.0795  |
# |    n_updates            | 2650     |
# |    policy_gradient_loss | -0.016   |
# |    std                  | 0.0436   |
# |    value_loss           | 0.0821   |
# --------------------------------------
# --------------------------------------
# | rollout/                |          |
# |    ep_len_mean          | 5        |
# |    ep_rew_mean          | 4.77     |
# | time/                   |          |
# |    fps                  | 17       |
# |    iterations           | 22       |
# |    time_elapsed         | 2614     |
# |    total_timesteps      | 45056    |
# | train/                  |          |
# |    approx_kl            | 1.34515  |
# |    clip_fraction        | 0.778    |
# |    clip_range           | 0.2      |
# |    entropy_loss         | 7.05     |
# |    explained_variance   | 0.946    |
# |    learning_rate        | 0.0003   |
# |    loss                 | -0.0486  |
# |    n_updates            | 2660     |
# |    policy_gradient_loss | -0.00154 |
# |    std                  | 0.0437   |
# |    value_loss           | 0.0904   |
# --------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 5         |
# |    ep_rew_mean          | 4.79      |
# | time/                   |           |
# |    fps                  | 17        |
# |    iterations           | 23        |
# |    time_elapsed         | 2730      |
# |    total_timesteps      | 47104     |
# | train/                  |           |
# |    approx_kl            | 1.2532669 |
# |    clip_fraction        | 0.76      |
# |    clip_range           | 0.2       |
# |    entropy_loss         | 7.06      |
# |    explained_variance   | 0.958     |
# |    learning_rate        | 0.0003    |
# |    loss                 | -0.0371   |
# |    n_updates            | 2670      |
# |    policy_gradient_loss | -0.0117   |
# |    std                  | 0.0434    |
# |    value_loss           | 0.0726    |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 5         |
# |    ep_rew_mean          | 4.72      |
# | time/                   |           |
# |    fps                  | 17        |
# |    iterations           | 24        |
# |    time_elapsed         | 2851      |
# |    total_timesteps      | 49152     |
# | train/                  |           |
# |    approx_kl            | 1.7904352 |
# |    clip_fraction        | 0.747     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | 7.09      |
# |    explained_variance   | 0.954     |
# |    learning_rate        | 0.0003    |
# |    loss                 | -0.0299   |
# |    n_updates            | 2680      |
# |    policy_gradient_loss | -0.0279   |
# |    std                  | 0.0428    |
# |    value_loss           | 0.0777    |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 5         |
# |    ep_rew_mean          | 4.76      |
# | time/                   |           |
# |    fps                  | 17        |
# |    iterations           | 25        |
# |    time_elapsed         | 2971      |
# |    total_timesteps      | 51200     |
# | train/                  |           |
# |    approx_kl            | 1.6189973 |
# |    clip_fraction        | 0.773     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | 7.11      |
# |    explained_variance   | 0.95      |
# |    learning_rate        | 0.0003    |
# |    loss                 | -0.00271  |
# |    n_updates            | 2690      |
# |    policy_gradient_loss | -0.000685 |
# |    std                  | 0.0428    |
# |    value_loss           | 0.0844    |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 5         |
# |    ep_rew_mean          | 4.75      |
# | time/                   |           |
# |    fps                  | 17        |
# |    iterations           | 26        |
# |    time_elapsed         | 3100      |
# |    total_timesteps      | 53248     |
# | train/                  |           |
# |    approx_kl            | 1.9167566 |
# |    clip_fraction        | 0.76      |
# |    clip_range           | 0.2       |
# |    entropy_loss         | 7.14      |
# |    explained_variance   | 0.953     |
# |    learning_rate        | 0.0003    |
# |    loss                 | -0.0626   |
# |    n_updates            | 2700      |
# |    policy_gradient_loss | -0.0288   |
# |    std                  | 0.0424    |
# |    value_loss           | 0.0814    |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 5         |
# |    ep_rew_mean          | 4.73      |
# | time/                   |           |
# |    fps                  | 17        |
# |    iterations           | 27        |
# |    time_elapsed         | 3234      |
# |    total_timesteps      | 55296     |
# | train/                  |           |
# |    approx_kl            | 1.4753938 |
# |    clip_fraction        | 0.756     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | 7.18      |
# |    explained_variance   | 0.952     |
# |    learning_rate        | 0.0003    |
# |    loss                 | -0.00288  |
# |    n_updates            | 2710      |
# |    policy_gradient_loss | -0.0171   |
# |    std                  | 0.042     |
# |    value_loss           | 0.082     |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 5         |
# |    ep_rew_mean          | 4.82      |
# | time/                   |           |
# |    fps                  | 17        |
# |    iterations           | 28        |
# |    time_elapsed         | 3362      |
# |    total_timesteps      | 57344     |
# | train/                  |           |
# |    approx_kl            | 1.4985074 |
# |    clip_fraction        | 0.746     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | 7.21      |
# |    explained_variance   | 0.955     |
# |    learning_rate        | 0.0003    |
# |    loss                 | -0.0563   |
# |    n_updates            | 2720      |
# |    policy_gradient_loss | -0.0209   |
# |    std                  | 0.0416    |
# |    value_loss           | 0.0763    |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 5         |
# |    ep_rew_mean          | 4.79      |
# | time/                   |           |
# |    fps                  | 17        |
# |    iterations           | 29        |
# |    time_elapsed         | 3492      |
# |    total_timesteps      | 59392     |
# | train/                  |           |
# |    approx_kl            | 1.3691335 |
# |    clip_fraction        | 0.756     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | 7.25      |
# |    explained_variance   | 0.954     |
# |    learning_rate        | 0.0003    |
# |    loss                 | -0.0764   |
# |    n_updates            | 2730      |
# |    policy_gradient_loss | -0.0159   |
# |    std                  | 0.0412    |
# |    value_loss           | 0.08      |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 5         |
# |    ep_rew_mean          | 4.82      |
# | time/                   |           |
# |    fps                  | 16        |
# |    iterations           | 30        |
# |    time_elapsed         | 3616      |
# |    total_timesteps      | 61440     |
# | train/                  |           |
# |    approx_kl            | 1.5086014 |
# |    clip_fraction        | 0.765     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | 7.28      |
# |    explained_variance   | 0.954     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0.00896   |
# |    n_updates            | 2740      |
# |    policy_gradient_loss | -0.00182  |
# |    std                  | 0.041     |
# |    value_loss           | 0.0784    |
# ---------------------------------------
# --------------------------------------
# | rollout/                |          |
# |    ep_len_mean          | 5        |
# |    ep_rew_mean          | 4.75     |
# | time/                   |          |
# |    fps                  | 16       |
# |    iterations           | 31       |
# |    time_elapsed         | 3735     |
# |    total_timesteps      | 63488    |
# | train/                  |          |
# |    approx_kl            | 1.393042 |
# |    clip_fraction        | 0.762    |
# |    clip_range           | 0.2      |
# |    entropy_loss         | 7.31     |
# |    explained_variance   | 0.952    |
# |    learning_rate        | 0.0003   |
# |    loss                 | -0.0347  |
# |    n_updates            | 2750     |
# |    policy_gradient_loss | -0.0112  |
# |    std                  | 0.0406   |
# |    value_loss           | 0.0787   |
# --------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 5         |
# |    ep_rew_mean          | 4.8       |
# | time/                   |           |
# |    fps                  | 17        |
# |    iterations           | 32        |
# |    time_elapsed         | 3852      |
# |    total_timesteps      | 65536     |
# | train/                  |           |
# |    approx_kl            | 1.3095434 |
# |    clip_fraction        | 0.766     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | 7.33      |
# |    explained_variance   | 0.949     |
# |    learning_rate        | 0.0003    |
# |    loss                 | -0.0455   |
# |    n_updates            | 2760      |
# |    policy_gradient_loss | 0.000464  |
# |    std                  | 0.0405    |
# |    value_loss           | 0.0879    |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 5         |
# |    ep_rew_mean          | 4.8       |
# | time/                   |           |
# |    fps                  | 17        |
# |    iterations           | 33        |
# |    time_elapsed         | 3969      |
# |    total_timesteps      | 67584     |
# | train/                  |           |
# |    approx_kl            | 1.4041137 |
# |    clip_fraction        | 0.764     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | 7.36      |
# |    explained_variance   | 0.954     |
# |    learning_rate        | 0.0003    |
# |    loss                 | -0.0388   |
# |    n_updates            | 2770      |
# |    policy_gradient_loss | 0.00263   |
# |    std                  | 0.0402    |
# |    value_loss           | 0.0778    |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 5         |
# |    ep_rew_mean          | 4.84      |
# | time/                   |           |
# |    fps                  | 17        |
# |    iterations           | 34        |
# |    time_elapsed         | 4087      |
# |    total_timesteps      | 69632     |
# | train/                  |           |
# |    approx_kl            | 1.4448776 |
# |    clip_fraction        | 0.749     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | 7.38      |
# |    explained_variance   | 0.952     |
# |    learning_rate        | 0.0003    |
# |    loss                 | -0.0148   |
# |    n_updates            | 2780      |
# |    policy_gradient_loss | -0.0142   |
# |    std                  | 0.0402    |
# |    value_loss           | 0.085     |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 5         |
# |    ep_rew_mean          | 4.72      |
# | time/                   |           |
# |    fps                  | 17        |
# |    iterations           | 35        |
# |    time_elapsed         | 4206      |
# |    total_timesteps      | 71680     |
# | train/                  |           |
# |    approx_kl            | 1.5481272 |
# |    clip_fraction        | 0.778     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | 7.37      |
# |    explained_variance   | 0.952     |
# |    learning_rate        | 0.0003    |
# |    loss                 | -0.0155   |
# |    n_updates            | 2790      |
# |    policy_gradient_loss | -0.0095   |
# |    std                  | 0.0403    |
# |    value_loss           | 0.0859    |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 5         |
# |    ep_rew_mean          | 4.75      |
# | time/                   |           |
# |    fps                  | 17        |
# |    iterations           | 36        |
# |    time_elapsed         | 4325      |
# |    total_timesteps      | 73728     |
# | train/                  |           |
# |    approx_kl            | 2.0529904 |
# |    clip_fraction        | 0.758     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | 7.37      |
# |    explained_variance   | 0.945     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0.0265    |
# |    n_updates            | 2800      |
# |    policy_gradient_loss | -0.00752  |
# |    std                  | 0.0401    |
# |    value_loss           | 0.0944    |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 5         |
# |    ep_rew_mean          | 4.75      |
# | time/                   |           |
# |    fps                  | 17        |
# |    iterations           | 37        |
# |    time_elapsed         | 4446      |
# |    total_timesteps      | 75776     |
# | train/                  |           |
# |    approx_kl            | 1.5981135 |
# |    clip_fraction        | 0.767     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | 7.39      |
# |    explained_variance   | 0.952     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0.0134    |
# |    n_updates            | 2810      |
# |    policy_gradient_loss | -0.00296  |
# |    std                  | 0.0399    |
# |    value_loss           | 0.0838    |
# ---------------------------------------
# --------------------------------------
# | rollout/                |          |
# |    ep_len_mean          | 5        |
# |    ep_rew_mean          | 4.76     |
# | time/                   |          |
# |    fps                  | 17       |
# |    iterations           | 38       |
# |    time_elapsed         | 4565     |
# |    total_timesteps      | 77824    |
# | train/                  |          |
# |    approx_kl            | 1.509196 |
# |    clip_fraction        | 0.782    |
# |    clip_range           | 0.2      |
# |    entropy_loss         | 7.4      |
# |    explained_variance   | 0.95     |
# |    learning_rate        | 0.0003   |
# |    loss                 | -0.00968 |
# |    n_updates            | 2820     |
# |    policy_gradient_loss | 0.0199   |
# |    std                  | 0.0398   |
# |    value_loss           | 0.088    |
# --------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 5         |
# |    ep_rew_mean          | 4.76      |
# | time/                   |           |
# |    fps                  | 17        |
# |    iterations           | 39        |
# |    time_elapsed         | 4684      |
# |    total_timesteps      | 79872     |
# | train/                  |           |
# |    approx_kl            | 1.7297598 |
# |    clip_fraction        | 0.766     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | 7.42      |
# |    explained_variance   | 0.956     |
# |    learning_rate        | 0.0003    |
# |    loss                 | -0.0379   |
# |    n_updates            | 2830      |
# |    policy_gradient_loss | -0.00676  |
# |    std                  | 0.0396    |
# |    value_loss           | 0.0756    |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 5         |
# |    ep_rew_mean          | 4.88      |
# | time/                   |           |
# |    fps                  | 17        |
# |    iterations           | 40        |
# |    time_elapsed         | 4803      |
# |    total_timesteps      | 81920     |
# | train/                  |           |
# |    approx_kl            | 1.5905979 |
# |    clip_fraction        | 0.771     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | 7.44      |
# |    explained_variance   | 0.949     |
# |    learning_rate        | 0.0003    |
# |    loss                 | -0.0208   |
# |    n_updates            | 2840      |
# |    policy_gradient_loss | -0.0203   |
# |    std                  | 0.0393    |
# |    value_loss           | 0.0864    |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 5         |
# |    ep_rew_mean          | 4.73      |
# | time/                   |           |
# |    fps                  | 17        |
# |    iterations           | 41        |
# |    time_elapsed         | 4924      |
# |    total_timesteps      | 83968     |
# | train/                  |           |
# |    approx_kl            | 1.6947012 |
# |    clip_fraction        | 0.785     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | 7.47      |
# |    explained_variance   | 0.959     |
# |    learning_rate        | 0.0003    |
# |    loss                 | -0.0615   |
# |    n_updates            | 2850      |
# |    policy_gradient_loss | 0.0135    |
# |    std                  | 0.0388    |
# |    value_loss           | 0.0725    |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 5         |
# |    ep_rew_mean          | 4.76      |
# | time/                   |           |
# |    fps                  | 17        |
# |    iterations           | 42        |
# |    time_elapsed         | 5050      |
# |    total_timesteps      | 86016     |
# | train/                  |           |
# |    approx_kl            | 1.8165843 |
# |    clip_fraction        | 0.771     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | 7.49      |
# |    explained_variance   | 0.951     |
# |    learning_rate        | 0.0003    |
# |    loss                 | -0.0666   |
# |    n_updates            | 2860      |
# |    policy_gradient_loss | 0.00205   |
# |    std                  | 0.0388    |
# |    value_loss           | 0.0853    |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 5         |
# |    ep_rew_mean          | 4.8       |
# | time/                   |           |
# |    fps                  | 17        |
# |    iterations           | 43        |
# |    time_elapsed         | 5173      |
# |    total_timesteps      | 88064     |
# | train/                  |           |
# |    approx_kl            | 1.7178624 |
# |    clip_fraction        | 0.798     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | 7.48      |
# |    explained_variance   | 0.959     |
# |    learning_rate        | 0.0003    |
# |    loss                 | -0.00276  |
# |    n_updates            | 2870      |
# |    policy_gradient_loss | 0.0234    |
# |    std                  | 0.039     |
# |    value_loss           | 0.073     |
# ---------------------------------------
# --------------------------------------
# | rollout/                |          |
# |    ep_len_mean          | 5        |
# |    ep_rew_mean          | 4.79     |
# | time/                   |          |
# |    fps                  | 17       |
# |    iterations           | 44       |
# |    time_elapsed         | 5298     |
# |    total_timesteps      | 90112    |
# | train/                  |          |
# |    approx_kl            | 2.087168 |
# |    clip_fraction        | 0.768    |
# |    clip_range           | 0.2      |
# |    entropy_loss         | 7.48     |
# |    explained_variance   | 0.955    |
# |    learning_rate        | 0.0003   |
# |    loss                 | -0.0689  |
# |    n_updates            | 2880     |
# |    policy_gradient_loss | -0.0141  |
# |    std                  | 0.0388   |
# |    value_loss           | 0.0791   |
# --------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 5         |
# |    ep_rew_mean          | 4.8       |
# | time/                   |           |
# |    fps                  | 17        |
# |    iterations           | 45        |
# |    time_elapsed         | 5420      |
# |    total_timesteps      | 92160     |
# | train/                  |           |
# |    approx_kl            | 1.5314949 |
# |    clip_fraction        | 0.764     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | 7.5       |
# |    explained_variance   | 0.959     |
# |    learning_rate        | 0.0003    |
# |    loss                 | -0.0267   |
# |    n_updates            | 2890      |
# |    policy_gradient_loss | -0.0198   |
# |    std                  | 0.0386    |
# |    value_loss           | 0.073     |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 5         |
# |    ep_rew_mean          | 4.75      |
# | time/                   |           |
# |    fps                  | 16        |
# |    iterations           | 46        |
# |    time_elapsed         | 5542      |
# |    total_timesteps      | 94208     |
# | train/                  |           |
# |    approx_kl            | 1.3785238 |
# |    clip_fraction        | 0.779     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | 7.52      |
# |    explained_variance   | 0.951     |
# |    learning_rate        | 0.0003    |
# |    loss                 | -0.0389   |
# |    n_updates            | 2900      |
# |    policy_gradient_loss | 0.00199   |
# |    std                  | 0.0383    |
# |    value_loss           | 0.0888    |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 5         |
# |    ep_rew_mean          | 4.76      |
# | time/                   |           |
# |    fps                  | 17        |
# |    iterations           | 47        |
# |    time_elapsed         | 5661      |
# |    total_timesteps      | 96256     |
# | train/                  |           |
# |    approx_kl            | 1.7702965 |
# |    clip_fraction        | 0.743     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | 7.56      |
# |    explained_variance   | 0.952     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0.0414    |
# |    n_updates            | 2910      |
# |    policy_gradient_loss | -0.0223   |
# |    std                  | 0.0379    |
# |    value_loss           | 0.0848    |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 5         |
# |    ep_rew_mean          | 4.78      |
# | time/                   |           |
# |    fps                  | 16        |
# |    iterations           | 48        |
# |    time_elapsed         | 5782      |
# |    total_timesteps      | 98304     |
# | train/                  |           |
# |    approx_kl            | 1.7064841 |
# |    clip_fraction        | 0.762     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | 7.59      |
# |    explained_variance   | 0.953     |
# |    learning_rate        | 0.0003    |
# |    loss                 | -0.0353   |
# |    n_updates            | 2920      |
# |    policy_gradient_loss | -0.0088   |
# |    std                  | 0.0376    |
# |    value_loss           | 0.0824    |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 5         |
# |    ep_rew_mean          | 4.68      |
# | time/                   |           |
# |    fps                  | 16        |
# |    iterations           | 49        |
# |    time_elapsed         | 5910      |
# |    total_timesteps      | 100352    |
# | train/                  |           |
# |    approx_kl            | 1.6604176 |
# |    clip_fraction        | 0.793     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | 7.59      |
# |    explained_variance   | 0.956     |
# |    learning_rate        | 0.0003    |
# |    loss                 | -0.046    |
# |    n_updates            | 2930      |
# |    policy_gradient_loss | 0.025     |
# |    std                  | 0.0376    |
# |    value_loss           | 0.0762    |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 5         |
# |    ep_rew_mean          | 4.73      |
# | time/                   |           |
# |    fps                  | 16        |
# |    iterations           | 50        |
# |    time_elapsed         | 6033      |
# |    total_timesteps      | 102400    |
# | train/                  |           |
# |    approx_kl            | 2.5308642 |
# |    clip_fraction        | 0.764     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | 7.6       |
# |    explained_variance   | 0.955     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0.000436  |
# |    n_updates            | 2940      |
# |    policy_gradient_loss | -0.0134   |
# |    std                  | 0.0373    |
# |    value_loss           | 0.0806    |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 5         |
# |    ep_rew_mean          | 4.7       |
# | time/                   |           |
# |    fps                  | 16        |
# |    iterations           | 51        |
# |    time_elapsed         | 6154      |
# |    total_timesteps      | 104448    |
# | train/                  |           |
# |    approx_kl            | 1.9091052 |
# |    clip_fraction        | 0.78      |
# |    clip_range           | 0.2       |
# |    entropy_loss         | 7.63      |
# |    explained_variance   | 0.953     |
# |    learning_rate        | 0.0003    |
# |    loss                 | -0.034    |
# |    n_updates            | 2950      |
# |    policy_gradient_loss | 0.0113    |
# |    std                  | 0.0372    |
# |    value_loss           | 0.0813    |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 5         |
# |    ep_rew_mean          | 4.9       |
# | time/                   |           |
# |    fps                  | 16        |
# |    iterations           | 52        |
# |    time_elapsed         | 6275      |
# |    total_timesteps      | 106496    |
# | train/                  |           |
# |    approx_kl            | 2.0304856 |
# |    clip_fraction        | 0.794     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | 7.64      |
# |    explained_variance   | 0.949     |
# |    learning_rate        | 0.0003    |
# |    loss                 | -0.0569   |
# |    n_updates            | 2960      |
# |    policy_gradient_loss | 0.038     |
# |    std                  | 0.0372    |
# |    value_loss           | 0.0885    |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 5         |
# |    ep_rew_mean          | 4.84      |
# | time/                   |           |
# |    fps                  | 16        |
# |    iterations           | 53        |
# |    time_elapsed         | 6397      |
# |    total_timesteps      | 108544    |
# | train/                  |           |
# |    approx_kl            | 2.1349168 |
# |    clip_fraction        | 0.771     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | 7.65      |
# |    explained_variance   | 0.949     |
# |    learning_rate        | 0.0003    |
# |    loss                 | -0.0108   |
# |    n_updates            | 2970      |
# |    policy_gradient_loss | -0.00237  |
# |    std                  | 0.037     |
# |    value_loss           | 0.0891    |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 5         |
# |    ep_rew_mean          | 4.76      |
# | time/                   |           |
# |    fps                  | 16        |
# |    iterations           | 54        |
# |    time_elapsed         | 6518      |
# |    total_timesteps      | 110592    |
# | train/                  |           |
# |    approx_kl            | 1.9837639 |
# |    clip_fraction        | 0.773     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | 7.66      |
# |    explained_variance   | 0.959     |
# |    learning_rate        | 0.0003    |
# |    loss                 | -0.0695   |
# |    n_updates            | 2980      |
# |    policy_gradient_loss | -0.00452  |
# |    std                  | 0.037     |
# |    value_loss           | 0.0735    |
# ---------------------------------------
# --------------------------------------
# | rollout/                |          |
# |    ep_len_mean          | 5        |
# |    ep_rew_mean          | 4.87     |
# | time/                   |          |
# |    fps                  | 16       |
# |    iterations           | 55       |
# |    time_elapsed         | 6641     |
# |    total_timesteps      | 112640   |
# | train/                  |          |
# |    approx_kl            | 1.529076 |
# |    clip_fraction        | 0.767    |
# |    clip_range           | 0.2      |
# |    entropy_loss         | 7.67     |
# |    explained_variance   | 0.954    |
# |    learning_rate        | 0.0003   |
# |    loss                 | -0.0101  |
# |    n_updates            | 2990     |
# |    policy_gradient_loss | 0.00452  |
# |    std                  | 0.0369   |
# |    value_loss           | 0.0813   |
# --------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 5         |
# |    ep_rew_mean          | 4.78      |
# | time/                   |           |
# ...
# |    policy_gradient_loss | 0.0151    |
# |    std                  | 0.0251    |
# |    value_loss           | 0.0741    |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 5         |
# |    ep_rew_mean          | 4.84      |
# | time/                   |           |
# |    fps                  | 16        |
# |    iterations           | 228       |
# |    time_elapsed         | 28107     |
# |    total_timesteps      | 466944    |
# | train/                  |           |
# |    approx_kl            | 1.7547964 |
# |    clip_fraction        | 0.78      |
# |    clip_range           | 0.2       |
# |    entropy_loss         | 9.14      |
# |    explained_variance   | 0.965     |
# |    learning_rate        | 0.0003    |
# |    loss                 | -0.0548   |
# |    n_updates            | 4720      |
# |    policy_gradient_loss | 0.00394   |
# |    std                  | 0.0249    |
# |    value_loss           | 0.0631    |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 5         |
# |    ep_rew_mean          | 4.84      |
# | time/                   |           |
# |    fps                  | 16        |
# |    iterations           | 229       |
# |    time_elapsed         | 28222     |
# |    total_timesteps      | 468992    |
# | train/                  |           |
# |    approx_kl            | 1.3934345 |
# |    clip_fraction        | 0.785     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | 9.13      |
# |    explained_variance   | 0.961     |
# |    learning_rate        | 0.0003    |
# |    loss                 | -0.032    |
# |    n_updates            | 4730      |
# |    policy_gradient_loss | 0.0239    |
# |    std                  | 0.025     |
# |    value_loss           | 0.0705    |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 5         |
# |    ep_rew_mean          | 4.83      |
# | time/                   |           |
# |    fps                  | 16        |
# |    iterations           | 230       |
# |    time_elapsed         | 28338     |
# |    total_timesteps      | 471040    |
# | train/                  |           |
# |    approx_kl            | 1.7919824 |
# |    clip_fraction        | 0.788     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | 9.14      |
# |    explained_variance   | 0.965     |
# |    learning_rate        | 0.0003    |
# |    loss                 | -0.0431   |
# |    n_updates            | 4740      |
# |    policy_gradient_loss | 0.00679   |
# |    std                  | 0.025     |
# |    value_loss           | 0.0641    |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 5         |
# |    ep_rew_mean          | 4.8       |
# | time/                   |           |
# |    fps                  | 16        |
# |    iterations           | 231       |
# |    time_elapsed         | 28454     |
# |    total_timesteps      | 473088    |
# | train/                  |           |
# |    approx_kl            | 2.9292123 |
# |    clip_fraction        | 0.765     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | 9.16      |
# |    explained_variance   | 0.955     |
# |    learning_rate        | 0.0003    |
# |    loss                 | -0.0483   |
# |    n_updates            | 4750      |
# |    policy_gradient_loss | -0.00334  |
# |    std                  | 0.0246    |
# |    value_loss           | 0.0801    |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 5         |
# |    ep_rew_mean          | 4.76      |
# | time/                   |           |
# |    fps                  | 16        |
# |    iterations           | 232       |
# |    time_elapsed         | 28568     |
# |    total_timesteps      | 475136    |
# | train/                  |           |
# |    approx_kl            | 1.6431887 |
# |    clip_fraction        | 0.787     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | 9.2       |
# |    explained_variance   | 0.962     |
# |    learning_rate        | 0.0003    |
# |    loss                 | -0.0836   |
# |    n_updates            | 4760      |
# |    policy_gradient_loss | 0.00584   |
# |    std                  | 0.0246    |
# |    value_loss           | 0.0683    |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 5         |
# |    ep_rew_mean          | 4.86      |
# | time/                   |           |
# |    fps                  | 16        |
# |    iterations           | 233       |
# |    time_elapsed         | 28684     |
# |    total_timesteps      | 477184    |
# | train/                  |           |
# |    approx_kl            | 1.6743929 |
# |    clip_fraction        | 0.783     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | 9.19      |
# |    explained_variance   | 0.956     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0.0284    |
# |    n_updates            | 4770      |
# |    policy_gradient_loss | 0.0158    |
# |    std                  | 0.0247    |
# |    value_loss           | 0.0802    |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 5         |
# |    ep_rew_mean          | 4.92      |
# | time/                   |           |
# |    fps                  | 16        |
# |    iterations           | 234       |
# |    time_elapsed         | 28799     |
# |    total_timesteps      | 479232    |
# | train/                  |           |
# |    approx_kl            | 1.6334167 |
# |    clip_fraction        | 0.784     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | 9.18      |
# |    explained_variance   | 0.96      |
# |    learning_rate        | 0.0003    |
# |    loss                 | -0.0563   |
# |    n_updates            | 4780      |
# |    policy_gradient_loss | 0.0241    |
# |    std                  | 0.0248    |
# |    value_loss           | 0.073     |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 5         |
# |    ep_rew_mean          | 4.85      |
# | time/                   |           |
# |    fps                  | 16        |
# |    iterations           | 235       |
# |    time_elapsed         | 28914     |
# |    total_timesteps      | 481280    |
# | train/                  |           |
# |    approx_kl            | 3.1144462 |
# |    clip_fraction        | 0.802     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | 9.17      |
# |    explained_variance   | 0.966     |
# |    learning_rate        | 0.0003    |
# |    loss                 | -0.00177  |
# |    n_updates            | 4790      |
# |    policy_gradient_loss | 0.0179    |
# |    std                  | 0.0249    |
# |    value_loss           | 0.0632    |
# ---------------------------------------
# --------------------------------------
# | rollout/                |          |
# |    ep_len_mean          | 5        |
# |    ep_rew_mean          | 4.79     |
# | time/                   |          |
# |    fps                  | 16       |
# |    iterations           | 236      |
# |    time_elapsed         | 29030    |
# |    total_timesteps      | 483328   |
# | train/                  |          |
# |    approx_kl            | 1.830071 |
# |    clip_fraction        | 0.785    |
# |    clip_range           | 0.2      |
# |    entropy_loss         | 9.16     |
# |    explained_variance   | 0.962    |
# |    learning_rate        | 0.0003   |
# |    loss                 | -0.00868 |
# |    n_updates            | 4800     |
# |    policy_gradient_loss | 0.00903  |
# |    std                  | 0.0249   |
# |    value_loss           | 0.0684   |
# --------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 5         |
# |    ep_rew_mean          | 4.86      |
# | time/                   |           |
# |    fps                  | 16        |
# |    iterations           | 237       |
# |    time_elapsed         | 29150     |
# |    total_timesteps      | 485376    |
# | train/                  |           |
# |    approx_kl            | 2.1473007 |
# |    clip_fraction        | 0.78      |
# |    clip_range           | 0.2       |
# |    entropy_loss         | 9.17      |
# |    explained_variance   | 0.956     |
# |    learning_rate        | 0.0003    |
# |    loss                 | -0.0041   |
# |    n_updates            | 4810      |
# |    policy_gradient_loss | 0.0213    |
# |    std                  | 0.0247    |
# |    value_loss           | 0.0795    |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 5         |
# |    ep_rew_mean          | 4.84      |
# | time/                   |           |
# |    fps                  | 16        |
# |    iterations           | 238       |
# |    time_elapsed         | 29266     |
# |    total_timesteps      | 487424    |
# | train/                  |           |
# |    approx_kl            | 1.6509888 |
# |    clip_fraction        | 0.777     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | 9.2       |
# |    explained_variance   | 0.959     |
# |    learning_rate        | 0.0003    |
# |    loss                 | -0.0698   |
# |    n_updates            | 4820      |
# |    policy_gradient_loss | -0.00548  |
# |    std                  | 0.0246    |
# |    value_loss           | 0.0742    |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 5         |
# |    ep_rew_mean          | 4.9       |
# | time/                   |           |
# |    fps                  | 16        |
# |    iterations           | 239       |
# |    time_elapsed         | 29383     |
# |    total_timesteps      | 489472    |
# | train/                  |           |
# |    approx_kl            | 1.5885823 |
# |    clip_fraction        | 0.783     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | 9.21      |
# |    explained_variance   | 0.96      |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0.000417  |
# |    n_updates            | 4830      |
# |    policy_gradient_loss | 0.00917   |
# |    std                  | 0.0245    |
# |    value_loss           | 0.0727    |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 5         |
# |    ep_rew_mean          | 4.84      |
# | time/                   |           |
# |    fps                  | 16        |
# |    iterations           | 240       |
# |    time_elapsed         | 29500     |
# |    total_timesteps      | 491520    |
# | train/                  |           |
# |    approx_kl            | 1.6954486 |
# |    clip_fraction        | 0.782     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | 9.23      |
# |    explained_variance   | 0.961     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0.0249    |
# |    n_updates            | 4840      |
# |    policy_gradient_loss | 0.00726   |
# |    std                  | 0.0245    |
# |    value_loss           | 0.0727    |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 5         |
# |    ep_rew_mean          | 4.83      |
# | time/                   |           |
# |    fps                  | 16        |
# |    iterations           | 241       |
# |    time_elapsed         | 29616     |
# |    total_timesteps      | 493568    |
# | train/                  |           |
# |    approx_kl            | 1.6951416 |
# |    clip_fraction        | 0.765     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | 9.24      |
# |    explained_variance   | 0.959     |
# |    learning_rate        | 0.0003    |
# |    loss                 | -0.0386   |
# |    n_updates            | 4850      |
# |    policy_gradient_loss | -0.0145   |
# |    std                  | 0.0243    |
# |    value_loss           | 0.0753    |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 5         |
# |    ep_rew_mean          | 4.8       |
# | time/                   |           |
# |    fps                  | 16        |
# |    iterations           | 242       |
# |    time_elapsed         | 29732     |
# |    total_timesteps      | 495616    |
# | train/                  |           |
# |    approx_kl            | 1.7660427 |
# |    clip_fraction        | 0.789     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | 9.26      |
# |    explained_variance   | 0.959     |
# |    learning_rate        | 0.0003    |
# |    loss                 | -0.0298   |
# |    n_updates            | 4860      |
# |    policy_gradient_loss | 0.0469    |
# |    std                  | 0.0242    |
# |    value_loss           | 0.0746    |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 5         |
# |    ep_rew_mean          | 4.88      |
# | time/                   |           |
# |    fps                  | 16        |
# |    iterations           | 243       |
# |    time_elapsed         | 29848     |
# |    total_timesteps      | 497664    |
# | train/                  |           |
# |    approx_kl            | 1.7575752 |
# |    clip_fraction        | 0.816     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | 9.25      |
# |    explained_variance   | 0.965     |
# |    learning_rate        | 0.0003    |
# |    loss                 | -0.0719   |
# |    n_updates            | 4870      |
# |    policy_gradient_loss | 0.0638    |
# |    std                  | 0.0244    |
# |    value_loss           | 0.0631    |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 5         |
# |    ep_rew_mean          | 4.81      |
# | time/                   |           |
# |    fps                  | 16        |
# |    iterations           | 244       |
# |    time_elapsed         | 29965     |
# |    total_timesteps      | 499712    |
# | train/                  |           |
# |    approx_kl            | 1.8650573 |
# |    clip_fraction        | 0.785     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | 9.25      |
# |    explained_variance   | 0.962     |
# |    learning_rate        | 0.0003    |
# |    loss                 | -0.0591   |
# |    n_updates            | 4880      |
# |    policy_gradient_loss | -0.00363  |
# |    std                  | 0.0243    |
# |    value_loss           | 0.0696    |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 5         |
# |    ep_rew_mean          | 4.82      |
# | time/                   |           |
# |    fps                  | 16        |
# |    iterations           | 245       |
# |    time_elapsed         | 30081     |
# |    total_timesteps      | 501760    |
# | train/                  |           |
# |    approx_kl            | 1.7878394 |
# |    clip_fraction        | 0.775     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | 9.27      |
# |    explained_variance   | 0.961     |
# |    learning_rate        | 0.0003    |
# |    loss                 | -0.0529   |
# |    n_updates            | 4890      |
# |    policy_gradient_loss | -0.00459  |
# |    std                  | 0.0241    |
# |    value_loss           | 0.0722    |
# ---------------------------------------

# %%
model.save(os.path.join(log_dir, "ppo_model_2"))

# %%
import os
import pandas as pd
import seaborn as sns

from stable_baselines3 import PPO
from stable_baselines3.common.monitor import Monitor

# test environment
env = CustomEnv()

# ==== Configuration ====
log_dir = "logs/rl_repressilator_past_amort_multi_step_frame_5"
model_path = os.path.join(log_dir, "ppo_model_2")
monitor_file = os.path.join(log_dir, "monitor.csv")

df_2 = pd.read_csv(monitor_file, skiprows=1)  # Skip header comment row

# %%
# ==== 3. Plot learning curve ====
plt.figure(figsize=(10, 6))
sns.lineplot(x=range(len(df_2)), y=df_2["r"], linewidth=2)

plt.xlabel("Episode", fontsize=18)
plt.ylabel("Reward", fontsize=18)
plt.legend(fontsize=14)
sns.despine()

plt.tight_layout()
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
# merge df and df_2

df = pd.concat([df, df_2], ignore_index=True)
plt.figure(figsize=(10, 6))
sns.lineplot(x=range(len(df)), y=df["r"], linewidth=2)
plt.xlabel("Episode", fontsize=18)
plt.ylabel("Reward", fontsize=18)
plt.legend(fontsize=14)
sns.despine()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
#plot violins seaborn
import seaborn as sns
plt.figure(figsize=(10, 6))
sns.violinplot(data=[first_rewards, second_rewards, third_rewards, forth_rewards, fifth_rewards], inner="quartile")
plt.xlabel("Design", fontsize=18)
plt.ylabel("Reward", fontsize=18)
# Out:
# Text(0, 0.5, 'Reward')

# %%
#plot boxplot seaborn
plt.figure(figsize=(10, 6))
sns.boxplot(data=[first_rewards, second_rewards, third_rewards,forth_rewards, fifth_rewards],showmeans=True)
plt.xlabel("Design", fontsize=18)
plt.ylabel("Reward", fontsize=18)
# Out:
# Text(0, 0.5, 'Reward')

# %%
obs, info = env.reset()  # Reset the environment with a specific frequency

action, _states = model.predict(obs, deterministic=True)
action
print("Action taken:", action)
first_params = np.hstack((env.uncertain, action))

first_obs =  jl.plot_amort(np.hstack([env.uncertain, action]))

# print("First Reward:",jl.reward_normalized_past_amort(first_params, 1/7))
obs, reward, terminated, truncated, info = env.step(action)
print(terminated)

print("First reward:", reward)
# Take action in the environment

action, _states = model.predict(obs, deterministic=True)


second_obs =  jl.plot_amort(np.hstack([env.uncertain, action]))

obs, reward, terminated, truncated, info = env.step(action)

print("Action taken:", action)
print("Second reward:", reward)
print("Terminated", terminated)

action, _states = model.predict(obs, deterministic=True)

obs, reward, terminated, truncated, info = env.step(action)

third_obs =  jl.plot_amort(np.hstack([env.uncertain, action]))


print("Action taken:", action)
print("Third reward:", reward)
print("Terminated", terminated)

action, _states = model.predict(obs, deterministic=True)

obs, reward, terminated, truncated, info = env.step(action)

forth_obs =  jl.plot_amort(np.hstack([env.uncertain, action]))

print("Action taken:", action)
print("Forth reward:", reward)
print("Terminated", terminated)

action, _states = model.predict(obs, deterministic=True)

fifth_obs = jl.plot_amort(np.hstack([env.uncertain, action]))

obs, reward, terminated, truncated, info = env.step(action)

print("Action taken:", action)
print("Fifth reward:", reward)
print("Terminated", terminated)
# Out:
# Action taken: [ 0.8278582 -0.5568037  1.         1.       ]
# False
# First reward: 0.673587979123082
# Action taken: [ 0.46183604 -1.          0.25201946 -0.6121459 ]
# Second reward: 1.102091702373994
# Terminated False
# Action taken: [-0.17290956 -1.          0.9123991   0.05516392]
# Third reward: 0.9697459436685637
# Terminated False
# Action taken: [ 0.83727163 -0.60678923  1.          0.46342283]
# Forth reward: 0.9526242128470647
# Terminated False
# Action taken: [ 1.         -0.34745157  1.          0.77499306]
# Fifth reward: 0.9604778935022735
# Terminated True

# %%
plt.figure(figsize=(15, 15))

plt.subplot(5, 1, 1)
plt.plot(first_obs, label="First Design")
plt.legend()

plt.subplot(5, 1, 2)
plt.plot(second_obs, label="Second Design")
plt.legend()

plt.subplot(5, 1, 3)
plt.plot(third_obs, label="Third Design")
plt.legend()

plt.subplot(5, 1, 4)
plt.plot(forth_obs, label="Forth Design")
plt.legend()

plt.subplot(5, 1, 5)
plt.plot(fifth_obs, label="Fifth Design")
plt.legend()

plt.tight_layout()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

def stacked_amort_heatmap(env, action, step_idx, num_samples=10):
    """
    Repeats jl.plot_amort with the same input multiple times and plots a 2D heatmap.
    
    Parameters:
        env: the environment object
        action: the action taken
        step_idx: index of the current step (for labeling)
        num_samples: number of times to repeat jl.plot_amort
    """
    amort_outputs = []
    for _ in range(num_samples):
        out = jl.plot_amort(np.hstack([env.uncertain, action]))
        amort_outputs.append(out)
    return amort_outputs

# Start interaction with the environment
obs, info = env.reset()
print("Environment reset.")

# Step 1
action, _states = model.predict(obs, deterministic=True)
print("Action taken:", action)
h1 = stacked_amort_heatmap(env, action, step_idx=1)

obs, reward, terminated, truncated, info = env.step(action)
print("Step 1 reward:", reward)
print("Terminated:", terminated)

# Step 2
action, _states = model.predict(obs, deterministic=True)
print("Action taken:", action)
h2 = stacked_amort_heatmap(env, action, step_idx=2)

obs, reward, terminated, truncated, info = env.step(action)
print("Step 2 reward:", reward)
print("Terminated:", terminated)

# Step 3
action, _states = model.predict(obs, deterministic=True)
print("Action taken:", action)
h3 = stacked_amort_heatmap(env, action, step_idx=3)

obs, reward, terminated, truncated, info = env.step(action)
print("Step 3 reward:", reward)
print("Terminated:", terminated)

# Step 4
action, _states = model.predict(obs, deterministic=True)
print("Action taken:", action)
h4 = stacked_amort_heatmap(env, action, step_idx=4)

obs, reward, terminated, truncated, info = env.step(action)
print("Step 4 reward:", reward)
print("Terminated:", terminated)

# Step 5
action, _states = model.predict(obs, deterministic=True)
print("Action taken:", action)
h5 = stacked_amort_heatmap(env, action, step_idx=5)

obs, reward, terminated, truncated, info = env.step(action)
print("Step 5 reward:", reward)
print("Terminated:", terminated)

sns.heatmap(h1)
plt.show()
sns.heatmap(h2)
plt.show()
sns.heatmap(h3)
plt.show()
sns.heatmap(h4)
plt.show()
sns.heatmap(h5)
plt.show()
# Out:
# Environment reset.
# Action taken: [ 0.8278582 -0.5568037  1.         1.       ]
# Step 1 reward: 0.7023770641335045
# Terminated: False
# Action taken: [ 0.4359607  -1.          0.8845529  -0.06818658]
# Step 2 reward: 1.1363592623186203
# Terminated: False
# Action taken: [-0.1835736 -1.         0.9515308  1.       ]
# Step 3 reward: 0.8535349418147896
# Terminated: False
# Action taken: [ 0.5770437 -1.         1.         0.3090974]
# Step 4 reward: 1.136290171148281
# Terminated: False
# Action taken: [ 1.        -0.6710212  1.         1.       ]
# Step 5 reward: 1.1329427308904387
# Terminated: True

# %%
obs, info = env.reset(options={'frequancy': 1/8})  # Reset the environment with a specific frequency
    
# Predict action
action, _states = model.predict(obs, deterministic=True) 
print(action)
jl.reward_amort(action,1/8)
plt.plot(jl.plot_amort(action))
# Out:
# [-0.18644197 -0.9941113   1.          0.6916606 ]
# ---------------------------------------------------------------------------
# JuliaError                                Traceback (most recent call last)
# Cell In[64], line 6
#       4 action, _states = model.predict(obs, deterministic=True)
#       5 print(action)
# ----> 6 jl.reward_amort(action,1/8)
#       7 plt.plot(jl.plot_amort(action))
#
# File ~/.julia/packages/PythonCall/Nr75f/src/JlWrap/any.jl:258, in __call__(self, *args, **kwargs)
#     256     return ValueBase.__dir__(self) + self._jl_callmethod($(pyjl_methodnum(pyjlany_dir)))
#     257 def __call__(self, *args, **kwargs):
# --> 258     return self._jl_callmethod($(pyjl_methodnum(pyjlany_call)), args, kwargs)
#     259 def __bool__(self):
#     260     return True
#
# JuliaError: BoundsError: attempt to access 4-element PyArray{Float32, 1} at index [5]
# Stacktrace:
#  [1] throw_boundserror(A::PyArray{Float32, 1, true, true, Float32}, I::Tuple{Int64})
#    @ Base ./essentials.jl:14
#  [2] checkbounds
#    @ ./abstractarray.jl:699 [inlined]
#  [3] pyarray_getindex
#    @ ~/.julia/packages/PythonCall/Nr75f/src/Wrap/PyArray.jl:663 [inlined]
#  [4] getindex
#    @ ~/.julia/packages/PythonCall/Nr75f/src/Wrap/PyArray.jl:659 [inlined]
#  [5] unnorm_params(normalized_params::PyArray{Float32, 1, true, true, Float32})
#    @ Main ~/Coding/RL-circuits/rl_repressilator_past_amort_setup.jl:59
#  [6] reward_amort(normalized_params::PyArray{Float32, 1, true, true, Float32}, desired_freq::Float64)
#    @ Main ~/Coding/RL-circuits/rl_repressilator_past_amort_setup.jl:75
#  [7] pyjlany_call(self::typeof(reward_amort), args_::Py, kwargs_::Py)
#    @ PythonCall.JlWrap ~/.julia/packages/PythonCall/Nr75f/src/JlWrap/any.jl:0
#  [8] _pyjl_callmethod(f::Any, self_::Ptr{PythonCall.C.PyObject}, args_::Ptr{PythonCall.C.PyObject}, nargs::Int64)
#    @ PythonCall.JlWrap ~/.julia/packages/PythonCall/Nr75f/src/JlWrap/base.jl:73
#  [9] _pyjl_callmethod(o::Ptr{PythonCall.C.PyObject}, args::Ptr{PythonCall.C.PyObject})
#    @ PythonCall.JlWrap.Cjl ~/.julia/packages/PythonCall/Nr75f/src/JlWrap/C.jl:63

# %%
action, _states = model.predict(obs, deterministic=True) 
jl.reward_amort(action,1/10)
plt.plot(jl.plot_amort(action))

# %%
obs, info = env.reset(options={'frequancy': 1/10})  # Reset the environment with a specific frequency
    
# Predict action
action, _states = model.predict(obs, deterministic=True) 
print(action)
jl.reward_amort(action,1/10)
plt.plot(jl.plot_amort(action))
# Out:
# [-0.24743213  1.         -0.49190277  1.          1.        ]

# %%
obs, info = env.reset(options={'frequancy': 1/12})  # Reset the environment with a specific frequency
    
# Predict action
action, _states = model.predict(obs, deterministic=True) 
print(action)
print(jl.reward_amort(action,1/12))
plt.plot(jl.plot_amort(action))
# Out:
# [ 0.9266927  1.        -0.9064123  1.         1.       ]
# -0.5484597951722563

# %%
rev10 = np.zeros(100)
rev9 = np.zeros(100)
rev11 = np.zeros(100)
for i in range(100):
    obs, info = env.reset(options={'frequancy': 1/10}) 
    env.frequancy = 1/10
        
    # Predict action
    action, _states = model.predict(obs, deterministic=True) 
    rev10[i] = jl.reward_amort(action,1/10)
    rev9[i] = jl.reward_amort(action,1/9)
    rev11[i] = jl.reward_amort(action,1/11)
print(rev10.mean(), rev10.std())
print(rev9.mean(), rev9.std())
print(rev11.mean(), rev11.std())
# Out:
# 0.030861651764838762 0.38155695014611873
# -0.9489301528593321 0.5099098517389462
# -0.7196163637373822 0.40851304991854526

# %%
rev8 = np.zeros(100)
rev9 = np.zeros(100)
rev7 = np.zeros(100)
for i in range(100):
    obs, info = env.reset(options={'frequancy': 1/8}) 
    env.frequancy = 1/8
        
    # Predict action
    action, _states = model.predict(obs, deterministic=True) 
    rev8[i] = jl.reward_amort(action,1/8)
    rev9[i] = jl.reward_amort(action,1/9)
    rev7[i] = jl.reward_amort(action,1/7)
print(rev10.mean(), rev8.std())
print(rev9.mean(), rev9.std())
print(rev11.mean(), rev7.std())
# Out:
# 0.030861651764838762 0.49172829444986077
# -1.5035365016307207 0.8585483345559198
# -0.7196163637373822 0.6841481384323931

# %%
# Store actions in a list
actions = []

# Generate 1000 samples
for _ in range(100000):
    # Reset env with random hidden_state (as in your example)
    obs, info = env.reset()
    env.frequancy = 1/8
    
    # Predict action
    action, _states = model.predict(obs, deterministic=False)  # deterministic=False for stochastic sampling
    actions.append(jl.denormalize_params(action))

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Create the DataFrame
df = pd.DataFrame(actions, columns=["H", "γm", "kX", "km", "K"])

# Define ground truth and deterministic prediction
gt = [7.0, 17.6822, 100.0, 113.4372, 199.8989]
action_determinstic = model.predict(obs, deterministic=True)[0]
action_determinstic_denormalized = jl.denormalize_params(action_determinstic)

# Hexbin plot function
def hexbin_plot(x, y, color, **kwargs):
    ax = plt.gca()
    ax.hexbin(
        x, y,
        gridsize=5,
        cmap='Blues',
        mincnt=1,
        edgecolors='gray',
        linewidths=0.7,
        alpha=0.9
    )

# Histogram function for diagonal
def hist_plot(x, color, **kwargs):
    ax = plt.gca()
    ax.hist(x, bins=10, color='darkblue', edgecolor='black',log=True)

# Initialize PairGrid
g = sns.PairGrid(df)
g.map_lower(hexbin_plot)
g.map_diag(hist_plot)
g.map_upper(hexbin_plot)

# Overlay scatter points and vertical lines
for row in range(len(df.columns)):
    for col in range(len(df.columns)):
        ax = g.axes[row, col]

        if row == col:
            # Add vertical lines to diagonal
            ax.axvline(action_determinstic_denormalized[row], color='lightblue',zorder=10, linewidth=2, label='Deterministic' if row == 0 else "")
            ax.axvline(gt[row], color='red', linestyle='--', linewidth=2, zorder=10, label='Ground Truth' if row == 0 else "")
        else:
            ax.scatter(df.iloc[:, col], df.iloc[:, row],
                       color='darkblue', s=1, alpha=0.1, label='Samples' if (row, col) == (1, 0) else "")
            ax.scatter(gt[col], gt[row],
                       color='red', s=100,marker='x', label='Ground Truth' if (row, col) == (1, 0) else "")
            ax.scatter(action_determinstic_denormalized[col], action_determinstic_denormalized[row],
                       color='lightblue', marker="+", alpha=0.9, label='Deterministic' if (row, col) == (1, 0) else "")

# Add legend only once
handles, labels = g.axes[-1][0].get_legend_handles_labels()
if handles:
    g.axes[-1][0].legend(handles, labels, loc='upper right', fontsize='small')

plt.show()

# %%
stochastic_policy_result = []
for i in range(1000):
    action = model.predict(obs)[0]
    stochastic_policy_result.append(jl.reward(action))

action_determinstic = model.predict(obs, deterministic=True)[0]

policy_det_eval = jl.evaluate_params(action_determinstic)

sequiros_eval = jl.evaluate_params(jl.normalize_params(np.array(gt, dtype=np.float32)))

# %%
plt.figure(figsize=(8, 4))
sns.violinplot(data=[stochastic_policy_result, policy_det_eval, sequiros_eval], inner="quartile", palette="muted")
plt.xticks([0, 1, 2], ['PPO Policy (stochastic)','PPO Policy (deterministic)', 'Sequiros'])
plt.ylabel('Reward')
plt.tight_layout()
plt.show()

print("mean of policy_det_eval:", np.mean(policy_det_eval))
print("mean of policy_stoch_eval:", np.mean(stochastic_policy_result))
print("mean of sequiros_eval:", np.mean(sequiros_eval))
# Out:
# mean of policy_det_eval: 0.5997235608265995
# mean of policy_stoch_eval: 0.5988463618449332
# mean of sequiros_eval: 0.5999704605703644
