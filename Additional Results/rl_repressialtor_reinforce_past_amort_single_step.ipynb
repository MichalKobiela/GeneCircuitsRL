# %% [markdown]
# Setup

# %%
# %pip install numpy
# %pip install matplotlib
# %pip install tensorboard
import numpy as np
import matplotlib.pyplot as plt
from juliacall import Main as jl
from juliacall import Pkg as jlPkg
jlPkg.activate("../.")
jl.Pkg.instantiate()
jl.include("../models/rl_repressilator_past_amort_setup.jl")
#jlPkg.instantiate() #run the first time using this repo
# Out:
# Requirement already satisfied: numpy in c:\Users\micha\miniconda3\envs\circuitsrl\Lib\site-packages (2.4.2)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: matplotlib in c:\Users\micha\miniconda3\envs\circuitsrl\Lib\site-packages (3.10.8)
# Requirement already satisfied: contourpy>=1.0.1 in c:\Users\micha\miniconda3\envs\circuitsrl\Lib\site-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\Users\micha\miniconda3\envs\circuitsrl\Lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\Users\micha\miniconda3\envs\circuitsrl\Lib\site-packages (from matplotlib) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\Users\micha\miniconda3\envs\circuitsrl\Lib\site-packages (from matplotlib) (1.4.9)
# Requirement already satisfied: numpy>=1.23 in c:\Users\micha\miniconda3\envs\circuitsrl\Lib\site-packages (from matplotlib) (2.4.2)
# Requirement already satisfied: packaging>=20.0 in c:\Users\micha\miniconda3\envs\circuitsrl\Lib\site-packages (from matplotlib) (26.0)
# Requirement already satisfied: pillow>=8 in c:\Users\micha\miniconda3\envs\circuitsrl\Lib\site-packages (from matplotlib) (12.1.0)
# Requirement already satisfied: pyparsing>=3 in c:\Users\micha\miniconda3\envs\circuitsrl\Lib\site-packages (from matplotlib) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\Users\micha\miniconda3\envs\circuitsrl\Lib\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\Users\micha\miniconda3\envs\circuitsrl\Lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: tensorboard in c:\Users\micha\miniconda3\envs\circuitsrl\Lib\site-packages (2.20.0)
# Requirement already satisfied: absl-py>=0.4 in c:\Users\micha\miniconda3\envs\circuitsrl\Lib\site-packages (from tensorboard) (2.4.0)
# Requirement already satisfied: grpcio>=1.48.2 in c:\Users\micha\miniconda3\envs\circuitsrl\Lib\site-packages (from tensorboard) (1.78.0)
# Requirement already satisfied: markdown>=2.6.8 in c:\Users\micha\miniconda3\envs\circuitsrl\Lib\site-packages (from tensorboard) (3.10.2)
# Requirement already satisfied: numpy>=1.12.0 in c:\Users\micha\miniconda3\envs\circuitsrl\Lib\site-packages (from tensorboard) (2.4.2)
# Requirement already satisfied: packaging in c:\Users\micha\miniconda3\envs\circuitsrl\Lib\site-packages (from tensorboard) (26.0)
# Requirement already satisfied: pillow in c:\Users\micha\miniconda3\envs\circuitsrl\Lib\site-packages (from tensorboard) (12.1.0)
# Requirement already satisfied: protobuf!=4.24.0,>=3.19.6 in c:\Users\micha\miniconda3\envs\circuitsrl\Lib\site-packages (from tensorboard) (6.33.5)
# Requirement already satisfied: setuptools>=41.0.0 in c:\Users\micha\miniconda3\envs\circuitsrl\Lib\site-packages (from tensorboard) (82.0.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in c:\Users\micha\miniconda3\envs\circuitsrl\Lib\site-packages (from tensorboard) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\Users\micha\miniconda3\envs\circuitsrl\Lib\site-packages (from tensorboard) (3.1.5)
# Requirement already satisfied: typing-extensions~=4.12 in c:\Users\micha\miniconda3\envs\circuitsrl\Lib\site-packages (from grpcio>=1.48.2->tensorboard) (4.15.0)
# Requirement already satisfied: markupsafe>=2.1.1 in c:\Users\micha\miniconda3\envs\circuitsrl\Lib\site-packages (from werkzeug>=1.0.1->tensorboard) (3.0.3)
# Note: you may need to restart the kernel to use updated packages.
# Detected IPython. Loading juliacall extension. See https://juliapy.github.io/PythonCall.jl/stable/compat/#IPython
#   Activating project at `c:\Users\micha\GeneCircuitsRL`
# Second peak value: 0.7038096038235359
# observation (generic function with 2 methods)

# %%
import gymnasium as gym
from gymnasium import spaces
import numpy as np
import torch as th
import torch.nn as nn
from stable_baselines3.common.torch_layers import BaseFeaturesExtractor

class Custom1DCNNExtractor(BaseFeaturesExtractor):
    def __init__(self, observation_space, features_dim=128, obs_dim=128, action_dim=3, n_steps=1):
        super(Custom1DCNNExtractor, self).__init__(observation_space, features_dim)

        self.obs_dim = obs_dim
        self.action_dim = action_dim
        self.n_steps = n_steps

        n_input_channels = 1
        seq_len = obs_dim

        # CNN to process each observation chunk
        self.cnn = nn.Sequential(
            nn.Conv1d(n_input_channels, 32, kernel_size=3, stride=1, padding=1),
            nn.ReLU(),
            nn.Conv1d(32, 64, kernel_size=3, stride=1, padding=1),
            nn.ReLU(),
            nn.Flatten()
        )

        # Determine CNN output size
        with th.no_grad():
            sample_obs = th.zeros((1, n_input_channels, seq_len), dtype=th.float32)
            cnn_output_dim = self.cnn(sample_obs).shape[1]

        # Concatenate obs features and raw actions across all steps
        combined_dim = self.n_steps * cnn_output_dim + self.n_steps * action_dim

        self.linear = nn.Sequential(
            nn.Linear(combined_dim, features_dim),
            nn.ReLU()
        )

    def forward(self, observations):
        """
        observations: (batch, 1, obs1 + act1 + ... + obsN + actN)
        """
        obs_feats = []
        act_feats = []

        for i in range(self.n_steps):
            obs_start = i * (self.obs_dim + self.action_dim)
            act_start = obs_start + self.obs_dim
            act_end = act_start + self.action_dim

            obs = observations[:, :, obs_start:act_start]  # (batch, 1, obs_dim)
            act = observations[:, 0, act_start:act_end]    # (batch, action_dim)

            obs_feat = self.cnn(obs)                       # (batch, cnn_output_dim)
            obs_feats.append(obs_feat)
            act_feats.append(act)

        combined = th.cat(obs_feats + act_feats, dim=1)
        return self.linear(combined)


# ======================
#  Environment
# ======================

import random
import torch
from gymnasium.utils import seeding

class CustomEnv(gym.Env):
    metadata = {"render_modes": []}

    def __init__(self, max_episode_steps=1):
        super(CustomEnv, self).__init__()

        self.obs_dim = 128
        self.action_dim = 3          # design params: kX, km, K
        self.uncertain_dim = 4       # H, γX, γm, ϵ
        self.n_steps = max_episode_steps

        self.observation_space = spaces.Box(
            low=-np.inf,
            high=np.inf,
            shape=(1, self.n_steps * (self.obs_dim + self.action_dim)),
            dtype=np.float32
        )

        self.action_space = spaces.Box(
            low=-1,
            high=1,
            shape=(self.action_dim,),
            dtype=np.float32
        )

        self.max_episode_steps = max_episode_steps
        self.current_step = 0
        self.uncertain = np.zeros(self.uncertain_dim, dtype=np.float32)

        self.effective_observation = np.zeros(self.observation_space.shape, dtype=np.float32)
    
    def seed(self, seed=None):
        self._np_random, seed = seeding.np_random(seed)
        np.random.seed(seed)
        random.seed(seed)
        torch.manual_seed(seed)
        jl.seval(f"Random.seed!({seed})")  # sync seed with Julia
        return [seed]
    
    def reset(self, seed=None, options=None):
        if options is not None and 'uncertain' in options:
            self.uncertain = np.array(options['uncertain'], dtype=np.float32)
        else:
            self.uncertain = (np.random.rand(self.uncertain_dim) * 2 - 1).astype(np.float32)

        if seed is not None:
            self.seed(seed)
        
        self.current_step = 0
        self.effective_observation[:] = 0.0

        info = {}
        return self.effective_observation.copy(), info

    def step(self, action):
        params_action = np.concatenate((self.uncertain, action))
        reward = jl.reward_normalized_past_amort(params_action, 1 / 7)
        rew = np.clip(reward, -5, 5)

        obs_vector = jl.observation(self.uncertain, action)
        obs_vector = np.array(obs_vector).reshape(1, -1).astype(np.float32)

        if self.current_step < self.max_episode_steps:
            obs_start = self.current_step * (self.obs_dim + self.action_dim)
            act_start = obs_start + self.obs_dim

            self.effective_observation[:, obs_start:act_start] = obs_vector
            self.effective_observation[:, act_start:act_start + self.action_dim] = action

        self.current_step += 1
        terminated = self.current_step >= self.max_episode_steps
        truncated = False
        info = {}

        return self.effective_observation.copy(), rew, terminated, truncated, info

# %%
from stable_baselines3.common.env_checker import check_env
env = CustomEnv()
check_env(env)
# Out:
# c:\Users\micha\miniconda3\envs\circuitsrl\Lib\site-packages\stable_baselines3\common\env_checker.py:316: UserWarning: Your observation  has an unconventional shape (neither an image, nor a 1D vector). We recommend you to flatten the observation to have only a 1D vector or use a custom policy to properly process the data.
#   warnings.warn(

# %% [markdown]
# Training

# %%
import os
import pandas as pd
import seaborn as sns

from stable_baselines3 import PPO
from stable_baselines3.common.monitor import Monitor

log_dir = "../logs/rl_repressilator_past_amort_single_step/"
os.makedirs(log_dir, exist_ok=True)


SEED = 1235 # Different seed - orginal one 1234

random.seed(SEED)
np.random.seed(SEED)
torch.manual_seed(SEED)
jl.seval(f"Random.seed!({SEED})") 
env = CustomEnv()
env.seed(SEED)
env.reset(seed=SEED)
env = Monitor(env, filename=log_dir)

policy_kwargs = dict(
    features_extractor_class=Custom1DCNNExtractor,
    features_extractor_kwargs=dict(features_dim=128),
)

model = PPO(
    "CnnPolicy", 
    env,
    policy_kwargs=policy_kwargs,
    verbose=1,
    tensorboard_log=log_dir,
    seed=SEED
)
# Out:
# Using cpu device
# Wrapping the env in a DummyVecEnv.

# %%
model.learn(total_timesteps=1500000)

obs, info = env.reset()
action, _ = model.predict(obs)
print("Test action:", action)
# Out:
# Logging to ../logs/rl_repressilator_past_amort_single_step/PPO_1
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1        |
# |    ep_rew_mean     | -0.0425  |
# | time/              |          |
# |    fps             | 13       |
# |    iterations      | 1        |
# |    time_elapsed    | 153      |
# |    total_timesteps | 2048     |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1           |
# |    ep_rew_mean          | 0.0632      |
# | time/                   |             |
# |    fps                  | 13          |
# |    iterations           | 2           |
# |    time_elapsed         | 308         |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.010841848 |
# |    clip_fraction        | 0.141       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.26       |
# |    explained_variance   | -1.19e-07   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.47        |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.0148     |
# |    std                  | 0.999       |
# |    value_loss           | 1.12        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1           |
# |    ep_rew_mean          | -0.152      |
# | time/                   |             |
# |    fps                  | 13          |
# |    iterations           | 3           |
# |    time_elapsed         | 466         |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.007695622 |
# |    clip_fraction        | 0.12        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.24       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.608       |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.0111     |
# |    std                  | 0.99        |
# |    value_loss           | 1.14        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1           |
# |    ep_rew_mean          | -0.0212     |
# | time/                   |             |
# |    fps                  | 13          |
# |    iterations           | 4           |
# |    time_elapsed         | 627         |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.010822541 |
# |    clip_fraction        | 0.153       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.21       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.45        |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.0136     |
# |    std                  | 0.981       |
# |    value_loss           | 1.04        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1            |
# |    ep_rew_mean          | 0.0648       |
# | time/                   |              |
# |    fps                  | 12           |
# |    iterations           | 5            |
# |    time_elapsed         | 788          |
# |    total_timesteps      | 10240        |
# | train/                  |              |
# |    approx_kl            | 0.0114971325 |
# |    clip_fraction        | 0.174        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.18        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.245        |
# |    n_updates            | 40           |
# |    policy_gradient_loss | -0.017       |
# |    std                  | 0.971        |
# |    value_loss           | 0.971        |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1           |
# |    ep_rew_mean          | 0.0214      |
# | time/                   |             |
# |    fps                  | 12          |
# |    iterations           | 6           |
# |    time_elapsed         | 947         |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.012720939 |
# |    clip_fraction        | 0.201       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.13       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.785       |
# |    n_updates            | 50          |
# |    policy_gradient_loss | -0.0198     |
# |    std                  | 0.949       |
# |    value_loss           | 1.03        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1           |
# |    ep_rew_mean          | -0.0377     |
# | time/                   |             |
# |    fps                  | 13          |
# |    iterations           | 7           |
# |    time_elapsed         | 1101        |
# |    total_timesteps      | 14336       |
# | train/                  |             |
# |    approx_kl            | 0.014242121 |
# |    clip_fraction        | 0.206       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.08       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.415       |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.0197     |
# |    std                  | 0.937       |
# |    value_loss           | 1.12        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1           |
# |    ep_rew_mean          | 0.0277      |
# | time/                   |             |
# |    fps                  | 13          |
# |    iterations           | 8           |
# |    time_elapsed         | 1257        |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.015892994 |
# |    clip_fraction        | 0.202       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.02       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.554       |
# |    n_updates            | 70          |
# |    policy_gradient_loss | -0.021      |
# |    std                  | 0.914       |
# |    value_loss           | 1           |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1           |
# |    ep_rew_mean          | -0.0983     |
# | time/                   |             |
# |    fps                  | 13          |
# |    iterations           | 9           |
# |    time_elapsed         | 1408        |
# |    total_timesteps      | 18432       |
# | train/                  |             |
# |    approx_kl            | 0.018288624 |
# |    clip_fraction        | 0.22        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.93       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.482       |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.0224     |
# |    std                  | 0.882       |
# |    value_loss           | 1.04        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1           |
# |    ep_rew_mean          | 0.219       |
# | time/                   |             |
# |    fps                  | 13          |
# |    iterations           | 10          |
# |    time_elapsed         | 1558        |
# |    total_timesteps      | 20480       |
# | train/                  |             |
# |    approx_kl            | 0.015108481 |
# |    clip_fraction        | 0.192       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.83       |
# |    explained_variance   | -1.19e-07   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.835       |
# |    n_updates            | 90          |
# |    policy_gradient_loss | -0.0204     |
# |    std                  | 0.858       |
# |    value_loss           | 0.966       |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1          |
# |    ep_rew_mean          | 0.237      |
# | time/                   |            |
# |    fps                  | 13         |
# |    iterations           | 11         |
# |    time_elapsed         | 1710       |
# |    total_timesteps      | 22528      |
# | train/                  |            |
# |    approx_kl            | 0.01720114 |
# |    clip_fraction        | 0.225      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.75      |
# |    explained_variance   | -1.19e-07  |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.486      |
# |    n_updates            | 100        |
# |    policy_gradient_loss | -0.0229    |
# |    std                  | 0.834      |
# |    value_loss           | 0.884      |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1           |
# |    ep_rew_mean          | 0.262       |
# | time/                   |             |
# |    fps                  | 13          |
# |    iterations           | 12          |
# |    time_elapsed         | 1862        |
# |    total_timesteps      | 24576       |
# | train/                  |             |
# |    approx_kl            | 0.017935768 |
# |    clip_fraction        | 0.233       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.65       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.472       |
# |    n_updates            | 110         |
# |    policy_gradient_loss | -0.0289     |
# |    std                  | 0.805       |
# |    value_loss           | 0.877       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1           |
# |    ep_rew_mean          | 0.421       |
# | time/                   |             |
# |    fps                  | 13          |
# |    iterations           | 13          |
# |    time_elapsed         | 2011        |
# |    total_timesteps      | 26624       |
# | train/                  |             |
# |    approx_kl            | 0.017827619 |
# |    clip_fraction        | 0.209       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.54       |
# |    explained_variance   | -1.19e-07   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.602       |
# |    n_updates            | 120         |
# |    policy_gradient_loss | -0.0258     |
# |    std                  | 0.777       |
# |    value_loss           | 0.9         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1           |
# |    ep_rew_mean          | 0.409       |
# | time/                   |             |
# |    fps                  | 13          |
# |    iterations           | 14          |
# |    time_elapsed         | 2164        |
# |    total_timesteps      | 28672       |
# | train/                  |             |
# |    approx_kl            | 0.015248111 |
# |    clip_fraction        | 0.195       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.44       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.351       |
# |    n_updates            | 130         |
# |    policy_gradient_loss | -0.0226     |
# |    std                  | 0.753       |
# |    value_loss           | 0.906       |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1          |
# |    ep_rew_mean          | 0.305      |
# | time/                   |            |
# |    fps                  | 13         |
# |    iterations           | 15         |
# |    time_elapsed         | 2318       |
# |    total_timesteps      | 30720      |
# | train/                  |            |
# |    approx_kl            | 0.01220059 |
# |    clip_fraction        | 0.173      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.35      |
# |    explained_variance   | 0          |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.294      |
# |    n_updates            | 140        |
# |    policy_gradient_loss | -0.0185    |
# |    std                  | 0.73       |
# |    value_loss           | 0.787      |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1           |
# |    ep_rew_mean          | 0.312       |
# | time/                   |             |
# |    fps                  | 13          |
# |    iterations           | 16          |
# |    time_elapsed         | 2473        |
# |    total_timesteps      | 32768       |
# | train/                  |             |
# |    approx_kl            | 0.011978338 |
# |    clip_fraction        | 0.184       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.27       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.314       |
# |    n_updates            | 150         |
# |    policy_gradient_loss | -0.0192     |
# |    std                  | 0.712       |
# |    value_loss           | 0.746       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1           |
# |    ep_rew_mean          | 0.367       |
# | time/                   |             |
# |    fps                  | 13          |
# |    iterations           | 17          |
# |    time_elapsed         | 2625        |
# |    total_timesteps      | 34816       |
# | train/                  |             |
# |    approx_kl            | 0.013199117 |
# |    clip_fraction        | 0.149       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.18       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.3         |
# |    n_updates            | 160         |
# |    policy_gradient_loss | -0.017      |
# |    std                  | 0.689       |
# |    value_loss           | 0.816       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1           |
# |    ep_rew_mean          | 0.347       |
# | time/                   |             |
# |    fps                  | 13          |
# |    iterations           | 18          |
# |    time_elapsed         | 2778        |
# |    total_timesteps      | 36864       |
# | train/                  |             |
# |    approx_kl            | 0.014259841 |
# |    clip_fraction        | 0.178       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.1        |
# |    explained_variance   | 1.19e-07    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.278       |
# |    n_updates            | 170         |
# |    policy_gradient_loss | -0.0178     |
# |    std                  | 0.675       |
# |    value_loss           | 0.814       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1           |
# |    ep_rew_mean          | 0.509       |
# | time/                   |             |
# |    fps                  | 13          |
# |    iterations           | 19          |
# |    time_elapsed         | 2932        |
# |    total_timesteps      | 38912       |
# | train/                  |             |
# |    approx_kl            | 0.012369474 |
# |    clip_fraction        | 0.145       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.03       |
# |    explained_variance   | -1.19e-07   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.312       |
# |    n_updates            | 180         |
# |    policy_gradient_loss | -0.0161     |
# |    std                  | 0.658       |
# |    value_loss           | 0.781       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1           |
# |    ep_rew_mean          | 0.553       |
# | time/                   |             |
# |    fps                  | 13          |
# |    iterations           | 20          |
# |    time_elapsed         | 3090        |
# |    total_timesteps      | 40960       |
# | train/                  |             |
# |    approx_kl            | 0.011132231 |
# |    clip_fraction        | 0.184       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.96       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.219       |
# |    n_updates            | 190         |
# |    policy_gradient_loss | -0.0182     |
# |    std                  | 0.646       |
# |    value_loss           | 0.712       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1           |
# |    ep_rew_mean          | 0.556       |
# | time/                   |             |
# |    fps                  | 13          |
# |    iterations           | 21          |
# |    time_elapsed         | 3247        |
# |    total_timesteps      | 43008       |
# | train/                  |             |
# |    approx_kl            | 0.010231728 |
# |    clip_fraction        | 0.109       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.9        |
# |    explained_variance   | 5.96e-08    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.319       |
# |    n_updates            | 200         |
# |    policy_gradient_loss | -0.00988    |
# |    std                  | 0.629       |
# |    value_loss           | 0.701       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1           |
# |    ep_rew_mean          | 0.509       |
# | time/                   |             |
# |    fps                  | 13          |
# |    iterations           | 22          |
# |    time_elapsed         | 3406        |
# |    total_timesteps      | 45056       |
# | train/                  |             |
# |    approx_kl            | 0.012173967 |
# |    clip_fraction        | 0.155       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.82       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.149       |
# |    n_updates            | 210         |
# |    policy_gradient_loss | -0.0141     |
# |    std                  | 0.615       |
# |    value_loss           | 0.725       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1           |
# |    ep_rew_mean          | 0.365       |
# | time/                   |             |
# |    fps                  | 13          |
# |    iterations           | 23          |
# |    time_elapsed         | 3563        |
# |    total_timesteps      | 47104       |
# | train/                  |             |
# |    approx_kl            | 0.009302256 |
# |    clip_fraction        | 0.108       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.75       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.254       |
# |    n_updates            | 220         |
# |    policy_gradient_loss | -0.0112     |
# |    std                  | 0.6         |
# |    value_loss           | 0.668       |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1          |
# |    ep_rew_mean          | 0.486      |
# | time/                   |            |
# |    fps                  | 13         |
# |    iterations           | 24         |
# |    time_elapsed         | 3720       |
# |    total_timesteps      | 49152      |
# | train/                  |            |
# |    approx_kl            | 0.00974072 |
# |    clip_fraction        | 0.0983     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -2.7       |
# |    explained_variance   | 1.19e-07   |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.447      |
# |    n_updates            | 230        |
# |    policy_gradient_loss | -0.00706   |
# |    std                  | 0.593      |
# |    value_loss           | 0.622      |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1           |
# |    ep_rew_mean          | 0.517       |
# | time/                   |             |
# |    fps                  | 13          |
# |    iterations           | 25          |
# |    time_elapsed         | 3879        |
# |    total_timesteps      | 51200       |
# | train/                  |             |
# |    approx_kl            | 0.009642719 |
# |    clip_fraction        | 0.116       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.65       |
# |    explained_variance   | -1.19e-07   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.132       |
# |    n_updates            | 240         |
# |    policy_gradient_loss | -0.00872    |
# |    std                  | 0.584       |
# |    value_loss           | 0.619       |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1            |
# |    ep_rew_mean          | 0.509        |
# | time/                   |              |
# |    fps                  | 13           |
# |    iterations           | 26           |
# |    time_elapsed         | 4038         |
# |    total_timesteps      | 53248        |
# | train/                  |              |
# |    approx_kl            | 0.0068850163 |
# |    clip_fraction        | 0.0826       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.61        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.33         |
# |    n_updates            | 250          |
# |    policy_gradient_loss | -0.00528     |
# |    std                  | 0.575        |
# |    value_loss           | 0.57         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1            |
# |    ep_rew_mean          | 0.408        |
# | time/                   |              |
# |    fps                  | 13           |
# |    iterations           | 27           |
# |    time_elapsed         | 4198         |
# |    total_timesteps      | 55296        |
# | train/                  |              |
# |    approx_kl            | 0.0058961655 |
# |    clip_fraction        | 0.0384       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.54        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.256        |
# |    n_updates            | 260          |
# |    policy_gradient_loss | -0.00383     |
# |    std                  | 0.56         |
# |    value_loss           | 0.602        |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1           |
# |    ep_rew_mean          | 0.546       |
# | time/                   |             |
# |    fps                  | 13          |
# |    iterations           | 28          |
# |    time_elapsed         | 4358        |
# |    total_timesteps      | 57344       |
# | train/                  |             |
# |    approx_kl            | 0.008767263 |
# |    clip_fraction        | 0.0862      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.47       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.139       |
# |    n_updates            | 270         |
# |    policy_gradient_loss | -0.00566    |
# |    std                  | 0.55        |
# |    value_loss           | 0.588       |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1            |
# |    ep_rew_mean          | 0.354        |
# | time/                   |              |
# |    fps                  | 13           |
# |    iterations           | 29           |
# |    time_elapsed         | 4521         |
# |    total_timesteps      | 59392        |
# | train/                  |              |
# |    approx_kl            | 0.0049572084 |
# |    clip_fraction        | 0.068        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.42        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.188        |
# |    n_updates            | 280          |
# |    policy_gradient_loss | -0.00327     |
# |    std                  | 0.54         |
# |    value_loss           | 0.583        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1            |
# |    ep_rew_mean          | 0.349        |
# | time/                   |              |
# |    fps                  | 13           |
# |    iterations           | 30           |
# |    time_elapsed         | 4682         |
# |    total_timesteps      | 61440        |
# | train/                  |              |
# |    approx_kl            | 0.0077022673 |
# |    clip_fraction        | 0.0734       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.37        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.316        |
# |    n_updates            | 290          |
# |    policy_gradient_loss | -0.00419     |
# |    std                  | 0.532        |
# |    value_loss           | 0.569        |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1          |
# |    ep_rew_mean          | 0.486      |
# | time/                   |            |
# |    fps                  | 13         |
# |    iterations           | 31         |
# |    time_elapsed         | 4845       |
# |    total_timesteps      | 63488      |
# | train/                  |            |
# |    approx_kl            | 0.00423768 |
# |    clip_fraction        | 0.0481     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -2.32      |
# |    explained_variance   | 0          |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.249      |
# |    n_updates            | 300        |
# |    policy_gradient_loss | -0.00167   |
# |    std                  | 0.522      |
# |    value_loss           | 0.649      |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1            |
# |    ep_rew_mean          | 0.525        |
# | time/                   |              |
# |    fps                  | 13           |
# |    iterations           | 32           |
# |    time_elapsed         | 5007         |
# |    total_timesteps      | 65536        |
# | train/                  |              |
# |    approx_kl            | 0.0047087297 |
# |    clip_fraction        | 0.0457       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.28        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.18         |
# |    n_updates            | 310          |
# |    policy_gradient_loss | -0.00173     |
# |    std                  | 0.517        |
# |    value_loss           | 0.564        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1            |
# |    ep_rew_mean          | 0.599        |
# | time/                   |              |
# |    fps                  | 13           |
# |    iterations           | 33           |
# |    time_elapsed         | 5170         |
# |    total_timesteps      | 67584        |
# | train/                  |              |
# |    approx_kl            | 0.0057235304 |
# |    clip_fraction        | 0.0713       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.24        |
# |    explained_variance   | -1.19e-07    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.414        |
# |    n_updates            | 320          |
# |    policy_gradient_loss | -0.00578     |
# |    std                  | 0.512        |
# |    value_loss           | 0.584        |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1           |
# |    ep_rew_mean          | 0.579       |
# | time/                   |             |
# |    fps                  | 13          |
# |    iterations           | 34          |
# |    time_elapsed         | 5331        |
# |    total_timesteps      | 69632       |
# | train/                  |             |
# |    approx_kl            | 0.004648758 |
# |    clip_fraction        | 0.0683      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.22       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.359       |
# |    n_updates            | 330         |
# |    policy_gradient_loss | -0.00206    |
# |    std                  | 0.511       |
# |    value_loss           | 0.543       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1           |
# |    ep_rew_mean          | 0.336       |
# | time/                   |             |
# |    fps                  | 13          |
# |    iterations           | 35          |
# |    time_elapsed         | 5494        |
# |    total_timesteps      | 71680       |
# | train/                  |             |
# |    approx_kl            | 0.008811755 |
# |    clip_fraction        | 0.0805      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.2        |
# |    explained_variance   | -1.19e-07   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.266       |
# |    n_updates            | 340         |
# |    policy_gradient_loss | -0.00349    |
# |    std                  | 0.501       |
# |    value_loss           | 0.537       |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1            |
# |    ep_rew_mean          | 0.538        |
# | time/                   |              |
# |    fps                  | 13           |
# |    iterations           | 36           |
# |    time_elapsed         | 5657         |
# |    total_timesteps      | 73728        |
# | train/                  |              |
# |    approx_kl            | 0.0073275073 |
# |    clip_fraction        | 0.0743       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.17        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.425        |
# |    n_updates            | 350          |
# |    policy_gradient_loss | -0.00184     |
# |    std                  | 0.5          |
# |    value_loss           | 0.58         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1           |
# |    ep_rew_mean          | 0.519       |
# | time/                   |             |
# |    fps                  | 13          |
# |    iterations           | 37          |
# |    time_elapsed         | 5819        |
# |    total_timesteps      | 75776       |
# | train/                  |             |
# |    approx_kl            | 0.006891458 |
# |    clip_fraction        | 0.0826      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.16       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.321       |
# |    n_updates            | 360         |
# |    policy_gradient_loss | -0.00263    |
# |    std                  | 0.5         |
# |    value_loss           | 0.633       |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1            |
# |    ep_rew_mean          | 0.359        |
# | time/                   |              |
# |    fps                  | 13           |
# |    iterations           | 38           |
# |    time_elapsed         | 5980         |
# |    total_timesteps      | 77824        |
# | train/                  |              |
# |    approx_kl            | 0.0049976604 |
# |    clip_fraction        | 0.0678       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.16        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.286        |
# |    n_updates            | 370          |
# |    policy_gradient_loss | -0.001       |
# |    std                  | 0.498        |
# |    value_loss           | 0.604        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1            |
# |    ep_rew_mean          | 0.553        |
# | time/                   |              |
# |    fps                  | 13           |
# |    iterations           | 39           |
# |    time_elapsed         | 6140         |
# |    total_timesteps      | 79872        |
# | train/                  |              |
# |    approx_kl            | 0.0068363165 |
# |    clip_fraction        | 0.0845       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.14        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.331        |
# |    n_updates            | 380          |
# |    policy_gradient_loss | -0.00453     |
# |    std                  | 0.494        |
# |    value_loss           | 0.525        |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1           |
# |    ep_rew_mean          | 0.531       |
# | time/                   |             |
# |    fps                  | 12          |
# |    iterations           | 40          |
# |    time_elapsed         | 6303        |
# |    total_timesteps      | 81920       |
# | train/                  |             |
# |    approx_kl            | 0.005374673 |
# |    clip_fraction        | 0.0623      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.11       |
# |    explained_variance   | -1.19e-07   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.251       |
# |    n_updates            | 390         |
# |    policy_gradient_loss | -0.0011     |
# |    std                  | 0.49        |
# |    value_loss           | 0.58        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1           |
# |    ep_rew_mean          | 0.471       |
# | time/                   |             |
# |    fps                  | 12          |
# |    iterations           | 41          |
# |    time_elapsed         | 6466        |
# |    total_timesteps      | 83968       |
# | train/                  |             |
# |    approx_kl            | 0.005597518 |
# |    clip_fraction        | 0.0625      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.1        |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.3         |
# |    n_updates            | 400         |
# |    policy_gradient_loss | -0.00081    |
# |    std                  | 0.489       |
# |    value_loss           | 0.607       |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1            |
# |    ep_rew_mean          | 0.507        |
# | time/                   |              |
# |    fps                  | 12           |
# |    iterations           | 42           |
# |    time_elapsed         | 6631         |
# |    total_timesteps      | 86016        |
# | train/                  |              |
# |    approx_kl            | 0.0067599467 |
# |    clip_fraction        | 0.0777       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.09        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.223        |
# |    n_updates            | 410          |
# |    policy_gradient_loss | -0.00235     |
# |    std                  | 0.487        |
# |    value_loss           | 0.592        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1            |
# |    ep_rew_mean          | 0.482        |
# | time/                   |              |
# |    fps                  | 12           |
# |    iterations           | 43           |
# |    time_elapsed         | 6793         |
# |    total_timesteps      | 88064        |
# | train/                  |              |
# |    approx_kl            | 0.0070507014 |
# |    clip_fraction        | 0.0599       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.07        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.256        |
# |    n_updates            | 420          |
# |    policy_gradient_loss | -0.00163     |
# |    std                  | 0.483        |
# |    value_loss           | 0.574        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1            |
# |    ep_rew_mean          | 0.444        |
# | time/                   |              |
# |    fps                  | 12           |
# |    iterations           | 44           |
# |    time_elapsed         | 6958         |
# |    total_timesteps      | 90112        |
# | train/                  |              |
# |    approx_kl            | 0.0061445907 |
# |    clip_fraction        | 0.0418       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.07        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.213        |
# |    n_updates            | 430          |
# |    policy_gradient_loss | -0.000796    |
# |    std                  | 0.485        |
# |    value_loss           | 0.531        |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1           |
# |    ep_rew_mean          | 0.54        |
# | time/                   |             |
# |    fps                  | 12          |
# |    iterations           | 45          |
# |    time_elapsed         | 7123        |
# |    total_timesteps      | 92160       |
# | train/                  |             |
# |    approx_kl            | 0.005456389 |
# |    clip_fraction        | 0.0395      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.07       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.39        |
# |    n_updates            | 440         |
# |    policy_gradient_loss | -0.000158   |
# |    std                  | 0.484       |
# |    value_loss           | 0.527       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1           |
# |    ep_rew_mean          | 0.565       |
# | time/                   |             |
# |    fps                  | 12          |
# |    iterations           | 46          |
# |    time_elapsed         | 7287        |
# |    total_timesteps      | 94208       |
# | train/                  |             |
# |    approx_kl            | 0.006065615 |
# |    clip_fraction        | 0.07        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.06       |
# |    explained_variance   | 1.19e-07    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.184       |
# |    n_updates            | 450         |
# |    policy_gradient_loss | -0.00153    |
# |    std                  | 0.483       |
# |    value_loss           | 0.612       |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1          |
# |    ep_rew_mean          | 0.571      |
# | time/                   |            |
# |    fps                  | 12         |
# |    iterations           | 47         |
# |    time_elapsed         | 7452       |
# |    total_timesteps      | 96256      |
# | train/                  |            |
# |    approx_kl            | 0.00450187 |
# |    clip_fraction        | 0.052      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -2.05      |
# |    explained_variance   | 0          |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.198      |
# |    n_updates            | 460        |
# |    policy_gradient_loss | 0.000456   |
# |    std                  | 0.481      |
# |    value_loss           | 0.569      |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1            |
# |    ep_rew_mean          | 0.621        |
# | time/                   |              |
# |    fps                  | 12           |
# |    iterations           | 48           |
# |    time_elapsed         | 7617         |
# |    total_timesteps      | 98304        |
# | train/                  |              |
# |    approx_kl            | 0.0012456875 |
# |    clip_fraction        | 0.0301       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.03        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.311        |
# |    n_updates            | 470          |
# |    policy_gradient_loss | 0.000254     |
# |    std                  | 0.477        |
# |    value_loss           | 0.599        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1            |
# |    ep_rew_mean          | 0.574        |
# | time/                   |              |
# |    fps                  | 12           |
# |    iterations           | 49           |
# |    time_elapsed         | 7784         |
# |    total_timesteps      | 100352       |
# | train/                  |              |
# |    approx_kl            | 0.0028106896 |
# |    clip_fraction        | 0.0347       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.03        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.234        |
# |    n_updates            | 480          |
# |    policy_gradient_loss | -0.000335    |
# |    std                  | 0.481        |
# |    value_loss           | 0.573        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1            |
# |    ep_rew_mean          | 0.429        |
# | time/                   |              |
# |    fps                  | 12           |
# |    iterations           | 50           |
# |    time_elapsed         | 7948         |
# |    total_timesteps      | 102400       |
# | train/                  |              |
# |    approx_kl            | 0.0016741701 |
# |    clip_fraction        | 0.0458       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.03        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.337        |
# |    n_updates            | 490          |
# |    policy_gradient_loss | 0.000365     |
# |    std                  | 0.479        |
# |    value_loss           | 0.545        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1            |
# |    ep_rew_mean          | 0.507        |
# | time/                   |              |
# |    fps                  | 12           |
# |    iterations           | 51           |
# |    time_elapsed         | 8112         |
# |    total_timesteps      | 104448       |
# | train/                  |              |
# |    approx_kl            | 0.0046589696 |
# |    clip_fraction        | 0.0699       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.03        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.593        |
# |    n_updates            | 500          |
# |    policy_gradient_loss | -0.00175     |
# |    std                  | 0.478        |
# |    value_loss           | 0.588        |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1           |
# |    ep_rew_mean          | 0.638       |
# | time/                   |             |
# |    fps                  | 12          |
# |    iterations           | 52          |
# |    time_elapsed         | 8276        |
# |    total_timesteps      | 106496      |
# | train/                  |             |
# |    approx_kl            | 0.006608584 |
# |    clip_fraction        | 0.0654      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.01       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.289       |
# |    n_updates            | 510         |
# |    policy_gradient_loss | -0.00112    |
# |    std                  | 0.473       |
# |    value_loss           | 0.511       |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1            |
# |    ep_rew_mean          | 0.463        |
# ...
# |    value_loss           | 0.606        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1            |
# |    ep_rew_mean          | 0.552        |
# | time/                   |              |
# |    fps                  | 11           |
# |    iterations           | 717          |
# |    time_elapsed         | 122686       |
# |    total_timesteps      | 1468416      |
# | train/                  |              |
# |    approx_kl            | 0.0050693424 |
# |    clip_fraction        | 0.0389       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.77        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.238        |
# |    n_updates            | 7160         |
# |    policy_gradient_loss | -0.000579    |
# |    std                  | 0.622        |
# |    value_loss           | 0.584        |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1           |
# |    ep_rew_mean          | 0.546       |
# | time/                   |             |
# |    fps                  | 11          |
# |    iterations           | 718         |
# |    time_elapsed         | 122859      |
# |    total_timesteps      | 1470464     |
# | train/                  |             |
# |    approx_kl            | 0.006474299 |
# |    clip_fraction        | 0.0774      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.78       |
# |    explained_variance   | -1.19e-07   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.213       |
# |    n_updates            | 7170        |
# |    policy_gradient_loss | -0.00315    |
# |    std                  | 0.622       |
# |    value_loss           | 0.539       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1           |
# |    ep_rew_mean          | 0.509       |
# | time/                   |             |
# |    fps                  | 11          |
# |    iterations           | 719         |
# |    time_elapsed         | 123029      |
# |    total_timesteps      | 1472512     |
# | train/                  |             |
# |    approx_kl            | 0.005675175 |
# |    clip_fraction        | 0.0319      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.79       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.399       |
# |    n_updates            | 7180        |
# |    policy_gradient_loss | -0.000399   |
# |    std                  | 0.624       |
# |    value_loss           | 0.504       |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1            |
# |    ep_rew_mean          | 0.545        |
# | time/                   |              |
# |    fps                  | 11           |
# |    iterations           | 720          |
# |    time_elapsed         | 123201       |
# |    total_timesteps      | 1474560      |
# | train/                  |              |
# |    approx_kl            | 0.0057326676 |
# |    clip_fraction        | 0.0666       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.77        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.305        |
# |    n_updates            | 7190         |
# |    policy_gradient_loss | -0.00233     |
# |    std                  | 0.617        |
# |    value_loss           | 0.507        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1            |
# |    ep_rew_mean          | 0.475        |
# | time/                   |              |
# |    fps                  | 11           |
# |    iterations           | 721          |
# |    time_elapsed         | 123373       |
# |    total_timesteps      | 1476608      |
# | train/                  |              |
# |    approx_kl            | 0.0037929956 |
# |    clip_fraction        | 0.0349       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.76        |
# |    explained_variance   | -1.19e-07    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.154        |
# |    n_updates            | 7200         |
# |    policy_gradient_loss | -2.29e-05    |
# |    std                  | 0.621        |
# |    value_loss           | 0.625        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1            |
# |    ep_rew_mean          | 0.45         |
# | time/                   |              |
# |    fps                  | 11           |
# |    iterations           | 722          |
# |    time_elapsed         | 123544       |
# |    total_timesteps      | 1478656      |
# | train/                  |              |
# |    approx_kl            | 0.0028197225 |
# |    clip_fraction        | 0.0204       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.78        |
# |    explained_variance   | -1.19e-07    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.17         |
# |    n_updates            | 7210         |
# |    policy_gradient_loss | 0.000316     |
# |    std                  | 0.625        |
# |    value_loss           | 0.596        |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1           |
# |    ep_rew_mean          | 0.614       |
# | time/                   |             |
# |    fps                  | 11          |
# |    iterations           | 723         |
# |    time_elapsed         | 123714      |
# |    total_timesteps      | 1480704     |
# | train/                  |             |
# |    approx_kl            | 0.007874535 |
# |    clip_fraction        | 0.0723      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.79       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.401       |
# |    n_updates            | 7220        |
# |    policy_gradient_loss | -0.00121    |
# |    std                  | 0.625       |
# |    value_loss           | 0.586       |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1            |
# |    ep_rew_mean          | 0.397        |
# | time/                   |              |
# |    fps                  | 11           |
# |    iterations           | 724          |
# |    time_elapsed         | 123885       |
# |    total_timesteps      | 1482752      |
# | train/                  |              |
# |    approx_kl            | 0.0033443007 |
# |    clip_fraction        | 0.0617       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.81        |
# |    explained_variance   | -1.19e-07    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.294        |
# |    n_updates            | 7230         |
# |    policy_gradient_loss | -0.002       |
# |    std                  | 0.633        |
# |    value_loss           | 0.525        |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1           |
# |    ep_rew_mean          | 0.596       |
# | time/                   |             |
# |    fps                  | 11          |
# |    iterations           | 725         |
# |    time_elapsed         | 124056      |
# |    total_timesteps      | 1484800     |
# | train/                  |             |
# |    approx_kl            | 0.005366045 |
# |    clip_fraction        | 0.0687      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.82       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.133       |
# |    n_updates            | 7240        |
# |    policy_gradient_loss | -0.00215    |
# |    std                  | 0.631       |
# |    value_loss           | 0.545       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1           |
# |    ep_rew_mean          | 0.498       |
# | time/                   |             |
# |    fps                  | 11          |
# |    iterations           | 726         |
# |    time_elapsed         | 124227      |
# |    total_timesteps      | 1486848     |
# | train/                  |             |
# |    approx_kl            | 0.005095505 |
# |    clip_fraction        | 0.0476      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.81       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.195       |
# |    n_updates            | 7250        |
# |    policy_gradient_loss | -0.00107    |
# |    std                  | 0.63        |
# |    value_loss           | 0.503       |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1            |
# |    ep_rew_mean          | 0.414        |
# | time/                   |              |
# |    fps                  | 11           |
# |    iterations           | 727          |
# |    time_elapsed         | 124397       |
# |    total_timesteps      | 1488896      |
# | train/                  |              |
# |    approx_kl            | 0.0035511567 |
# |    clip_fraction        | 0.0241       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.83        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.134        |
# |    n_updates            | 7260         |
# |    policy_gradient_loss | 0.000747     |
# |    std                  | 0.637        |
# |    value_loss           | 0.541        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1            |
# |    ep_rew_mean          | 0.516        |
# | time/                   |              |
# |    fps                  | 11           |
# |    iterations           | 728          |
# |    time_elapsed         | 124570       |
# |    total_timesteps      | 1490944      |
# | train/                  |              |
# |    approx_kl            | 0.0055860933 |
# |    clip_fraction        | 0.0678       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.84        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.284        |
# |    n_updates            | 7270         |
# |    policy_gradient_loss | -0.00319     |
# |    std                  | 0.636        |
# |    value_loss           | 0.465        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1            |
# |    ep_rew_mean          | 0.583        |
# | time/                   |              |
# |    fps                  | 11           |
# |    iterations           | 729          |
# |    time_elapsed         | 124741       |
# |    total_timesteps      | 1492992      |
# | train/                  |              |
# |    approx_kl            | 0.0052462174 |
# |    clip_fraction        | 0.0531       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.84        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.168        |
# |    n_updates            | 7280         |
# |    policy_gradient_loss | -0.000911    |
# |    std                  | 0.638        |
# |    value_loss           | 0.643        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1            |
# |    ep_rew_mean          | 0.564        |
# | time/                   |              |
# |    fps                  | 11           |
# |    iterations           | 730          |
# |    time_elapsed         | 124915       |
# |    total_timesteps      | 1495040      |
# | train/                  |              |
# |    approx_kl            | 0.0055056307 |
# |    clip_fraction        | 0.0562       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.83        |
# |    explained_variance   | 2.38e-07     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.257        |
# |    n_updates            | 7290         |
# |    policy_gradient_loss | -0.000113    |
# |    std                  | 0.636        |
# |    value_loss           | 0.565        |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1           |
# |    ep_rew_mean          | 0.63        |
# | time/                   |             |
# |    fps                  | 11          |
# |    iterations           | 731         |
# |    time_elapsed         | 125087      |
# |    total_timesteps      | 1497088     |
# | train/                  |             |
# |    approx_kl            | 0.005363228 |
# |    clip_fraction        | 0.0561      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.84       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.296       |
# |    n_updates            | 7300        |
# |    policy_gradient_loss | -0.00215    |
# |    std                  | 0.638       |
# |    value_loss           | 0.584       |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1          |
# |    ep_rew_mean          | 0.568      |
# | time/                   |            |
# |    fps                  | 11         |
# |    iterations           | 732        |
# |    time_elapsed         | 125259     |
# |    total_timesteps      | 1499136    |
# | train/                  |            |
# |    approx_kl            | 0.00514084 |
# |    clip_fraction        | 0.0406     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -2.83      |
# |    explained_variance   | 0          |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.271      |
# |    n_updates            | 7310       |
# |    policy_gradient_loss | -0.000216  |
# |    std                  | 0.632      |
# |    value_loss           | 0.542      |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1           |
# |    ep_rew_mean          | 0.446       |
# | time/                   |             |
# |    fps                  | 11          |
# |    iterations           | 733         |
# |    time_elapsed         | 125432      |
# |    total_timesteps      | 1501184     |
# | train/                  |             |
# |    approx_kl            | 0.006275613 |
# |    clip_fraction        | 0.0589      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.82       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.61        |
# |    n_updates            | 7320        |
# |    policy_gradient_loss | -0.00258    |
# |    std                  | 0.631       |
# |    value_loss           | 0.578       |
# -----------------------------------------
# Test action: [-1.  1.  1.]

# %%
model.save(os.path.join(log_dir, "ppo_model"))

# %% [markdown]
# Evaluation

# %%
import os
import pandas as pd
import seaborn as sns

from stable_baselines3 import PPO
from stable_baselines3.common.monitor import Monitor

# test environment
env = CustomEnv()

# ==== Configuration ====
log_dir = "../logs/rl_repressilator_past_amort_single_step"
model_path = os.path.join(log_dir, "ppo_model")

df = pd.read_csv(monitor_file, skiprows=1)  # Skip header comment row

# %%
model = PPO.load(model_path)

# %%
obs, info = env.reset()
action, _ = model.predict(obs)
print("Test action:", action)
# Out:
# Test action: [-1.  1.  1.]

# %%
obs, info = env.reset()  # Reset the environment with a specific frequency

action, _states = model.predict(obs, deterministic=True)
action
print("Action taken:", action)
first_params = np.hstack((env.uncertain, action))
plt.plot(jl.observation(env.uncertain, action), label=" Design")
# Out:
# Action taken: [-1.  1.  1.]

# %%
first_rewards = np.zeros(1000)


env.seed(31415)

for i in range(1000):
    obs, info = env.reset() 
    action, _states = model.predict(obs, deterministic=True)
    obs, reward, terminated, truncated, info = env.step(action)
    first_rewards[i] = (reward + jl.reward_normalized_past_amort(np.hstack((env.uncertain, action)), 1/7) + jl.reward_normalized_past_amort(np.hstack((env.uncertain, action)), 1/7) + jl.reward_normalized_past_amort(np.hstack((env.uncertain, action)), 1/7) + jl.reward_normalized_past_amort(np.hstack((env.uncertain, action)), 1/7))/ 5

# %%
plt.figure(figsize=(10, 6))
plt.plot(first_rewards, label='First Reward', alpha=0.7)
plt.legend()
plt.xlabel("Trial (new uncertain parameters sampled from the prior)", fontsize=18)
plt.ylabel("Reward", fontsize=18)
# Out:
# Text(0, 0.5, 'Reward')

# %%
#plot violins seaborn
import seaborn as sns
plt.figure(figsize=(2, 6))
sns.violinplot(data=[first_rewards], inner="quartile")
plt.xlabel("Design", fontsize=18)
plt.ylabel("Reward", fontsize=18)
# Out:
# Text(0, 0.5, 'Reward')

# %%
# Plot boxplot with seaborn
plt.figure(figsize=(2, 6))
sns.boxplot(data=[first_rewards], showmeans=True)

# Set x-axis labels starting from 1
plt.xticks(ticks=range(1), labels=["single-step"])

plt.xlabel("design", fontsize=18)
plt.ylabel("reward", fontsize=18)

sns.despine()
plt.ylim(-3,1.5)
plt.tight_layout()
plt.show()
